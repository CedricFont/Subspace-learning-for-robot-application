# %% [markdown]
# # Panda robot identification using SLFC

# %%
import numpy as np
from numpy import random as rnd
from numpy.linalg import pinv
from numpy import linalg as lg
from scipy import linalg as slg
from importlib import reload
import seaborn as snb
import matplotlib.pyplot as plt
import Utils.Functions 
from Utils.Functions import *
import pbdlib as pbd
from scipy.linalg import hankel
import joblib
import pybullet
from pbdlib import LQR
from pbdlib.utils import get_canonical
import pandapybullet as ppb
import torch
import time
import GPy, GPyOpt
# %load_ext autoreload
# %autoreload 2
plt.style.use("default")
plt.rcParams['font.size'] = 13
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams['lines.linewidth'] = 2.5
np.set_printoptions(precision=5, suppress=False)

# %% [markdown]
# ## Gather training data
# ### Define random sine reference
#
# Run a LQR using desired joint position and velocity to retrieve jooitn acceleration

# %%
dt = 1e-3
world_sim = ppb.WorldSim()
world_sim.setup_scene()
world_sim.load_table()
robot = world_sim.load_panda()

# %%
N=15000
T = N*dt
n_training = 5
n_testing = 2
n_tot = n_training + n_testing
joint_limits = robot.joint_limits.copy()
joint_limits[1,:] = [-deg2rad(35),deg2rad(35)]
# joint_limits[3,0] = -deg2rad(60)

# Trajectories specifications
specs = {'phi': {'low': -np.pi, 'high': np.pi}, 
         'A': {'low': -np.pi, 'high': np.pi},
         'f': {'low': 1/20, 'high': .3},
         'nb_parts': 100, 'margin': .2, 'safety': .8}

pandaRobot = Robot(7, 7, dt, N, robot)
pandaRobot.drawTrajectories(nb_traj=n_tot, q_limits=joint_limits, specs=specs)

# %% [markdown]
# ## Gather training data using CTC + PD
#
# ### Tune PD controller

# %%
Kp = np.diag([200]*7)
Ki = np.eye(7)*5.
Kd = np.eye(7)*5.

robot.reset_q(max_iter=100)
robot.joints_free=True
# Out:
# joints are free now

# %% [markdown]
# ### Simulate using CTC + PD

# %%
log_control = np.empty(shape=[n_tot,7,N-1])
log_q = np.empty(shape=[n_tot,7,N])
log_dq = np.empty(shape=[n_tot,7,N])
log_ddq = np.empty(shape=[n_tot,7,N])

for n in range(n_tot):
    log_error = []
    sum_error = np.zeros(7)
    log_q[n,:,0] = robot.q
    log_dq[n,:,0] = robot.dq
    log_ddq[n,:,0] = robot.ddq
    
    robot.default_q = pandaRobot.ref[n,:7,0]
    robot.reset_q(max_iter=100)
    robot.joints_free=True
    for i in range(0, N-1):
        error_q = pandaRobot.ref[n,:7,i] - robot.q
        error_dq = pandaRobot.ref[n,7:,i] - robot.dq

    #   Computed Torque Control
        control_input = robot.configuration_ctc(Kp @ error_q + Ki @ sum_error + Kd @ error_dq + pandaRobot.desired_ddq[n,:,i])
        
        for j in range(7):
            if control_input[j] < robot.joint_torque_limits[j,0]:
                control_input[j] = robot.joint_torque_limits[j,0].copy()
            if control_input[j] > robot.joint_torque_limits[j,1]:
                control_input[j] = robot.joint_torque_limits[j,1].copy()

        robot.set_torque(control_input[:7])

        log_error.append(np.copy(error_q))
        log_q[n,:,i] = robot.q.copy()
        log_dq[n,:,i] = robot.dq.copy()
        log_ddq[n,:,i] = robot.ddq.copy()
        log_control[n,:,i] = np.copy(control_input)
    #     time.sleep(dt)
        sum_error += error_q*dt
# Out:
# joints are free now
# joints are free now
# joints are free now
# joints are free now
# joints are free now
# joints are free now
# joints are free now

# %% [markdown]
# ### Store data in state-space form

# %%
pandaRobot.toStateSpace(log_q, log_dq, log_control)

# %% [markdown]
# ## Model training

# %% [markdown]
# ### Using *GPyOpt*

# %%
traj_ratio = .02
nx_low, nx_high = 1, 10
nu_low, nu_high = 0, 5
d_low, d_high = 1, np.int((1-traj_ratio)/max(nx_high,nu_high)*pandaRobot.N)

domain = [
    {'name': 'input_cost', 'type': 'continuous', 'domain': (0.,3.)},
    {'name': 'dimension_x', 'type': 'discrete', 'domain': np.arange(nx_low,nx_high,1)},
    {'name': 'dimension_u', 'type': 'discrete', 'domain': np.arange(nu_low,nu_high,1)},
    {'name': 'nb_delays', 'type': 'discrete', 'domain': np.arange(d_low,d_high,1)}
]

print('delay max : ',np.int((1-traj_ratio)/max(nx_high,nu_high)*pandaRobot.N))
print('points min : ',pandaRobot.N- d_high*max(nx_high,nu_high))

# n_training = 5 # Number of trainings per epoch
loss_traj = np.empty(shape=[n_training])
loss_U = np.empty(shape=[n_training])
loss_LQR = np.empty(shape=[n_training])

# @use_named_args(SPACE)
def loss(space):
    # Model parameters
    n_params = space.shape[0] # If train by batch
    u_std = space[0,0]
    nx = np.int(space[0,1])
    nu = np.int(space[0,2])
    d = np.int(space[0,3])
    
    timing = np.empty([2,n_training])
    
    for fold in range(n_training):
        timing[0,fold] = time.time() # HAVOK computation time
        
        model = SLFC(pandaRobot.dX[fold,:,:], pandaRobot.dU[fold,:,:], learnOnDiff=True)
        model.delayEmbeddings(nx, nu, d)
        model.EDMD()

        timing[0,fold] = time.time() - timing[0,fold]  
        timing[1,fold] = time.time() # LQR computation time
        
        # LQR loss ##############################
        model.ConstructLQR(x_std=1e6*np.ones(pandaRobot.nb_S), u_std=u_std, dt=dt, ref=pandaRobot.ref[fold,:,:]) # To learn on differences
        model.LQR_simulate(X0=pandaRobot.ref[fold,:,0])
        
#         loss_traj[fold] = model.RMSE(X_pred=model.X_traj, X_true=pandaRobot.X[fold,:,:]) 
        loss_LQR[fold] = model.RMSE(X_pred=torch.tensor(model.LQR_X[:7,:],dtype=torch.float), 
                                    X_true=torch.tensor(pandaRobot.ref[fold,:7,:],dtype=torch.float))
        loss_U[fold] = model.RMSE(X_pred=model.LQR_U[0,:,:].T, 
                                  X_true=pandaRobot.U[fold,:,:])
        
        timing[1,fold] = time.time() - timing[1,fold]  
        
    loss_LQR_sum = loss_LQR.sum()/n_training
    loss_U_sum = loss_U.sum()/n_training
    loss = loss_LQR_sum + loss_U_sum
    avg_time = [timing[0,:].sum()/n_training,timing[1,:].sum()/n_training]
    
    if np.isnan(loss) or np.isinf(loss):
        loss = 1e10
        
    print('Total loss : '+str(loss)+'Loss LQR : '+str(loss_LQR_sum)+'Loss U : '+str(loss_U_sum)+
          ', u_std : '+str(u_std)+', nx :'+str(nx)+', nu :'+str(nu)+', d : '+str(d))
    print('Avg computation time for SLFC : '+str(avg_time[0])+' [s], for LQR : '+str(avg_time[1])+' [s]')
    
    return loss

max_iter = 500
batch_size = 6
num_cores = 6

opt = GPyOpt.methods.BayesianOptimization(f = loss,            # function to optimize       
                                          domain = domain,         # box-constraints of the problem
                                          acquisition_type ='LCB',       # LCB acquisition
                                          acquisition_weight = 0.3)     # Exploration exploitation
 

opt.run_optimization(max_iter)
# Out:
# delay max :  1470
# points min :  300
# Total loss : 2571.039581026929Loss LQR : 55.8004867553711Loss U : 2515.2390942715583, u_std : 0.016102738698969166, nx :4, nu :4, d : 932
# Avg computation time for SLFC : 0.5128286361694336 [s], for LQR : 7.876493310928344 [s]
# Total loss : 942.0912071191915Loss LQR : 56.95481719970703Loss U : 885.1363899194845, u_std : 1.3422432558769173, nx :4, nu :1, d : 74
# Avg computation time for SLFC : 0.5032540321350097 [s], for LQR : 5.7903142929077145 [s]
# Total loss : 607.5282065566852Loss LQR : 54.816009521484375Loss U : 552.7121970352008, u_std : 1.5007475937526307, nx :1, nu :4, d : 786
# Avg computation time for SLFC : 0.2756622314453125 [s], for LQR : 3.9195157527923583 [s]
# Total loss : 2691.3903949955525Loss LQR : 58.611446380615234Loss U : 2632.7789486149372, u_std : 0.04292956625047717, nx :8, nu :1, d : 105
# Avg computation time for SLFC : 0.8551132202148437 [s], for LQR : 15.014237403869629 [s]
# Total loss : 1206.44814588331Loss LQR : 61.8589729309082Loss U : 1144.5891729524017, u_std : 1.0043499224896677, nx :9, nu :3, d : 542
# Avg computation time for SLFC : 1.2424770832061767 [s], for LQR : 27.1306263923645 [s]
# Total loss : 607.5282065605013Loss LQR : 54.816009521484375Loss U : 552.7121970390169, u_std : 1.5007475937526278, nx :1, nu :4, d : 786
# Avg computation time for SLFC : 0.3003969669342041 [s], for LQR : 4.42835431098938 [s]
# Total loss : 1004.4931750051119Loss LQR : 54.94112319946289Loss U : 949.552051805649, u_std : 1.1281007538924681, nx :3, nu :0, d : 77
# Avg computation time for SLFC : 0.3949441909790039 [s], for LQR : 4.435135316848755 [s]
# Total loss : 1065.0231497487039Loss LQR : 56.74014129638672Loss U : 1008.2830084523172, u_std : 1.1804691810973198, nx :4, nu :3, d : 781
# Avg computation time for SLFC : 0.7037179946899415 [s], for LQR : 17.91788249015808 [s]
# Total loss : 424.90337747621794Loss LQR : 56.61998291015625Loss U : 368.2833945660617, u_std : 2.01766420589239, nx :1, nu :4, d : 794
# Avg computation time for SLFC : 0.3442798137664795 [s], for LQR : 5.517574071884155 [s]
# Total loss : 1768.7650547354551Loss LQR : 49.85569686889649Loss U : 1718.9093578665586, u_std : 0.0, nx :1, nu :4, d : 794
# Avg computation time for SLFC : 0.3283219337463379 [s], for LQR : 5.47136378288269 [s]
# Total loss : 605.1225573142619Loss LQR : 75.16577224731445Loss U : 529.9567850669475, u_std : 2.0262681454165103, nx :9, nu :0, d : 922
# Avg computation time for SLFC : 1.3717309474945067 [s], for LQR : 37.05627646446228 [s]
# Total loss : 518.0269338378496Loss LQR : 62.00969467163086Loss U : 456.01723916621876, u_std : 2.002712162614835, nx :2, nu :4, d : 787
# Avg computation time for SLFC : 0.5718702793121337 [s], for LQR : 11.113670921325683 [s]
# Avg computation time for SLFC : 1.432568073272705 [s], for LQR : 42.9505871295929 [s]
# Total loss : 299.35738082636254Loss LQR : 69.81915893554688Loss U : 229.53822189081566, u_std : 3.0, nx :3, nu :0, d : 1232
# Avg computation time for SLFC : 0.3594375133514404 [s], for LQR : 6.678335380554199 [s]
# Total loss : 231.578685459736Loss LQR : 82.0275634765625Loss U : 149.5511219831735, u_std : 3.0, nx :9, nu :4, d : 1230
# Avg computation time for SLFC : 1.9683341979980469 [s], for LQR : 54.13887276649475 [s]
# Total loss : 237.86228871479952Loss LQR : 86.65131988525391Loss U : 151.2109688295456, u_std : 3.0, nx :9, nu :1, d : 1226
# Avg computation time for SLFC : 1.8081562995910645 [s], for LQR : 49.734137773513794 [s]
# Total loss : 1875.8142207744083Loss LQR : 70.85063247680664Loss U : 1804.9635882976017, u_std : 0.0, nx :9, nu :4, d : 1225
# Avg computation time for SLFC : 2.3088237762451174 [s], for LQR : 60.63745012283325 [s]
# Total loss : 255.36783947864762Loss LQR : 87.4805191040039Loss U : 167.8873203746437, u_std : 3.0, nx :9, nu :0, d : 1267
# Avg computation time for SLFC : 1.8078195095062255 [s], for LQR : 52.82162537574768 [s]
# Total loss : 246.47213027671077Loss LQR : 84.79447784423829Loss U : 161.67765243247248, u_std : 3.0, nx :8, nu :0, d : 1228
# Avg computation time for SLFC : 1.5684043407440185 [s], for LQR : 44.47084288597107 [s]
# Total loss : 257.0565092339187Loss LQR : 81.91619110107422Loss U : 175.14031813284447, u_std : 3.0, nx :6, nu :0, d : 1272
# Avg computation time for SLFC : 0.8627838134765625 [s], for LQR : 27.25837073326111 [s]
# Total loss : 269.3341352038515Loss LQR : 86.83246154785157Loss U : 182.50167365599992, u_std : 3.0, nx :9, nu :0, d : 1275
# Avg computation time for SLFC : 1.619867753982544 [s], for LQR : 46.59615712165832 [s]
# Total loss : 2706.7233847990406Loss LQR : 75.86036758422851Loss U : 2630.863017214812, u_std : 0.0, nx :9, nu :0, d : 1272
# Avg computation time for SLFC : 1.7764477729797363 [s], for LQR : 49.86912994384765 [s]
# Total loss : 269.50867693458304Loss LQR : 77.11970672607421Loss U : 192.38897020850885, u_std : 3.0, nx :5, nu :0, d : 1279
# Avg computation time for SLFC : 0.6684053897857666 [s], for LQR : 18.871275091171263 [s]
# Total loss : 239.2660473093727Loss LQR : 62.49271850585937Loss U : 176.77332880351335, u_std : 3.0, nx :1, nu :0, d : 1271
# Avg computation time for SLFC : 0.34667248725891114 [s], for LQR : 2.5471862316131593 [s]
# Total loss : 245.994530921076Loss LQR : 87.42317199707031Loss U : 158.5713589240057, u_std : 3.0, nx :9, nu :0, d : 1279
# Avg computation time for SLFC : 1.7168076992034913 [s], for LQR : 50.82842621803284 [s]
# Total loss : 281.91154688101403Loss LQR : 75.29708938598633Loss U : 206.61445749502772, u_std : 3.0, nx :5, nu :1, d : 1275
# Avg computation time for SLFC : 0.7904873371124268 [s], for LQR : 26.382897663116456 [s]
# Total loss : 1032.317315697876Loss LQR : 50.60105438232422Loss U : 981.7162613155517, u_std : 0.879731424161018, nx :1, nu :0, d : 1429
# Avg computation time for SLFC : 0.3510613918304443 [s], for LQR : 2.6250289916992187 [s]
# Total loss : 262.7194656213778Loss LQR : 80.78196563720704Loss U : 181.93749998417078, u_std : 3.0, nx :5, nu :0, d : 1267
# Avg computation time for SLFC : 0.6003940105438232 [s], for LQR : 17.19541916847229 [s]
# Total loss : 276.36453330289635Loss LQR : 72.93306121826171Loss U : 203.43147208463466, u_std : 3.0, nx :3, nu :0, d : 1272
# Avg computation time for SLFC : 0.3416865825653076 [s], for LQR : 6.028822946548462 [s]
# Total loss : 1447.80998033584Loss LQR : 52.112823486328125Loss U : 1395.6971568495119, u_std : 0.6765034113221292, nx :5, nu :0, d : 252
# Avg computation time for SLFC : 0.8571075916290283 [s], for LQR : 19.31755676269531 [s]
# Total loss : 229.11935619431975Loss LQR : 62.78197250366211Loss U : 166.33738369065765, u_std : 3.0, nx :1, nu :0, d : 1289
# Avg computation time for SLFC : 0.3574439525604248 [s], for LQR : 2.816864585876465 [s]
# Total loss : 236.76235528800504Loss LQR : 63.19850845336914Loss U : 173.5638468346359, u_std : 3.0, nx :1, nu :0, d : 1295
# Avg computation time for SLFC : 0.3807825088500977 [s], for LQR : 2.8571561336517335 [s]
# Total loss : 272.65241071929444Loss LQR : 79.95735168457031Loss U : 192.69505903472412, u_std : 3.0, nx :6, nu :0, d : 1292
# Avg computation time for SLFC : 0.9223330020904541 [s], for LQR : 32.00526061058044 [s]
# Total loss : 299.4749636693998Loss LQR : 73.38006744384765Loss U : 226.0948962255522, u_std : 3.0, nx :2, nu :4, d : 1292
# Avg computation time for SLFC : 0.5692775249481201 [s], for LQR : 11.93367772102356 [s]
# Total loss : 2228.9427981331464Loss LQR : 43.908914947509764Loss U : 2185.0338831856366, u_std : 0.0, nx :1, nu :0, d : 1292
# Avg computation time for SLFC : 0.3584409713745117 [s], for LQR : 2.595058012008667 [s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-7-c540077785c4> in <module>
#      76
#      77
# ---> 78 opt.run_optimization(max_iter)
#
# ~\anaconda3\lib\site-packages\GPyOpt\core\bo.py in run_optimization(self, max_iter, max_time, eps, context, verbosity, save_models_parameters, report_file, evaluations_file, models_file)
#     149
#     150             # --- Evaluate *f* in X, augment Y and update cost function (if needed)
# --> 151             self.evaluate_objective()
#     152
#     153             # --- Update current evaluation time and function evaluations
#
# ~\anaconda3\lib\site-packages\GPyOpt\core\bo.py in evaluate_objective(self)
#     195         Evaluates the objective
#     196         """
# --> 197         self.Y_new, cost_new = self.objective.evaluate(self.suggested_sample)
#     198         self.cost.update_cost_model(self.suggested_sample, cost_new)
#     199         self.Y = np.vstack((self.Y,self.Y_new))
#
# ~\anaconda3\lib\site-packages\GPyOpt\core\task\objective.py in evaluate(self, x)
#      48
#      49         if self.n_procs == 1:
# ---> 50             f_evals, cost_evals = self._eval_func(x)
#      51         else:
#      52             try:
#
# ~\anaconda3\lib\site-packages\GPyOpt\core\task\objective.py in _eval_func(self, x)
#      72         for i in range(x.shape[0]):
#      73             st_time    = time.time()
# ---> 74             rlt = self.func(np.atleast_2d(x[i]))
#      75             f_evals     = np.vstack([f_evals,rlt])
#      76             cost_evals += [time.time()-st_time]
#
# <ipython-input-7-c540077785c4> in loss(space)
#      34
#      35         model = SLFC(pandaRobot.dX[fold,:,:], pandaRobot.dU[fold,:,:], learnOnDiff=True)
# ---> 36         model.delayEmbeddings(nx, nu, d)
#      37         model.EDMD()
#      38
#
# ~\OneDrive\Documents\Mécanique - EPFL\Master III\Semester project\Software\My code\Subspace-learning-for-robot-application\LQR simulation\Utils\Functions.py in delayEmbeddings(self, nx, nu, d)
#     554
#     555         # Observable : norm of the input vector
# --> 556         self.X_lift[nx*self.nb_S + nu*self.nb_U - 1,:] = torch.norm(torch.cat((self.X[:,:self.N - max(nx,nu)*d],
#     557                                                   self.U[:,:self.N - max(nx,nu)*d]),axis=0),p=2)
#     558
#
# RuntimeError: torch.cat(): Sizes of tensors must match except in dimension 0. Got 14999 and 14998 in dimension 1 (The offending index is 1)

# %% [markdown]
# ## LQR control of the Panda robot
# ### Construct LQR planner

# %%
# Train linear model
traj = 0

nx = 1
nu = 2
d = 790
u_std = 3.0

model = SLFC(pandaRobot.dX[traj,:,:], pandaRobot.dU[traj,:,:], learnOnDiff=True)
model.delayEmbeddings(nx, nu, d)
model.EDMD()

# loss_traj_train = model.RMSE(X_pred=model.X_sim, X_true=pandaRobot.X[traj,:,:])
# print('Forward prediction RMSE : '+str(loss_traj_train))

# Train LQR controller
model.ConstructLQR(x_std=1e6*np.ones(pandaRobot.nb_S), u_std=u_std, dt=dt, ref=pandaRobot.ref[traj,:,:]) # To learn on differences
model.LQR_simulate(X0=pandaRobot.ref[traj,:,0])

loss_LQR_subspace = model.RMSE(X_pred=torch.tensor(model.LQR_X[:7,:]), 
                                    X_true=torch.tensor(pandaRobot.ref[traj,:7,:]))
print('LQR RMSE : '+str(loss_LQR_subspace))

# plt.rcParams['font.size'] = 20
# fig, ax = plt.subplots(1, 2, constrained_layout = True, figsize=(18,8))

# figA = snb.heatmap(model.A,cmap='Reds',ax=ax[0])
# figB = snb.heatmap(model.B,cmap='Reds',ax=ax[1])

plt.rcParams['font.size'] = 20
fig, ax = plt.subplots(7, 3, constrained_layout = True, figsize=(18,13))

for i in range(7):
    
    ax[i,0].plot(pandaRobot.T, rad2deg(model.LQR_X[i,:]), label='Joint '+str(i+1)+' pos.')
    ax[i,0].plot(pandaRobot.T, rad2deg(pandaRobot.ref[traj,i,:]), label='Pos. ref.')
    ax[i,1].plot(pandaRobot.T, rad2deg(model.LQR_X[7+i,:]), label='Joint '+str(i+1)+' vel.')
    ax[i,1].plot(pandaRobot.T, rad2deg(pandaRobot.X[traj,7+i,:]), label='Vel. CTC.')
    ax[i,2].plot(pandaRobot.T[:len(pandaRobot.T)-1], model.LQR_U[0,:,i], label='Joint '+str(i+1)+' torque LQR')
    ax[i,2].plot(pandaRobot.T[:len(pandaRobot.T)-1], pandaRobot.U[traj,i,:], label='Joint '+str(i+1)+' torque CTC')
    ax[i,0].set_ylabel('Pos. [deg]'), ax[i,1].set_ylabel('Vel. [deg/s]'), ax[i,2].set_ylabel('Torque [Nm]')
    ax[i,0].legend(), ax[i,1].legend(), ax[i,2].legend()
    
ax[6,0].set_xlabel('Time [s]'), ax[6,1].set_xlabel('Time [s]')
# Out:
# LQR RMSE : tensor(65.6593, dtype=torch.float64)
# (Text(0.5, 0, 'Time [s]'), Text(0.5, 0, 'Time [s]'))

# %% [markdown]
# ### Plot CTC trajectory

# %%
traj = 4
plt.rcParams['font.size'] = 20
fig, ax = plt.subplots(7, 3, constrained_layout = True, figsize=(18,11))

for i in range(7):
    
    ax[i,0].plot(pandaRobot.T, rad2deg(pandaRobot.X[traj,i,:]), label='Joint '+str(i+1)+' pos.')
    ax[i,0].plot(pandaRobot.T, rad2deg(pandaRobot.ref[traj,i,:]), label='Pos. ref.')
    ax[i,1].plot(pandaRobot.T, rad2deg(pandaRobot.X[traj,i+7,:]), label='Joint '+str(i+1)+' vel.')
    ax[i,1].plot(pandaRobot.T, rad2deg(pandaRobot.ref[traj,i+7,:]), label='Vel. ref.')
    ax[i,2].plot(pandaRobot.T[:len(pandaRobot.T)-1], pandaRobot.U[traj,i,:], label='Joint '+str(i+1)+' torque')
    ax[i,0].set_ylabel('Position [deg]'), ax[i,1].set_ylabel('Velocity [deg/s]'), ax[i,2].set_ylabel('Torque [Nm]')
    ax[i,0].legend(), ax[i,1].legend(), ax[i,2].legend()
    
ax[6,0].set_xlabel('Time [s]'), ax[6,1].set_xlabel('Time [s]')
# Out:
# (Text(0.5, 0, 'Time [s]'), Text(0.5, 0, 'Time [s]'))

# %% [markdown]
# ### Apply LQR planner onto real robot dynamics

# %%
X0 = pandaRobot.ref[traj,:,0]
Xc, Yc = np.zeros(shape=[model.nb_S,model.N]), np.zeros(shape=[model.tau,model.N])
Uc = np.empty(shape=[model.nb_U,model.N-1])

# Initial condition
Xc[:,0] = X0
# N = np.eye(model.tau) - pinv(model.C) @ model.C
Y0 = pinv(model.C)@X0
# Y0 = Y0 + N@(model.Y[:,0] - Y0) # Nullspace projection into subspace 
Yc[:,0] = Y0

robot.default_q = Xc[:7,0]
robot.reset_q(max_iter=100)
robot.joints_free=True

sum_error = np.zeros(7)

# Simulate the closed-loop trajectory for the non-linear dynamics
for i in range(model.N-1):

#   LQR planner control input
    control_input = model.LQR.get_command(Yc[:,i],i)

    robot.set_torque(control_input[:7])

    log_error.append(np.copy(error_q))
    Xc[0:7,i] = robot.q
    Xc[7:,i] = robot.dq
#     log_ddq[n,:,i] = robot.ddq
    Uc[:,i] = np.copy(control_input)
#     time.sleep(dt) # Real-time rendering
    sum_error += error_q*dt
    
    Yc[:,i+1] = pinv(model.C)@Xc[:,i+1]
    
loss_LQR_true = model.RMSE(X_pred=Xc[, 
                                    X_true=pandaRobot.ref[traj,:,:])
print('LQR RMSE : '+str(loss_LQR_true))
    
plt.rcParams['font.size'] = 20
fig,ax = plt.subplots(7, 3, constrained_layout = True, figsize=(18,13))

for i in range(7):
    
    ax[i,0].plot(pandaRobot.T, rad2deg(Xc[i,:]), label='Joint '+str(i+1)+' pos.')
    ax[i,0].plot(pandaRobot.T, rad2deg(pandaRobot.ref[traj,i,:]), label='Pos. ref.')
    ax[i,1].plot(pandaRobot.T, rad2deg(Xc[i+7,:]), label='Joint '+str(i+1)+' vel.')
    ax[i,1].plot(pandaRobot.T, rad2deg(pandaRobot.ref[traj,i+7,:]), label='Vel. ref.')
    ax[i,2].plot(pandaRobot.T[:len(pandaRobot.T)-1], Uc[i,:], label='Joint '+str(i+1)+' control')
    
    ax[i,0].set_ylabel('Position [deg]'), ax[i,1].set_ylabel('Velocity [deg/s]')
    ax[i,2].set_ylabel('Torque [Nm]')
    ax[i,0].legend(), ax[i,1].legend(), ax[i,2].legend()
    
ax[6,0].set_xlabel('Time [s]'), ax[6,1].set_xlabel('Time [s]')
# Out:
# C:\Users\cedri\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# joints are free now
# LQR RMSE : 497.4645270185171
# (Text(0.5, 0, 'Time [s]'), Text(0.5, 0, 'Time [s]'))

# %%
print(Xc[:,0],pandaRobot.ref[traj,:,0])
# Out:
# [ 1.92311 -0.84735  1.12334 -1.5787   1.15286 -0.00617 -1.87547  0.32676
#  -0.18946 -0.40925 -0.64609  0.71115 -0.24451 -1.27567] [-1.00575 -0.67185  1.75852 -0.44156 -1.78396  1.44367  0.94552  0.
#   0.       0.       0.       0.       0.       0.     ]
