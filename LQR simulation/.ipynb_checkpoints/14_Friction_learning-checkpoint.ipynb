# %% [markdown]
# # Friction models learning for Panda robot

# %%
import numpy as np
from numpy import random as rnd
from numpy.linalg import pinv
from numpy import linalg as lg
from scipy import linalg as slg
from importlib import reload
import seaborn as snb
import matplotlib.pyplot as plt
import Utils.Functions 
from Utils.Functions import *
import pbdlib as pbd
from scipy.linalg import hankel
import joblib
import pybullet
from pbdlib import LQR
from pbdlib.utils import get_canonical
import pandapybullet as ppb
import torch
import time
import GPy, GPyOpt
# %load_ext autoreload
# %autoreload 2
plt.style.use("default")
plt.rcParams['font.size'] = 13
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams['lines.linewidth'] = 2.5
np.set_printoptions(precision=5, suppress=False)

# %% [markdown]
# ## Gather training data
# ### Define random sine reference
#
# Run a LQR using desired joint position and velocity to retrieve joint acceleration

# %%
dt = 1e-3
world_sim = ppb.WorldSim()
world_sim.setup_scene()
world_sim.load_table()
robot = world_sim.load_panda()

# %%
N=30000
T = N*dt
n_training = 5
n_testing = 0
n_tot = n_training + n_testing
joint_limits = robot.joint_limits.copy()
joint_limits[1,:] = [-deg2rad(35),deg2rad(35)]
# joint_limits[3,0] = -deg2rad(60)

# Trajectories specifications
specs = {'phi': {'low': -np.pi, 'high': np.pi}, 
         'A': {'low': -np.pi, 'high': np.pi},
         'f': {'low': 1/15, 'high': .4},
         'nb_parts': 100, 'margin': .2, 'safety': .9}

RobotSim, RobotReal = Robot(7, 7, dt, N, robot), Robot(7, 7, dt, N, robot)
RobotSim.drawTrajectories(nb_traj=n_tot, q_limits=joint_limits, specs=specs)
RobotReal.ref, RobotReal.desired_ddq = RobotSim.ref, RobotSim.desired_ddq
RobotReal.nb_traj = RobotSim.nb_traj

# %% [markdown]
# ## Gather training data using CTC + PD
#
# ### Tune PD controller

# %%
Kp = np.diag([70,90,70,70,80,170,150])
Ki = np.eye(7)*70.
Kd = np.diag([10,10,10,10,8,30,30])

robot.reset_q(max_iter=100)
robot.joints_free=True
# Out:
# joints are free now

# %% [markdown]
# ### Perturb robot dynamics

# %%
rnd.seed(3)
P_M, P_N = rnd.uniform(.92,1.08,size=(7)), rnd.uniform(.92,1.08,size=(7)) 
P_M, P_N = np.diag(P_M), np.diag(P_N)
F_v = 0.3*np.diag([3.,15.,2.,4.,.15,.2,.02]) # Viscous friction coefficient

# %%
def configuration_ctc(ddq, robot, P_M=np.eye(7), P_N=np.eye(7), **kwargs):
        
        if 'correction' in kwargs:
            correction = kwargs['correction']
        else: 
            correction = np.zeros([7])
        
        return np.dot(np.multiply(
            robot.M,P_M), ddq) + robot.b + (
            1-int(robot._gravity_compensation))*robot.g + P_N @ robot.damping@robot.dq + correction

# %% [markdown]
# ### Simulate using CTC + PD

# %%
log_control = np.empty(shape=[n_tot,7,N-1])
log_control_model = np.empty(shape=[n_tot,7,N-1])
log_q = np.empty(shape=[n_tot,7,N])
log_dq = np.empty(shape=[n_tot,7,N])
log_ddq = np.empty(shape=[n_tot,7,N])

for n in range(n_tot):
    log_error = []
    sum_error = np.zeros(7)
    log_q[n,:,0] = robot.q
    log_dq[n,:,0] = robot.dq
    log_ddq[n,:,0] = robot.ddq
    
    robot.default_q = RobotReal.ref[n,:7,0]
    robot.reset_q(max_iter=100)
    robot.joints_free=True
    for i in range(0, N-1):
        error_q = RobotReal.ref[n,:7,i] - robot.q
        error_dq = RobotReal.ref[n,7:,i] - robot.dq

    #   Computed Torque Control
        control_input = configuration_ctc(Kp @ error_q + Ki @ sum_error + Kd @ error_dq + RobotReal.desired_ddq[n,:,i],
                                          robot)
        # Add viscous friction
#         log_control_model[n,:,i] = control_input
        add_friction = F_v@robot.dq
        control_input -= add_friction
    #     PID Control + Feedforward term (with inverse dynamics)
#         control_input = robot.inverse_dynamics(pandaRobot.desired_ddq[n,:,i]) + Kp @ error_q + Ki @ sum_error + Kd @ error_dq
#         control_input = Kp @ error_q + Ki @ sum_error + Kd @ error_dq
    
        for j in range(7):
            if control_input[j] < robot.joint_torque_limits[j,0]:
                control_input[j] = robot.joint_torque_limits[j,0].copy()
            if control_input[j] > robot.joint_torque_limits[j,1]:
                control_input[j] = robot.joint_torque_limits[j,1].copy()

        robot.set_torque(control_input[:7]) # Simulation
#         robot.set_torque(control_input[:7] - add_friction) # Real robot, with friction
#         robot.set_torque(save_controls[n,:,i] - add_friction) # Real robot, with friction

        log_error.append(np.copy(error_q))
        log_q[n,:,i] = robot.q.copy()
        log_dq[n,:,i] = robot.dq.copy()
        log_ddq[n,:,i] = robot.ddq.copy()
        log_control[n,:,i] = np.copy(control_input)
    #     time.sleep(dt)
        sum_error += error_q*dt
        
log_q[:,:,N-1] = log_q[:,:,N-2]
log_dq[:,:,N-1] = log_dq[:,:,N-2]
# Out:
# joints are free now
# joints are free now
# joints are free now
# joints are free now
# joints are free now

# %% [markdown]
# ## Store data in state-space form

# %% [markdown]
# ### Data for bad model (simulated)

# %%
RobotSim.toStateSpace(log_q.copy(), log_dq.copy(), log_control.copy())

# %% [markdown]
# ### Data for true dynamics (observed)

# %%
RobotReal.toStateSpace(log_q.copy(), log_dq.copy(), log_control.copy())

# %% [markdown]
# ### Difference dynamics
# Here, the difference between the data simulated with the bad model with the suitable controller and the data gathered using the same controller but on the true system dynamics (which have synthetically been altered) is computed. <br><br>
# $$ \delta X = X_0 - X_{model}$$ <br><br>
# After that, the same algorithm leveraging HAVOK will be employed to retrieve a dynamical expression of the dynamical discrepancy.

# %%
delta_U = RobotReal.U - RobotSim.U
delta_X = RobotReal.X - RobotSim.X

# %% [markdown]
# ### Plot for bad model (but rightly calibrated controller)

# %%
traj = 0
plt.rcParams['font.size'] = 20
fig, ax = plt.subplots(7, 3, constrained_layout = True, figsize=(18,11))

for i in range(7):
    
    ax[i,0].plot(RobotSim.T, rad2deg(RobotSim.X[traj,i,:]), label='Joint '+str(i+1)+' pos.')
    ax[i,0].plot(RobotSim.T, rad2deg(RobotSim.ref[traj,i,:]), label='Pos. ref.')
    ax[i,1].plot(RobotSim.T, rad2deg(RobotSim.X[traj,i+7,:]), label='Joint '+str(i+1)+' vel.')
    ax[i,1].plot(RobotSim.T, rad2deg(RobotSim.ref[traj,i+7,:]), label='Vel. ref.')
    ax[i,2].plot(RobotSim.T[:len(RobotSim.T)-1], RobotSim.U[traj,i,:], label='Joint '+str(i+1)+' torque')
    ax[i,0].set_ylabel('Position [deg]'), ax[i,1].set_ylabel('Velocity [deg/s]'), ax[i,2].set_ylabel('Torque [Nm]')
    ax[i,0].legend(), ax[i,1].legend(), ax[i,2].legend()
    
ax[6,0].set_xlabel('Time [s]'), ax[6,1].set_xlabel('Time [s]')
# Out:
# (Text(0.5, 0, 'Time [s]'), Text(0.5, 0, 'Time [s]'))

# %% [markdown]
# ### Plot for true dynamics with wrong controller

# %%
traj = 0
plt.rcParams['font.size'] = 20
fig, ax = plt.subplots(7, 3, constrained_layout = True, figsize=(18,11))

for i in range(7):
    
    ax[i,0].plot(RobotReal.T, rad2deg(RobotReal.X[traj,i,:]), label='Joint '+str(i+1)+' pos.')
    ax[i,0].plot(RobotReal.T, rad2deg(RobotReal.ref[traj,i,:]), label='Pos. ref.')
    ax[i,1].plot(RobotReal.T, rad2deg(RobotReal.X[traj,i+7,:]), label='Joint '+str(i+1)+' vel.')
    ax[i,1].plot(RobotReal.T, rad2deg(RobotReal.ref[traj,i+7,:]), label='Vel. ref.')
    ax[i,2].plot(RobotReal.T[:len(RobotReal.T)-1], RobotReal.U[traj,i,:], label='Joint '+str(i+1)+' torque')
    ax[i,0].set_ylabel('Position [deg]'), ax[i,1].set_ylabel('Velocity [deg/s]'), ax[i,2].set_ylabel('Torque [Nm]')
    ax[i,0].legend(), ax[i,1].legend(), ax[i,2].legend()
    
ax[6,0].set_xlabel('Time [s]'), ax[6,1].set_xlabel('Time [s]')
# Out:
# (Text(0.5, 0, 'Time [s]'), Text(0.5, 0, 'Time [s]'))

# %% [markdown]
# ### Plot residual dynamics

# %%
traj = 0
plt.rcParams['font.size'] = 20
fig, ax = plt.subplots(7, 3, constrained_layout = True, figsize=(18,11))

for i in range(7):
    
    ax[i,0].plot(RobotReal.T, rad2deg(delta_X[traj,i,:]), label='Joint '+str(i+1)+' pos.')
    ax[i,1].plot(RobotReal.T, rad2deg(delta_X[traj,i+7,:]), label='Joint '+str(i+1)+' vel.')
    ax[i,2].plot(RobotReal.T[:-1], delta_U[traj,i,:], label='Joint '+str(i+1)+' torque')
    ax[i,0].set_ylabel('Position [deg]'), ax[i,1].set_ylabel('Velocity [deg/s]'), ax[i,2].set_ylabel('Torque [Nm]')
    ax[i,0].legend(), ax[i,1].legend(), ax[i,2].legend()
    
ax[6,0].set_xlabel('Time [s]'), ax[6,1].set_xlabel('Time [s]')
# Out:
# (Text(0.5, 0, 'Time [s]'), Text(0.5, 0, 'Time [s]'))

# %%
nb_train, nb_test = 22500, 7500

# %% [markdown]
# ## Model training

# %% [markdown]
# ### Using *GPyOpt*

# %%
nb_train, nb_test = 22500, 7500

traj_ratio = .05
n_low, n_high = 200, 350
d_low, d_high = 1, np.int((1-traj_ratio)/n_high*nb_train)
ref_zeros = np.zeros([14,nb_train-1])

domain = [
    {'name': 'dimension', 'type': 'discrete', 'domain': np.arange(14,30,1)},
    {'name': 'nb_traj', 'type': 'discrete', 'domain': np.arange(n_low,n_high,1)},
    {'name': 'nb_delays', 'type': 'discrete', 'domain': np.arange(d_low,d_high,1)}
]

print('delay max : ',np.int((1-traj_ratio)/n_high*nb_train))
print('points min : ',nb_train- d_high*n_high)

loss_prediction_train = np.empty(shape=[n_training])
loss_prediction_test = np.empty(shape=[n_training])
loss_corr = np.empty(shape=[n_training])
loss_LQR = np.empty(shape=[n_training])

N = RobotReal.X.shape[2]

def loss(space):
    # Model parameters
    n_params = space.shape[0] # If train by batch
    s = np.int(space[0,0])
    n = np.int(space[0,1])
    d = np.int(space[0,2])
#     nx = np.int(space[0,0])
#     nu = np.int(space[0,1])
#     d = np.int(space[0,2])
    
    timing = np.empty([2,n_training])
    
    for fold in range(n_training):
        timing[0,fold] = time.time() # HAVOK computation time
        
        # TRAINING #####################################################
        model = HAVOK(delta_X[fold,:,:nb_train], # state-wise difference
                      torch.cat((RobotSim.X[fold,:,:nb_train-1], # Exogenous inputs vector
                                 RobotSim.U[fold,:,:nb_train-1],
                                 delta_U[fold,:,:nb_train-1]),axis=0), 
                      mode='ELQR form',
                      nb_U=28, # All inputs
                      nb_U_ex=21 # Exogenous inputs
                     )
#         model = HAVOK(pandaRobot.X[fold,:,:nb_train], # state-wise difference
#                       pandaRobot.U[fold,:,:nb_train-1],
#                       mode='prediction'
#                      )
        model.HANKEL(n, d)
        model.SVD(s)
        model.LS(s,rcond=0)
        
        timing[0,fold] = time.time() - timing[0,fold]  
        timing[1,fold] = time.time() # Simulation time computation
        # TESTING ######################################################
        model.Simulate(X0=delta_X[fold,:,0],
                       horizon=nb_train,
                       U=torch.cat((RobotSim.X[fold,:,:nb_train],
                                    RobotSim.U[fold,:,:nb_train],
                                    delta_U[fold,:,:nb_train]),axis=0).to(torch.float)
                      )
        
        loss_prediction_train[fold] = model.RMSE(X_pred=model.X_prediction,
                                                 X_true=delta_X[fold,:,:nb_train])
        model.Simulate(X0=delta_X[fold,:,nb_train],
                       horizon=nb_test,
                       U=torch.cat((RobotSim.X[fold,:,nb_train:-1],
                                    RobotSim.U[fold,:,nb_train:],
                                    delta_U[fold,:,nb_train:]),axis=0).to(torch.float)
                      )
        loss_prediction_test[fold] = model.RMSE(X_pred=model.X_prediction,
                                                X_true=delta_X[fold,:,nb_train:])
        
        timing[1,fold] = time.time() - timing[1,fold]  
        
    loss_pred_train_sum = np.mean(loss_prediction_train)
    loss_pred_test_sum = np.mean(loss_prediction_test)
    loss = loss_pred_train_sum + loss_pred_test_sum
    avg_time = [timing[0,:].sum()/n_training,timing[1,:].sum()/n_training]
    
    if np.isnan(loss) or np.isinf(loss):
        loss = 1e10
        
#     print('Total loss : '+str(loss)+' Loss sim. : '+str(loss_traj_sum)+
#           ', s :'+str(s)+', n :'+str(n)+', d : '+str(d))
    print('Total loss : '+str(loss)+' Loss train. : '+str(loss_pred_train_sum)+
          ' Loss test. : '+str(loss_pred_test_sum)+
          ', r :'+str(s)+', n :'+str(n)+', d : '+str(d))
    print('Avg computation time for HAVOK : '+str(avg_time[0])+' [s], for sim. : '+str(avg_time[1])+' [s]')
    
    return loss

max_iter = 100000
batch_size = 6
num_cores = 6

opt = GPyOpt.methods.BayesianOptimization(f = loss,            # function to optimize       
                                          domain = domain,         # box-constraints of the problem
                                          acquisition_type ='LCB',       # LCB acquisition
                                          acquisition_weight = 0.2)     # Exploration exploitation
 

opt.run_optimization(max_iter)
# Out:
# delay max :  61
# points min :  1150
# Total loss : 563.0792938232422 Loss train. : 233.16321411132813 Loss test. : 329.91607971191405, r :20, n :329, d : 34
# Avg computation time for HAVOK : 1.92224440574646 [s], for sim. : 1.7560765266418457 [s]
# Total loss : 374.71385803222654 Loss train. : 120.02420043945312 Loss test. : 254.68965759277344, r :16, n :290, d : 30
# Avg computation time for HAVOK : 1.9166921138763429 [s], for sim. : 1.9983591556549072 [s]
# Total loss : 7246.537866210937 Loss train. : 6851.475851440429 Loss test. : 395.0620147705078, r :16, n :269, d : 43
# Avg computation time for HAVOK : 1.7257864952087403 [s], for sim. : 2.376769542694092 [s]
# Total loss : 127987674299.60368 Loss train. : 127987642254.88481 Loss test. : 32044.71887817383, r :29, n :304, d : 25
# Avg computation time for HAVOK : 2.959316778182983 [s], for sim. : 2.460009145736694 [s]
# Total loss : 6294.458764648438 Loss train. : 3238.5027587890627 Loss test. : 3055.956005859375, r :26, n :310, d : 60
# Avg computation time for HAVOK : 0.9390883922576905 [s], for sim. : 2.029876470565796 [s]
# Total loss : 374.57032623291013 Loss train. : 119.9413833618164 Loss test. : 254.62894287109376, r :16, n :290, d : 30
# Avg computation time for HAVOK : 1.7034523963928223 [s], for sim. : 1.7082330703735351 [s]
# Total loss : 6292.965478515625 Loss train. : 3237.3894775390627 Loss test. : 3055.5760009765627, r :26, n :310, d : 60
# Avg computation time for HAVOK : 0.7619624137878418 [s], for sim. : 1.7508260250091552 [s]
# Total loss : 6990.397552490234 Loss train. : 6596.652209472656 Loss test. : 393.74534301757814, r :16, n :269, d : 43
# Avg computation time for HAVOK : 1.5373059272766114 [s], for sim. : 2.2846054553985597 [s]
# Total loss : 563.4455993652343 Loss train. : 233.49405517578126 Loss test. : 329.9515441894531, r :20, n :329, d : 34
# Avg computation time for HAVOK : 2.7085077285766603 [s], for sim. : 2.472324085235596 [s]
# Total loss : 500.9871551513672 Loss train. : 198.23240356445314 Loss test. : 302.75475158691404, r :16, n :290, d : 31
# Avg computation time for HAVOK : 2.417351579666138 [s], for sim. : 2.328503227233887 [s]
# Total loss : 505.8795394897461 Loss train. : 173.74742279052734 Loss test. : 332.1321166992187, r :14, n :283, d : 30
# Avg computation time for HAVOK : 1.654392147064209 [s], for sim. : 1.7951030731201172 [s]
# Total loss : 8679.090942382812 Loss train. : 8102.802145385742 Loss test. : 576.2887969970703, r :17, n :335, d : 38
# Avg computation time for HAVOK : 1.6945693969726563 [s], for sim. : 1.8506613731384278 [s]
# Total loss : 2611789.397090149 Loss train. : 2610156.1727981567 Loss test. : 1633.2242919921875, r :19, n :336, d : 31
# Avg computation time for HAVOK : 2.7396831035614015 [s], for sim. : 2.9638914585113527 [s]
# Total loss : 5977.540576171875 Loss train. : 2551.616015625 Loss test. : 3425.924560546875, r :19, n :319, d : 60
# Avg computation time for HAVOK : 0.711890459060669 [s], for sim. : 2.633173418045044 [s]
# Total loss : 4443.243135070801 Loss train. : 3997.740696716309 Loss test. : 445.5024383544922, r :14, n :288, d : 30
# Avg computation time for HAVOK : 2.366096019744873 [s], for sim. : 2.467807388305664 [s]
# Total loss : 389.9070480346679 Loss train. : 126.57954559326171 Loss test. : 263.32750244140624, r :22, n :276, d : 33
# Avg computation time for HAVOK : 1.7399491310119628 [s], for sim. : 1.9701337337493896 [s]
# Total loss : 38349.92756652832 Loss train. : 30639.35805053711 Loss test. : 7710.569515991211, r :14, n :330, d : 35
# Avg computation time for HAVOK : 1.7789216995239259 [s], for sim. : 1.7871348857879639 [s]
# Total loss : 3245.3808837890624 Loss train. : 1371.5631103515625 Loss test. : 1873.8177734375, r :14, n :306, d : 60
# Avg computation time for HAVOK : 0.7424156665802002 [s], for sim. : 1.8666131019592285 [s]
# Total loss : 396.12010192871094 Loss train. : 153.5078125 Loss test. : 242.61228942871094, r :19, n :284, d : 30
# Avg computation time for HAVOK : 2.3889188289642336 [s], for sim. : 2.409011125564575 [s]
# Total loss : 1497.5338256835937 Loss train. : 1055.8066375732421 Loss test. : 441.72718811035156, r :16, n :266, d : 28
# Avg computation time for HAVOK : 2.275952959060669 [s], for sim. : 2.55887975692749 [s]
# Total loss : 2116.149334716797 Loss train. : 1737.4646911621094 Loss test. : 378.6846435546875, r :24, n :259, d : 40
# Avg computation time for HAVOK : 1.5921428680419922 [s], for sim. : 1.9960787773132325 [s]
# Total loss : 730.5253845214843 Loss train. : 308.9051879882812 Loss test. : 421.6201965332031, r :24, n :333, d : 40
# Avg computation time for HAVOK : 1.6458012104034423 [s], for sim. : 1.7365682125091553 [s]
# Total loss : 5774624.872814941 Loss train. : 5765939.79555664 Loss test. : 8685.077258300782, r :25, n :264, d : 58
# Avg computation time for HAVOK : 0.8985196590423584 [s], for sim. : 1.8091023921966554 [s]
# Total loss : 699.0489196777344 Loss train. : 265.82903442382815 Loss test. : 433.2198852539062, r :16, n :252, d : 54
# Avg computation time for HAVOK : 1.2560411453247071 [s], for sim. : 2.3329770088195803 [s]
# Total loss : 428778070.79532164 Loss train. : 428772738.4658966 Loss test. : 5332.329425048828, r :29, n :248, d : 57
# Avg computation time for HAVOK : 1.221740961074829 [s], for sim. : 2.4141687870025637 [s]
# Total loss : 1768.5145568847656 Loss train. : 1381.9943237304688 Loss test. : 386.5202331542969, r :20, n :240, d : 42
# Avg computation time for HAVOK : 1.548671293258667 [s], for sim. : 2.485362195968628 [s]
# Total loss : 689.9366851806641 Loss train. : 274.2211608886719 Loss test. : 415.7155242919922, r :16, n :232, d : 56
# Avg computation time for HAVOK : 0.9425826072692871 [s], for sim. : 2.1757914066314696 [s]
# Total loss : 201178.10221862793 Loss train. : 200828.60911865236 Loss test. : 349.49309997558595, r :29, n :227, d : 49
# Avg computation time for HAVOK : 0.996137285232544 [s], for sim. : 1.7666604042053222 [s]
# Total loss : 63967.21142883301 Loss train. : 63625.85000305176 Loss test. : 341.36142578125, r :15, n :222, d : 42
# Avg computation time for HAVOK : 1.024674654006958 [s], for sim. : 1.7389511108398437 [s]
# Total loss : 952.1777435302733 Loss train. : 366.6817901611328 Loss test. : 585.4959533691406, r :20, n :213, d : 56
# Avg computation time for HAVOK : 1.024463701248169 [s], for sim. : 2.3382605075836183 [s]
# Total loss : 445.83485717773436 Loss train. : 139.67579650878906 Loss test. : 306.1590606689453, r :28, n :209, d : 41
# Avg computation time for HAVOK : 1.4347633361816405 [s], for sim. : 2.4722807884216307 [s]
# Total loss : 893.6240173339843 Loss train. : 510.16762084960936 Loss test. : 383.456396484375, r :29, n :224, d : 30
# Avg computation time for HAVOK : 1.7863352298736572 [s], for sim. : 2.3971936225891115 [s]
# Total loss : 468.8307800292969 Loss train. : 220.42162170410157 Loss test. : 248.4091583251953, r :18, n :210, d : 26
# Avg computation time for HAVOK : 1.4973013877868653 [s], for sim. : 2.205208921432495 [s]
# Total loss : 459.7716461181641 Loss train. : 174.30731201171875 Loss test. : 285.46433410644534, r :14, n :201, d : 42
# Avg computation time for HAVOK : 0.871470594406128 [s], for sim. : 1.7774499893188476 [s]
# Total loss : 2439.122839355469 Loss train. : 1510.5920166015626 Loss test. : 928.5308227539062, r :14, n :229, d : 22
# Avg computation time for HAVOK : 1.3667520999908447 [s], for sim. : 1.7245936393737793 [s]
# Total loss : 5269.131610107422 Loss train. : 4973.773403930664 Loss test. : 295.3582061767578, r :25, n :221, d : 11
# Avg computation time for HAVOK : 1.7070441722869873 [s], for sim. : 2.0201988220214844 [s]
# Total loss : 27282345.43281555 Loss train. : 27281582.43494568 Loss test. : 762.9978698730469, r :28, n :239, d : 17
# Avg computation time for HAVOK : 2.3010488986968993 [s], for sim. : 2.432616424560547 [s]
# Total loss : 327088159.79801023 Loss train. : 327081012.44876707 Loss test. : 7147.3492431640625, r :16, n :235, d : 4
# Avg computation time for HAVOK : 2.4307923316955566 [s], for sim. : 2.2568424701690675 [s]
# Total loss : 9098552534.444365 Loss train. : 9098520259.760893 Loss test. : 32274.683471679688, r :14, n :246, d : 20
# Avg computation time for HAVOK : 1.5983062744140626 [s], for sim. : 1.736272430419922 [s]
# Total loss : 10000000000.0 Loss train. : inf Loss test. : 7753775.76640625, r :29, n :234, d : 2
# Avg computation time for HAVOK : 1.9472206592559815 [s], for sim. : 1.8407087326049805 [s]
# Total loss : 7896.56206665039 Loss train. : 7046.767599487304 Loss test. : 849.794467163086, r :14, n :221, d : 10
# Avg computation time for HAVOK : 2.0549094676971436 [s], for sim. : 2.352922296524048 [s]
# Total loss : 1212.94451751709 Loss train. : 990.925212097168 Loss test. : 222.01930541992186, r :24, n :227, d : 19
# Avg computation time for HAVOK : 2.230985498428345 [s], for sim. : 2.574501466751099 [s]
# Total loss : 2091660426365.6707 Loss train. : 2091660397964.8542 Loss test. : 28400.816525268554, r :29, n :238, d : 30
# Avg computation time for HAVOK : 2.204207992553711 [s], for sim. : 2.78076548576355 [s]
# Total loss : 8950.992907714843 Loss train. : 8624.319815063476 Loss test. : 326.6730926513672, r :27, n :239, d : 12
# Avg computation time for HAVOK : 1.981908369064331 [s], for sim. : 2.287883472442627 [s]
# Total loss : 938.6551193237306 Loss train. : 631.969142150879 Loss test. : 306.68597717285155, r :28, n :219, d : 29
# Avg computation time for HAVOK : 1.5549493789672852 [s], for sim. : 2.207614612579346 [s]
# Total loss : 1040.1928802490233 Loss train. : 602.1163299560546 Loss test. : 438.07655029296876, r :17, n :240, d : 46
# Avg computation time for HAVOK : 1.6049805641174317 [s], for sim. : 2.7175951957702638 [s]
# Total loss : 304.04740600585933 Loss train. : 135.44017333984374 Loss test. : 168.60723266601562, r :19, n :226, d : 15
# Avg computation time for HAVOK : 2.0530269622802733 [s], for sim. : 2.357126760482788 [s]
# Total loss : 689.6221740722656 Loss train. : 299.7660308837891 Loss test. : 389.85614318847655, r :22, n :223, d : 51
# Avg computation time for HAVOK : 0.9618271827697754 [s], for sim. : 1.862144899368286 [s]
# Total loss : 216314307.27278137 Loss train. : 216306666.15915528 Loss test. : 7641.113626098633, r :29, n :221, d : 33
# Avg computation time for HAVOK : 1.2075716495513915 [s], for sim. : 1.7922096729278565 [s]
# Total loss : 530.2866821289062 Loss train. : 298.2423370361328 Loss test. : 232.04434509277343, r :25, n :221, d : 21
# Avg computation time for HAVOK : 1.3611628532409668 [s], for sim. : 1.970432424545288 [s]
# Total loss : 6037.513122558594 Loss train. : 5658.93742980957 Loss test. : 378.57569274902346, r :29, n :237, d : 14
# Avg computation time for HAVOK : 2.5729291915893553 [s], for sim. : 2.4689353466033936 [s]
# Total loss : 646191261.8572448 Loss train. : 646190417.4295166 Loss test. : 844.4277282714844, r :26, n :242, d : 15
# Avg computation time for HAVOK : 2.3496391773223877 [s], for sim. : 2.395499563217163 [s]
# Total loss : 1109146.8501464843 Loss train. : 1105932.7306427 Loss test. : 3214.11950378418, r :21, n :259, d : 48
# Avg computation time for HAVOK : 1.3485946178436279 [s], for sim. : 2.0073952674865723 [s]
# Total loss : 3620008.288430786 Loss train. : 3619723.1625427245 Loss test. : 285.1258880615234, r :25, n :238, d : 15
# Avg computation time for HAVOK : 1.647505283355713 [s], for sim. : 1.7755557537078857 [s]
# Total loss : 2912.101490783691 Loss train. : 2487.077470397949 Loss test. : 425.0240203857422, r :19, n :243, d : 44
# Avg computation time for HAVOK : 1.1893319606781005 [s], for sim. : 2.0196063041687013 [s]
# Total loss : 282126.1380508423 Loss train. : 281778.8756820679 Loss test. : 347.2623687744141, r :19, n :236, d : 45
# Avg computation time for HAVOK : 1.4329700946807862 [s], for sim. : 2.3624239921569825 [s]
# Total loss : 1444.2031616210938 Loss train. : 587.0727813720703 Loss test. : 857.1303802490235, r :14, n :222, d : 23
# Avg computation time for HAVOK : 1.7628864765167236 [s], for sim. : 2.3952009677886963 [s]
# Total loss : 9357.10094909668 Loss train. : 8749.410342407227 Loss test. : 607.6906066894531, r :23, n :266, d : 40
# Avg computation time for HAVOK : 1.5388945102691651 [s], for sim. : 1.9812150955200196 [s]
# Total loss : 389.0342956542969 Loss train. : 123.00399475097656 Loss test. : 266.0303009033203, r :16, n :239, d : 42
# Avg computation time for HAVOK : 1.0837581157684326 [s], for sim. : 1.7345678329467773 [s]
# Total loss : 113765991.51539002 Loss train. : 113762972.77426453 Loss test. : 3018.7411254882813, r :27, n :229, d : 56
# Avg computation time for HAVOK : 0.9003930568695069 [s], for sim. : 1.7529329299926757 [s]
# Total loss : 412.606005859375 Loss train. : 154.0860168457031 Loss test. : 258.5199890136719, r :18, n :211, d : 45
# Avg computation time for HAVOK : 1.2610223293304443 [s], for sim. : 2.3421710968017577 [s]
# Total loss : 1091.56064453125 Loss train. : 809.807992553711 Loss test. : 281.7526519775391, r :29, n :222, d : 28
# Avg computation time for HAVOK : 1.7898244857788086 [s], for sim. : 2.493953514099121 [s]
# Total loss : 19842.746018981932 Loss train. : 19507.414100646973 Loss test. : 335.33191833496096, r :23, n :221, d : 30
# Avg computation time for HAVOK : 1.7892086982727051 [s], for sim. : 2.496735429763794 [s]
# Total loss : 936.3899520874024 Loss train. : 217.99592132568358 Loss test. : 718.3940307617188, r :14, n :249, d : 14
# Avg computation time for HAVOK : 1.9288442134857178 [s], for sim. : 2.2339351654052733 [s]
# Total loss : 1075.779489135742 Loss train. : 619.9079833984375 Loss test. : 455.8715057373047, r :29, n :219, d : 52
# Avg computation time for HAVOK : 0.9656191349029541 [s], for sim. : 1.9773567199707032 [s]
# Total loss : 1398231.143444824 Loss train. : 1393740.4626220702 Loss test. : 4490.680822753906, r :22, n :254, d : 60
# Avg computation time for HAVOK : 0.8100339889526367 [s], for sim. : 1.771200132369995 [s]
# Total loss : 803.6420837402343 Loss train. : 359.80902709960935 Loss test. : 443.833056640625, r :16, n :262, d : 39
# Avg computation time for HAVOK : 1.7328672409057617 [s], for sim. : 2.411966896057129 [s]
# Total loss : 219969.82041320798 Loss train. : 219099.0785644531 Loss test. : 870.7418487548828, r :21, n :204, d : 36
# Avg computation time for HAVOK : 1.3961804389953614 [s], for sim. : 2.4512747287750245 [s]
# Total loss : 536.331689453125 Loss train. : 232.38014221191406 Loss test. : 303.95154724121096, r :24, n :203, d : 47
# Avg computation time for HAVOK : 1.3595352649688721 [s], for sim. : 2.793458890914917 [s]
# Total loss : 2550.4442749023438 Loss train. : 1063.81611328125 Loss test. : 1486.6281616210938, r :19, n :312, d : 54
# Avg computation time for HAVOK : 1.291688823699951 [s], for sim. : 1.9157070159912108 [s]
# Total loss : 1348.0148391723633 Loss train. : 838.6605209350586 Loss test. : 509.3543182373047, r :14, n :272, d : 34
# Avg computation time for HAVOK : 1.450226354598999 [s], for sim. : 1.7552974700927735 [s]
# Total loss : 10000000000.0 Loss train. : inf Loss test. : 141095474696507.06, r :14, n :226, d : 1
# Avg computation time for HAVOK : 1.6390254497528076 [s], for sim. : 1.747342872619629 [s]
# Total loss : 927.4057418823243 Loss train. : 668.0411483764649 Loss test. : 259.3645935058594, r :29, n :240, d : 15
# Avg computation time for HAVOK : 2.340772247314453 [s], for sim. : 2.5044186115264893 [s]
# Total loss : 1180255.9989120483 Loss train. : 1180042.7491592406 Loss test. : 213.2497528076172, r :26, n :225, d : 15
# Avg computation time for HAVOK : 2.344345712661743 [s], for sim. : 3.2676703453063967 [s]
# Total loss : 3000340380.790222 Loss train. : 3000337575.4746733 Loss test. : 2805.315548706055, r :21, n :223, d : 19
# Avg computation time for HAVOK : 1.6918211460113526 [s], for sim. : 2.0459976196289062 [s]
# Total loss : 1019.5265106201172 Loss train. : 367.7310546875 Loss test. : 651.7954559326172, r :14, n :261, d : 57
# Avg computation time for HAVOK : 0.8523213863372803 [s], for sim. : 1.7378557682037354 [s]
# Total loss : 1112.5859146118164 Loss train. : 393.4092544555664 Loss test. : 719.17666015625, r :14, n :229, d : 16
# Avg computation time for HAVOK : 1.4377555847167969 [s], for sim. : 1.7485167980194092 [s]
# Total loss : 17887.111097717287 Loss train. : 17182.950221252442 Loss test. : 704.1608764648438, r :20, n :240, d : 44
# Avg computation time for HAVOK : 1.5149497985839844 [s], for sim. : 2.3827324867248536 [s]
# Total loss : 853767317.9153075 Loss train. : 853765820.6384552 Loss test. : 1497.2768524169921, r :21, n :214, d : 5
# Avg computation time for HAVOK : 2.058910274505615 [s], for sim. : 2.380238437652588 [s]
# Total loss : 1702.8366210937502 Loss train. : 856.2032348632813 Loss test. : 846.6333862304688, r :18, n :325, d : 48
# Avg computation time for HAVOK : 1.6331315517425538 [s], for sim. : 2.3051493644714354 [s]
# Total loss : 2959.7844970703127 Loss train. : 1284.129052734375 Loss test. : 1675.6554443359375, r :27, n :321, d : 53
# Avg computation time for HAVOK : 1.1403539657592774 [s], for sim. : 1.8027938842773437 [s]
# Total loss : 409.07173309326174 Loss train. : 149.3121566772461 Loss test. : 259.75957641601565, r :17, n :275, d : 23
# Avg computation time for HAVOK : 1.8031790256500244 [s], for sim. : 1.8068763732910156 [s]
# Total loss : 4139.882797241211 Loss train. : 3436.4881439208984 Loss test. : 703.3946533203125, r :14, n :204, d : 54
# Avg computation time for HAVOK : 1.0418156147003175 [s], for sim. : 2.3271828174591063 [s]
# Total loss : 3450520.446118164 Loss train. : 3405055.237060547 Loss test. : 45465.20905761719, r :24, n :332, d : 54
# Avg computation time for HAVOK : 1.6734758377075196 [s], for sim. : 2.6730273246765135 [s]
# Total loss : 4857.848023986816 Loss train. : 4574.841914367676 Loss test. : 283.0061096191406, r :21, n :207, d : 15
# Avg computation time for HAVOK : 1.9445698738098145 [s], for sim. : 2.5308487892150877 [s]
# Total loss : 457.82130279541013 Loss train. : 175.49571380615234 Loss test. : 282.3255889892578, r :17, n :200, d : 24
# Avg computation time for HAVOK : 1.0649534225463868 [s], for sim. : 1.8071767807006835 [s]
# Total loss : 273.96264343261714 Loss train. : 93.12336120605468 Loss test. : 180.8392822265625, r :26, n :203, d : 25
# Avg computation time for HAVOK : 1.1773758411407471 [s], for sim. : 1.845330810546875 [s]
# Total loss : 826.9743362426758 Loss train. : 393.23103485107424 Loss test. : 433.74330139160156, r :16, n :281, d : 43
# Avg computation time for HAVOK : 1.4969480991363526 [s], for sim. : 2.0678101539611817 [s]
# Total loss : 2.2311060427891242e+17 Loss train. : 2.2311060427778355e+17 Loss test. : 1128851.891796875, r :18, n :273, d : 54
# Avg computation time for HAVOK : 1.3605647087097168 [s], for sim. : 2.455131006240845 [s]
# Total loss : 3715512592157.824 Loss train. : 3715512070421.6143 Loss test. : 521736.2101623535, r :29, n :260, d : 59
# Avg computation time for HAVOK : 1.319181537628174 [s], for sim. : 2.6851730823516844 [s]
# Total loss : 608.3034423828125 Loss train. : 157.6552276611328 Loss test. : 450.64821472167966, r :15, n :282, d : 39
# Avg computation time for HAVOK : 2.032515621185303 [s], for sim. : 2.4216519832611083 [s]
# Total loss : 1502850.727471924 Loss train. : 1487714.0528564453 Loss test. : 15136.674615478516, r :14, n :257, d : 59
# Avg computation time for HAVOK : 1.0130278587341308 [s], for sim. : 2.1248195648193358 [s]
# Total loss : 108223970.08561401 Loss train. : 108217638.04325561 Loss test. : 6332.0423583984375, r :23, n :260, d : 58
# Avg computation time for HAVOK : 0.8984965801239013 [s], for sim. : 1.7971577644348145 [s]
# Total loss : 4035857157.6870804 Loss train. : 4035847484.397624 Loss test. : 9673.289456176757, r :15, n :269, d : 40
# Avg computation time for HAVOK : 1.842339563369751 [s], for sim. : 2.5108947277069094 [s]
# Total loss : 679.5439392089844 Loss train. : 257.76267700195314 Loss test. : 421.78126220703126, r :14, n :258, d : 52
# Avg computation time for HAVOK : 1.4064748764038086 [s], for sim. : 2.5865227699279787 [s]
# Total loss : 656.1136917114259 Loss train. : 315.65298614501955 Loss test. : 340.46070556640626, r :17, n :265, d : 42
# Avg computation time for HAVOK : 1.7347837924957275 [s], for sim. : 2.517512321472168 [s]
# Total loss : 2698.5429351806642 Loss train. : 1921.481253051758 Loss test. : 777.0616821289062, r :23, n :253, d : 48
# Avg computation time for HAVOK : 1.301305627822876 [s], for sim. : 2.1275027275085447 [s]
# Total loss : 673.1309478759765 Loss train. : 233.21265563964843 Loss test. : 439.9182922363281, r :17, n :276, d : 39
# Avg computation time for HAVOK : 1.5015055179595946 [s], for sim. : 1.8900943756103517 [s]
# Total loss : 931.2216247558594 Loss train. : 311.8633636474609 Loss test. : 619.3582611083984, r :17, n :286, d : 42
# Avg computation time for HAVOK : 1.819176721572876 [s], for sim. : 2.6020153999328612 [s]
# Total loss : 6481964783.252917 Loss train. : 6481914795.65871 Loss test. : 49987.59420776367, r :23, n :243, d : 59
# Avg computation time for HAVOK : 1.4282447814941406 [s], for sim. : 2.8213061332702636 [s]
# Total loss : 3384.6744689941406 Loss train. : 1620.411639404297 Loss test. : 1764.2628295898437, r :27, n :263, d : 60
# Avg computation time for HAVOK : 1.5278755664825439 [s], for sim. : 2.666687488555908 [s]
# Total loss : 1344.100518798828 Loss train. : 552.6425964355469 Loss test. : 791.4579223632812, r :28, n :261, d : 55
# Avg computation time for HAVOK : 1.2029211521148682 [s], for sim. : 2.0288979530334474 [s]
# Total loss : 1232.48936920166 Loss train. : 153.78447418212892 Loss test. : 1078.7048950195312, r :15, n :254, d : 38
# Avg computation time for HAVOK : 1.2544699668884278 [s], for sim. : 1.7196061611175537 [s]
# Total loss : 404136827.34994054 Loss train. : 404129678.89688265 Loss test. : 7148.4530578613285, r :27, n :267, d : 31
# Avg computation time for HAVOK : 2.0527172088623047 [s], for sim. : 2.827677345275879 [s]
# Total loss : 1837.200112915039 Loss train. : 1477.3568603515625 Loss test. : 359.84325256347654, r :19, n :232, d : 32
# Avg computation time for HAVOK : 1.9490599632263184 [s], for sim. : 3.0712092876434327 [s]
# Total loss : 547.049104309082 Loss train. : 292.3071792602539 Loss test. : 254.74192504882814, r :21, n :254, d : 24
# Avg computation time for HAVOK : 2.2846411228179933 [s], for sim. : 2.6985049724578856 [s]
# Total loss : 10000000000.0 Loss train. : nan Loss test. : 9991048815322.037, r :24, n :225, d : 1
# Avg computation time for HAVOK : 2.0886589527130126 [s], for sim. : 2.1906574249267576 [s]
# Total loss : 319.4216888427734 Loss train. : 106.17521057128906 Loss test. : 213.24647827148436, r :20, n :243, d : 28
# Avg computation time for HAVOK : 1.5196028232574463 [s], for sim. : 1.9002800941467286 [s]
# Total loss : 1061.7862075805665 Loss train. : 752.2886154174805 Loss test. : 309.4975921630859, r :14, n :274, d : 29
# Avg computation time for HAVOK : 2.7160865306854247 [s], for sim. : 2.542447900772095 [s]
# Total loss : 1331.7747390747072 Loss train. : 107.57137908935547 Loss test. : 1224.2033599853517, r :14, n :284, d : 21
# Avg computation time for HAVOK : 3.164095067977905 [s], for sim. : 2.774737310409546 [s]
# Total loss : 414197.40906982427 Loss train. : 411858.25723876955 Loss test. : 2339.1518310546876, r :26, n :262, d : 58
# Avg computation time for HAVOK : 1.285470962524414 [s], for sim. : 2.5599506855010987 [s]
# Total loss : 543.7290542602539 Loss train. : 253.96730194091796 Loss test. : 289.7617523193359, r :27, n :280, d : 23
# Avg computation time for HAVOK : 2.0037254333496093 [s], for sim. : 1.760594367980957 [s]
# Total loss : 315.2875411987305 Loss train. : 124.52861785888672 Loss test. : 190.75892333984376, r :23, n :265, d : 18
# Avg computation time for HAVOK : 2.1271379947662354 [s], for sim. : 1.9707527160644531 [s]
# Total loss : 818.3113555908203 Loss train. : 334.1814239501953 Loss test. : 484.129931640625, r :16, n :259, d : 57
# Avg computation time for HAVOK : 1.1970611572265626 [s], for sim. : 2.5662439346313475 [s]
# Total loss : 18590.226998901366 Loss train. : 16479.121383666992 Loss test. : 2111.105615234375, r :14, n :260, d : 18
# Avg computation time for HAVOK : 2.453334093093872 [s], for sim. : 2.4467705726623534 [s]
# Total loss : 313064.31849365233 Loss train. : 312157.9804534912 Loss test. : 906.3380401611328, r :17, n :282, d : 41
# Avg computation time for HAVOK : 1.9462451457977294 [s], for sim. : 2.433295726776123 [s]
# Total loss : 10000000000.0 Loss train. : inf Loss test. : 11934832.130169678, r :14, n :283, d : 42
# Avg computation time for HAVOK : 1.348253107070923 [s], for sim. : 1.8175603866577148 [s]
# Total loss : 4070.0622619628907 Loss train. : 3566.5024536132814 Loss test. : 503.5598083496094, r :19, n :296, d : 41
# Avg computation time for HAVOK : 1.4762943267822266 [s], for sim. : 1.827927589416504 [s]
# Total loss : 1990.2263610839843 Loss train. : 1579.371353149414 Loss test. : 410.8550079345703, r :16, n :256, d : 45
# Avg computation time for HAVOK : 2.065935659408569 [s], for sim. : 2.5273773193359377 [s]
# Total loss : 50237148875535.99 Loss train. : 50237148653485.13 Loss test. : 222050.85690917968, r :29, n :293, d : 26
# Avg computation time for HAVOK : 2.949821376800537 [s], for sim. : 2.4123956203460692 [s]
# Total loss : 1328.76318359375 Loss train. : 874.168667602539 Loss test. : 454.5945159912109, r :25, n :316, d : 40
# Avg computation time for HAVOK : 2.318039894104004 [s], for sim. : 2.557916259765625 [s]
# Total loss : 65668.19136047363 Loss train. : 65017.55466308594 Loss test. : 650.6366973876953, r :29, n :303, d : 36
# Avg computation time for HAVOK : 2.61179518699646 [s], for sim. : 2.1768673419952393 [s]
# Total loss : 1123.8001235961915 Loss train. : 794.1527755737304 Loss test. : 329.64734802246096, r :20, n :307, d : 32
# Avg computation time for HAVOK : 1.8386091709136962 [s], for sim. : 1.7689150810241698 [s]
# Total loss : 645.6343643188477 Loss train. : 320.35616302490234 Loss test. : 325.2782012939453, r :29, n :315, d : 29
# Avg computation time for HAVOK : 2.703383445739746 [s], for sim. : 2.2701021671295165 [s]
# Total loss : 182364.4349090576 Loss train. : 181087.3019012451 Loss test. : 1277.1330078125, r :29, n :258, d : 48
# Avg computation time for HAVOK : 1.6480422019958496 [s], for sim. : 2.5185826301574705 [s]
# Total loss : 2360.270417785645 Loss train. : 1846.1275009155274 Loss test. : 514.1429168701172, r :14, n :279, d : 40
# Avg computation time for HAVOK : 1.9419485569000243 [s], for sim. : 2.4602782249450685 [s]
# Total loss : 303.1164260864258 Loss train. : 122.89971466064453 Loss test. : 180.21671142578126, r :23, n :290, d : 17
# Avg computation time for HAVOK : 3.0991787910461426 [s], for sim. : 2.3916595458984373 [s]
# Total loss : 8013.01549987793 Loss train. : 7760.814071655273 Loss test. : 252.20142822265626, r :21, n :278, d : 12
# Avg computation time for HAVOK : 2.2339816093444824 [s], for sim. : 1.831454372406006 [s]
# Total loss : 755.2566802978515 Loss train. : 214.1602355957031 Loss test. : 541.0964447021485, r :14, n :317, d : 38
# Avg computation time for HAVOK : 1.9643198013305665 [s], for sim. : 2.647562313079834 [s]
# Total loss : 669.7861770629883 Loss train. : 375.2820510864258 Loss test. : 294.5041259765625, r :18, n :318, d : 26
# Avg computation time for HAVOK : 3.202188587188721 [s], for sim. : 2.671614933013916 [s]
# Total loss : 3784.5807159423825 Loss train. : 3490.4709411621093 Loss test. : 294.1097747802734, r :18, n :302, d : 20
# Avg computation time for HAVOK : 3.087909984588623 [s], for sim. : 2.3632976531982424 [s]
# Total loss : 497.6772918701172 Loss train. : 275.8454193115234 Loss test. : 221.83187255859374, r :24, n :312, d : 18
# Avg computation time for HAVOK : 2.5826847553253174 [s], for sim. : 1.8907471656799317 [s]
# Total loss : 2140.688409423828 Loss train. : 1894.6552856445312 Loss test. : 246.0331237792969, r :24, n :255, d : 11
# Avg computation time for HAVOK : 1.9514317512512207 [s], for sim. : 1.9553205490112304 [s]
# Total loss : 10000000000.0 Loss train. : nan Loss test. : 5.557864154911001e+18, r :22, n :246, d : 2
# Avg computation time for HAVOK : 2.861181116104126 [s], for sim. : 2.5107404232025146 [s]
# Total loss : 1930.2868286132812 Loss train. : 1478.542544555664 Loss test. : 451.74428405761716, r :17, n :265, d : 7
# Avg computation time for HAVOK : 3.1794787406921388 [s], for sim. : 2.5319485664367676 [s]
# Total loss : 1924.298747253418 Loss train. : 1702.8808242797852 Loss test. : 221.4179229736328, r :28, n :301, d : 13
# Avg computation time for HAVOK : 3.8459281444549562 [s], for sim. : 2.4493620872497557 [s]
# Total loss : 3609.159777832031 Loss train. : 2521.355889892578 Loss test. : 1087.803887939453, r :29, n :309, d : 48
# Avg computation time for HAVOK : 1.379873514175415 [s], for sim. : 1.989913558959961 [s]
# Total loss : 587.8988098144531 Loss train. : 231.0897674560547 Loss test. : 356.8090423583984, r :18, n :308, d : 43
# Avg computation time for HAVOK : 1.4015737056732178 [s], for sim. : 1.9927675247192382 [s]
# Total loss : 2015.2428588867188 Loss train. : 841.54013671875 Loss test. : 1173.7027221679687, r :29, n :253, d : 60
# Avg computation time for HAVOK : 1.209563970565796 [s], for sim. : 2.583520030975342 [s]
# Total loss : 735828.464099121 Loss train. : 732151.078125 Loss test. : 3677.3859741210936, r :14, n :255, d : 3
# Avg computation time for HAVOK : 2.8931756973266602 [s], for sim. : 2.478962469100952 [s]
# Total loss : 446.24793090820316 Loss train. : 143.8948486328125 Loss test. : 302.35308227539065, r :26, n :326, d : 22
# Avg computation time for HAVOK : 3.4690034866333006 [s], for sim. : 2.4140089988708495 [s]
# Total loss : 58539640.86361999 Loss train. : 58529023.76366882 Loss test. : 10617.099951171875, r :15, n :329, d : 21
# Avg computation time for HAVOK : 3.0453994274139404 [s], for sim. : 2.034869432449341 [s]
# Total loss : 3215.0718887329103 Loss train. : 2931.5369857788087 Loss test. : 283.53490295410154, r :19, n :322, d : 13
# Avg computation time for HAVOK : 2.759513187408447 [s], for sim. : 1.8105327129364013 [s]
# Total loss : 725.4841735839843 Loss train. : 434.959033203125 Loss test. : 290.5251403808594, r :18, n :308, d : 9
# Avg computation time for HAVOK : 3.914289665222168 [s], for sim. : 2.521622085571289 [s]
# Total loss : 673.7308715820312 Loss train. : 366.0452941894531 Loss test. : 307.6855773925781, r :17, n :296, d : 9
# Avg computation time for HAVOK : 3.595940637588501 [s], for sim. : 2.5130000591278074 [s]
# Total loss : 23623119.804866027 Loss train. : 23622169.933476258 Loss test. : 949.8713897705078, r :28, n :315, d : 7
# Avg computation time for HAVOK : 4.176379823684693 [s], for sim. : 2.4328502655029296 [s]
# Total loss : 10000000000.0 Loss train. : nan Loss test. : 3575966792693365.0, r :25, n :303, d : 2
# Avg computation time for HAVOK : 2.9823163986206054 [s], for sim. : 1.8825138092041016 [s]
# Total loss : 222003.06697387696 Loss train. : 221166.7180419922 Loss test. : 836.3489318847656, r :27, n :290, d : 5
# Avg computation time for HAVOK : 3.9295403480529787 [s], for sim. : 2.5415226459503173 [s]
# Total loss : 10000000000.0 Loss train. : inf Loss test. : 21264055253.667286, r :25, n :259, d : 1
# Avg computation time for HAVOK : 3.2571900367736815 [s], for sim. : 2.837455224990845 [s]
# Total loss : 1673.3752105712892 Loss train. : 1178.417532348633 Loss test. : 494.9576782226562, r :17, n :269, d : 41
# Avg computation time for HAVOK : 2.0891214847564696 [s], for sim. : 3.057820749282837 [s]
# Total loss : 24524.603713989258 Loss train. : 24030.79229736328 Loss test. : 493.81141662597656, r :29, n :269, d : 7
# Avg computation time for HAVOK : 2.5208221435546876 [s], for sim. : 2.0777623653411865 [s]
# Total loss : 996.7926422119141 Loss train. : 328.1404327392578 Loss test. : 668.6522094726563, r :14, n :259, d : 57
# Avg computation time for HAVOK : 0.9597165584564209 [s], for sim. : 2.016501045227051 [s]
# Total loss : 161103805173.15363 Loss train. : 161103714861.1528 Loss test. : 90312.00081176758, r :29, n :264, d : 38
# Avg computation time for HAVOK : 2.19762282371521 [s], for sim. : 2.738921308517456 [s]
# Total loss : 4743.162545776368 Loss train. : 4061.9349060058594 Loss test. : 681.2276397705078, r :14, n :267, d : 42
# Avg computation time for HAVOK : 1.8182210445404052 [s], for sim. : 2.637264347076416 [s]
# Total loss : 3901.592462158203 Loss train. : 800.4674011230469 Loss test. : 3101.1250610351562, r :14, n :260, d : 60
# Avg computation time for HAVOK : 1.1277119636535644 [s], for sim. : 2.4561279296875 [s]
# Total loss : 10000000000.0 Loss train. : inf Loss test. : 4934235159.109375, r :23, n :277, d : 1
# Avg computation time for HAVOK : 3.5990149974823 [s], for sim. : 2.4179533958435058 [s]
# Total loss : 1186.9456268310546 Loss train. : 411.9859191894531 Loss test. : 774.9597076416015, r :14, n :248, d : 60
# Avg computation time for HAVOK : 0.8179455280303956 [s], for sim. : 1.9326311111450196 [s]
# Total loss : 2104.2981079101564 Loss train. : 1583.9195129394532 Loss test. : 520.3785949707031, r :14, n :256, d : 29
# Avg computation time for HAVOK : 1.5089269638061524 [s], for sim. : 1.8389736652374267 [s]
# Total loss : 243006.72729492188 Loss train. : 240918.573248291 Loss test. : 2088.1540466308593, r :15, n :285, d : 4
# Avg computation time for HAVOK : 3.717757320404053 [s], for sim. : 2.566198492050171 [s]
# Total loss : 291129.8209716797 Loss train. : 290792.648135376 Loss test. : 337.17283630371094, r :23, n :334, d : 14
# Avg computation time for HAVOK : 4.017864751815796 [s], for sim. : 2.3859987258911133 [s]
# Total loss : 7405.88850402832 Loss train. : 7105.298641967774 Loss test. : 300.58986206054686, r :29, n :326, d : 10
# Avg computation time for HAVOK : 4.223435592651367 [s], for sim. : 2.3858213901519774 [s]
# Total loss : 10000000000.0 Loss train. : inf Loss test. : 474912185.675, r :21, n :323, d : 1
# Avg computation time for HAVOK : 3.233035659790039 [s], for sim. : 1.7252901554107667 [s]
# Total loss : 2326.647741699219 Loss train. : 1107.8825592041017 Loss test. : 1218.7651824951172, r :14, n :331, d : 7
# Avg computation time for HAVOK : 3.8824875831604 [s], for sim. : 2.401844596862793 [s]
# Total loss : 10000000000.0 Loss train. : nan Loss test. : 32760267363174.844, r :24, n :334, d : 2
# Avg computation time for HAVOK : 5.227638244628906 [s], for sim. : 2.854583740234375 [s]
# Total loss : 28543.702505493166 Loss train. : 27664.204010009766 Loss test. : 879.4984954833984, r :26, n :204, d : 59
# Avg computation time for HAVOK : 1.1324752807617187 [s], for sim. : 2.566320037841797 [s]
# Total loss : 1693.8180908203126 Loss train. : 716.3989318847656 Loss test. : 977.4191589355469, r :14, n :336, d : 51
# Avg computation time for HAVOK : 1.5962276458740234 [s], for sim. : 2.6560490131378174 [s]
# Total loss : 24774.958001708983 Loss train. : 23414.139050292968 Loss test. : 1360.8189514160156, r :23, n :343, d : 48
# Avg computation time for HAVOK : 1.6984894752502442 [s], for sim. : 2.2229902267456056 [s]
# Total loss : 470.7613296508789 Loss train. : 157.75516510009766 Loss test. : 313.00616455078125, r :25, n :219, d : 42
# Avg computation time for HAVOK : 1.0728946685791017 [s], for sim. : 1.8216575622558593 [s]
# Total loss : 33703.441796875 Loss train. : 15694.74228515625 Loss test. : 18008.69951171875, r :20, n :342, d : 59
# Avg computation time for HAVOK : 0.28995471000671386 [s], for sim. : 1.7971543312072753 [s]
# Total loss : 21274.255639648436 Loss train. : 10296.350170898437 Loss test. : 10977.90546875, r :14, n :330, d : 60
# Avg computation time for HAVOK : 0.42096843719482424 [s], for sim. : 2.393015670776367 [s]
# Total loss : 718.9001373291015 Loss train. : 223.4730682373047 Loss test. : 495.42706909179685, r :14, n :213, d : 35
# Avg computation time for HAVOK : 1.6070072174072265 [s], for sim. : 2.578339767456055 [s]
# Total loss : 5316.0988494873045 Loss train. : 4537.362289428711 Loss test. : 778.7365600585938, r :14, n :341, d : 18
# Avg computation time for HAVOK : 4.3755332946777346 [s], for sim. : 3.012557792663574 [s]
# Total loss : 65084.87215270996 Loss train. : 64727.35690917969 Loss test. : 357.51524353027344, r :17, n :343, d : 7
# Avg computation time for HAVOK : 4.53132905960083 [s], for sim. : 2.64925856590271 [s]
# Total loss : 633.7885848999024 Loss train. : 326.3177749633789 Loss test. : 307.47080993652344, r :24, n :346, d : 17
# Avg computation time for HAVOK : 3.8965943336486815 [s], for sim. : 3.0021820068359375 [s]
# Total loss : 440.3879760742187 Loss train. : 155.71814880371093 Loss test. : 284.6698272705078, r :29, n :338, d : 25
# Avg computation time for HAVOK : 3.712748098373413 [s], for sim. : 2.788049077987671 [s]
# Total loss : 49934142.260981746 Loss train. : 49928879.96290436 Loss test. : 5262.298077392578, r :23, n :347, d : 30
# Avg computation time for HAVOK : 3.2687843322753904 [s], for sim. : 2.5992517471313477 [s]
# Total loss : 751.1457061767578 Loss train. : 292.3202697753906 Loss test. : 458.8254364013672, r :15, n :347, d : 40
# Avg computation time for HAVOK : 2.396606779098511 [s], for sim. : 2.6230120182037355 [s]
# Total loss : 3747.350119018555 Loss train. : 3043.708450317383 Loss test. : 703.6416687011719, r :29, n :343, d : 38
# Avg computation time for HAVOK : 2.208026647567749 [s], for sim. : 2.090730667114258 [s]
# Total loss : 3242.7399047851563 Loss train. : 1269.4550659179688 Loss test. : 1973.2848388671875, r :14, n :349, d : 52
# Avg computation time for HAVOK : 0.8279040813446045 [s], for sim. : 1.8565686225891114 [s]
# Total loss : 5780992449806.192 Loss train. : 5780992427184.869 Loss test. : 22621.323196411133, r :29, n :343, d : 7
# Avg computation time for HAVOK : 5.518367052078247 [s], for sim. : 2.892970609664917 [s]
# Total loss : 893.1898239135742 Loss train. : 436.75411529541014 Loss test. : 456.4357086181641, r :29, n :232, d : 39
# Avg computation time for HAVOK : 1.6483736515045166 [s], for sim. : 2.7045647144317626 [s]
# Total loss : 1123.2319915771484 Loss train. : 766.6773803710937 Loss test. : 356.5546112060547, r :14, n :349, d : 26
# Avg computation time for HAVOK : 3.4277726650238036 [s], for sim. : 2.5347119331359864 [s]
# Total loss : 319921.2737075805 Loss train. : 319432.3717208862 Loss test. : 488.90198669433596, r :29, n :211, d : 17
# Avg computation time for HAVOK : 2.0593846321105955 [s], for sim. : 3.1525649547576906 [s]
# Total loss : 802105.1123718262 Loss train. : 801472.7726074219 Loss test. : 632.3397644042968, r :29, n :205, d : 7
# Avg computation time for HAVOK : 1.9689894199371338 [s], for sim. : 2.5529758453369142 [s]
# Total loss : 10000000000.0 Loss train. : inf Loss test. : 13429266557.4, r :14, n :314, d : 1
# Avg computation time for HAVOK : 3.5323888301849364 [s], for sim. : 2.331602907180786 [s]
# Total loss : 339886681.49000853 Loss train. : 339872585.84558105 Loss test. : 14095.644427490235, r :18, n :201, d : 4
# Avg computation time for HAVOK : 1.9793760299682617 [s], for sim. : 2.5163816452026366 [s]
# Total loss : 13215.780236816407 Loss train. : 12863.251718139649 Loss test. : 352.5285186767578, r :29, n :281, d : 9
# Avg computation time for HAVOK : 3.5758574485778807 [s], for sim. : 2.6733736991882324 [s]
# Total loss : 25199873.173046876 Loss train. : 25195261.979260255 Loss test. : 4611.193786621094, r :29, n :238, d : 51
# Avg computation time for HAVOK : 1.4401179313659669 [s], for sim. : 2.4936789512634276 [s]
# Total loss : 10586.176094055176 Loss train. : 10268.951023864745 Loss test. : 317.2250701904297, r :29, n :200, d : 15
# Avg computation time for HAVOK : 1.4568090438842773 [s], for sim. : 2.1080007553100586 [s]
# Total loss : 16462.221600341796 Loss train. : 15812.497045898437 Loss test. : 649.7245544433594, r :29, n :209, d : 52
# Avg computation time for HAVOK : 1.028736686706543 [s], for sim. : 1.8526890754699707 [s]
# Total loss : 10000000000.0 Loss train. : inf Loss test. : 89463455769.325, r :14, n :302, d : 1
# Avg computation time for HAVOK : 3.8128318309783937 [s], for sim. : 2.4192428588867188 [s]
# Total loss : 657.5789855957032 Loss train. : 283.2328765869141 Loss test. : 374.3461090087891, r :14, n :222, d : 60
# Avg computation time for HAVOK : 1.034220314025879 [s], for sim. : 2.5690157890319822 [s]
# Total loss : 3420.8778274536135 Loss train. : 2902.086637878418 Loss test. : 518.7911895751953, r :14, n :200, d : 13
# Avg computation time for HAVOK : 1.6878893375396729 [s], for sim. : 2.4120678901672363 [s]
# Total loss : 13982.752880859374 Loss train. : 6670.20029296875 Loss test. : 7312.552587890625, r :29, n :349, d : 56
# Avg computation time for HAVOK : 0.5728167533874512 [s], for sim. : 1.933762216567993 [s]
# Total loss : 10000000000.0 Loss train. : nan Loss test. : 9649632602538436.0, r :29, n :215, d : 1
# Avg computation time for HAVOK : 1.68164119720459 [s], for sim. : 2.3459786891937258 [s]
# Total loss : 10000000000.0 Loss train. : inf Loss test. : 11411247628.75, r :23, n :349, d : 1
# Avg computation time for HAVOK : 5.702487277984619 [s], for sim. : 2.7157482624053957 [s]
# Total loss : 10679.304542541504 Loss train. : 10269.989451599122 Loss test. : 409.3150909423828, r :29, n :325, d : 33
# Avg computation time for HAVOK : 2.910085153579712 [s], for sim. : 2.5514901161193846 [s]
# Total loss : 1575.779592895508 Loss train. : 1106.5845672607422 Loss test. : 469.1950256347656, r :14, n :239, d : 13
# Avg computation time for HAVOK : 2.4313278675079344 [s], for sim. : 2.5569619655609133 [s]
# Total loss : 46581.779296875 Loss train. : 21821.51328125 Loss test. : 24760.266015625, r :29, n :339, d : 60
# Avg computation time for HAVOK : 0.35866332054138184 [s], for sim. : 2.5501402378082276 [s]
# Total loss : 10000000000.0 Loss train. : inf Loss test. : 24384821981101.145, r :14, n :273, d : 1
# Avg computation time for HAVOK : 2.427275228500366 [s], for sim. : 1.9419255256652832 [s]
# Total loss : 166077.24190979003 Loss train. : 165408.28803100585 Loss test. : 668.9538787841797, r :29, n :272, d : 17
# Avg computation time for HAVOK : 2.6728673934936524 [s], for sim. : 2.6452401161193846 [s]
# Total loss : 2177.589210510254 Loss train. : 846.6798049926758 Loss test. : 1330.909405517578, r :14, n :209, d : 8
# Avg computation time for HAVOK : 1.992520236968994 [s], for sim. : 2.588459873199463 [s]
# Total loss : 62733708.9069458 Loss train. : 62726165.561553955 Loss test. : 7543.3453918457035, r :14, n :349, d : 14
# Avg computation time for HAVOK : 4.481818103790284 [s], for sim. : 2.6511169910430907 [s]
# Total loss : 367.39803619384764 Loss train. : 119.75046234130859 Loss test. : 247.64757385253907, r :20, n :259, d : 33
# Avg computation time for HAVOK : 1.7793036937713622 [s], for sim. : 2.0284531116485596 [s]
# Total loss : 989.1443862915039 Loss train. : 122.69523773193359 Loss test. : 866.4491485595703, r :14, n :313, d : 18
# Avg computation time for HAVOK : 2.7872667789459227 [s], for sim. : 2.317850923538208 [s]
# Total loss : 10513.790356445312 Loss train. : 4871.759594726563 Loss test. : 5642.03076171875, r :29, n :327, d : 60
# Avg computation time for HAVOK : 0.6842815399169921 [s], for sim. : 2.631653642654419 [s]
# Total loss : 1170.2936767578126 Loss train. : 462.4765625 Loss test. : 707.8171142578125, r :29, n :326, d : 44
# Avg computation time for HAVOK : 2.2419317245483397 [s], for sim. : 2.6275516986846923 [s]
# Total loss : 7376187627.881784 Loss train. : 7376168747.431955 Loss test. : 18880.449829101562, r :29, n :215, d : 60
# Avg computation time for HAVOK : 1.1486739635467529 [s], for sim. : 2.5077800273895265 [s]
# Total loss : 580.512973022461 Loss train. : 347.6094177246094 Loss test. : 232.90355529785157, r :29, n :248, d : 23
# Avg computation time for HAVOK : 2.284307432174683 [s], for sim. : 2.561700391769409 [s]
# Total loss : 10000000000.0 Loss train. : inf Loss test. : 1347035319043.0234, r :19, n :293, d : 1
# Avg computation time for HAVOK : 4.0463783740997314 [s], for sim. : 2.549960803985596 [s]
# Total loss : 14671.780448913574 Loss train. : 13335.854328918456 Loss test. : 1335.9261199951172, r :14, n :271, d : 14
# Avg computation time for HAVOK : 2.0195280075073243 [s], for sim. : 1.8196744441986084 [s]
# Total loss : 779.2260986328125 Loss train. : 194.56781616210938 Loss test. : 584.6582824707032, r :14, n :213, d : 17
# Avg computation time for HAVOK : 1.3368353366851806 [s], for sim. : 1.9819794654846192 [s]
# Total loss : 17451778194.834267 Loss train. : 17451766840.34004 Loss test. : 11354.494229125976, r :29, n :250, d : 5
# Avg computation time for HAVOK : 3.1636051177978515 [s], for sim. : 3.1139803409576414 [s]
# Total loss : 2202.367785644531 Loss train. : 966.7248901367187 Loss test. : 1235.6428955078125, r :14, n :300, d : 32
# Avg computation time for HAVOK : 2.651422309875488 [s], for sim. : 2.5744814395904543 [s]
# Total loss : 1765.0968444824218 Loss train. : 895.46982421875 Loss test. : 869.6270202636719, r :24, n :349, d : 42
# Avg computation time for HAVOK : 2.2887058734893797 [s], for sim. : 2.5699212551116943 [s]
# Total loss : 385.16056518554683 Loss train. : 120.83511962890626 Loss test. : 264.3254455566406, r :23, n :298, d : 30
# Avg computation time for HAVOK : 2.2553146839141847 [s], for sim. : 2.089103126525879 [s]
# Total loss : 320633.59332733153 Loss train. : 320301.18285369873 Loss test. : 332.4104736328125, r :29, n :258, d : 19
# Avg computation time for HAVOK : 2.0513211250305177 [s], for sim. : 2.1949461460113526 [s]
# Total loss : 975.2742828369142 Loss train. : 373.1081817626953 Loss test. : 602.1661010742188, r :14, n :317, d : 48
# Avg computation time for HAVOK : 1.7390192985534667 [s], for sim. : 2.4852185249328613 [s]
# Total loss : 10000000000.0 Loss train. : inf Loss test. : 1348471749.00625, r :23, n :312, d : 1
# Avg computation time for HAVOK : 4.91046257019043 [s], for sim. : 3.077634000778198 [s]
# Total loss : 8261097338.542719 Loss train. : 8261081601.266724 Loss test. : 15737.275994873047, r :29, n :200, d : 36
# Avg computation time for HAVOK : 1.4435826301574708 [s], for sim. : 2.5452497482299803 [s]
# Total loss : 1024.109504699707 Loss train. : 664.7986068725586 Loss test. : 359.31089782714844, r :29, n :209, d : 31
# Avg computation time for HAVOK : 1.297048854827881 [s], for sim. : 1.8547224521636962 [s]
# Total loss : 10000000000.0 Loss train. : nan Loss test. : 230304473239115.0, r :14, n :244, d : 1
# Avg computation time for HAVOK : 1.8693978786468506 [s], for sim. : 1.7856374740600587 [s]
# Total loss : 25363.2421585083 Loss train. : 25107.97437286377 Loss test. : 255.26778564453124, r :24, n :273, d : 26
# Avg computation time for HAVOK : 2.5589871406555176 [s], for sim. : 2.521779441833496 [s]
# Total loss : 2600932.8179397583 Loss train. : 2599815.286122131 Loss test. : 1117.5318176269532, r :29, n :319, d : 17
# Avg computation time for HAVOK : 3.7566202163696287 [s], for sim. : 2.5945127964019776 [s]
# Total loss : 66233.0091796875 Loss train. : 65129.01664428711 Loss test. : 1103.9925354003906, r :14, n :218, d : 51
# Avg computation time for HAVOK : 1.186680269241333 [s], for sim. : 2.5265329837799073 [s]
# Total loss : 2762.8546783447264 Loss train. : 2480.3235107421874 Loss test. : 282.5311676025391, r :29, n :349, d : 24
# Avg computation time for HAVOK : 2.6833550453186037 [s], for sim. : 1.849793004989624 [s]
# Total loss : 10000000000.0 Loss train. : inf Loss test. : 41592195101989.54, r :14, n :216, d : 1
# Avg computation time for HAVOK : 1.8959792613983155 [s], for sim. : 2.332237720489502 [s]
# Total loss : 952.2632461547852 Loss train. : 629.3796249389649 Loss test. : 322.8836212158203, r :19, n :260, d : 41
# Avg computation time for HAVOK : 1.7551588535308837 [s], for sim. : 2.4106843948364256 [s]
# Total loss : 10000000000.0 Loss train. : inf Loss test. : 1270901690.4625, r :14, n :338, d : 1
# Avg computation time for HAVOK : 5.034674167633057 [s], for sim. : 2.5074276447296144 [s]
# Total loss : 489.0910003662109 Loss train. : 102.6527313232422 Loss test. : 386.4382690429687, r :14, n :200, d : 32
# Avg computation time for HAVOK : 1.411085605621338 [s], for sim. : 2.4661624431610107 [s]
# Total loss : 10000000000.0 Loss train. : nan Loss test. : 6.17002859509163e+18, r :29, n :200, d : 1
# Avg computation time for HAVOK : 1.5152098178863525 [s], for sim. : 1.969391441345215 [s]
# Total loss : 10486477660.633326 Loss train. : 10486445863.931372 Loss test. : 31796.701953125, r :29, n :337, d : 48
# Avg computation time for HAVOK : 1.520730447769165 [s], for sim. : 2.0382790088653566 [s]
# Total loss : 1575.6957916259767 Loss train. : 1245.107192993164 Loss test. : 330.5885986328125, r :14, n :309, d : 26
# Avg computation time for HAVOK : 2.921871280670166 [s], for sim. : 2.5184426307678223 [s]
# Total loss : 713.6579223632813 Loss train. : 177.21141052246094 Loss test. : 536.4465118408203, r :14, n :224, d : 33
# Avg computation time for HAVOK : 1.719460916519165 [s], for sim. : 2.4225276947021483 [s]
# Total loss : 920.2975708007812 Loss train. : 410.49725952148435 Loss test. : 509.80031127929686, r :19, n :246, d : 53
# Avg computation time for HAVOK : 1.3166816711425782 [s], for sim. : 2.401540994644165 [s]
# Total loss : 788.0942123413085 Loss train. : 172.1616195678711 Loss test. : 615.9325927734375, r :14, n :294, d : 18
# Avg computation time for HAVOK : 2.6727373123168947 [s], for sim. : 2.2152724742889403 [s]
# Total loss : 14035.264340209962 Loss train. : 13701.767343139649 Loss test. : 333.4969970703125, r :29, n :244, d : 38
# Avg computation time for HAVOK : 1.2946714401245116 [s], for sim. : 1.8322465896606446 [s]
# Total loss : 10000000000.0 Loss train. : inf Loss test. : 479898777.5875, r :14, n :349, d : 1
# Avg computation time for HAVOK : 5.21617112159729 [s], for sim. : 2.8265673160552978 [s]
# Total loss : 392.043196105957 Loss train. : 140.92120819091798 Loss test. : 251.12198791503906, r :14, n :244, d : 34
# Avg computation time for HAVOK : 1.9941825866699219 [s], for sim. : 3.1800764083862303 [s]
# Total loss : 5240.891857910156 Loss train. : 4525.033950805664 Loss test. : 715.8579071044921, r :18, n :200, d : 60
# Avg computation time for HAVOK : 1.0761943340301514 [s], for sim. : 2.93204083442688 [s]
# Total loss : 10000000000.0 Loss train. : inf Loss test. : 751658029600.8875, r :23, n :207, d : 1
# Avg computation time for HAVOK : 1.870495319366455 [s], for sim. : 2.127898073196411 [s]
# Total loss : 1779.0108337402344 Loss train. : 980.715087890625 Loss test. : 798.2957458496094, r :14, n :210, d : 60
# Avg computation time for HAVOK : 0.7105412483215332 [s], for sim. : 1.8029426097869874 [s]
# Total loss : 7066.197242736816 Loss train. : 5763.831056213379 Loss test. : 1302.3661865234376, r :14, n :228, d : 48
# Avg computation time for HAVOK : 0.9605554103851318 [s], for sim. : 1.776121234893799 [s]
# Total loss : 3398.29493560791 Loss train. : 2509.1781265258787 Loss test. : 889.1168090820313, r :14, n :320, d : 7
# Avg computation time for HAVOK : 4.309349870681762 [s], for sim. : 2.775446081161499 [s]
# Total loss : 1106.5443405151368 Loss train. : 98.09889678955078 Loss test. : 1008.445443725586, r :14, n :238, d : 25
# Avg computation time for HAVOK : 1.9573216915130616 [s], for sim. : 2.409855842590332 [s]
# Total loss : 835.7826248168944 Loss train. : 355.2373641967773 Loss test. : 480.5452606201172, r :14, n :286, d : 12
# Avg computation time for HAVOK : 3.300162363052368 [s], for sim. : 2.6057135105133056 [s]
# Total loss : 725.2714187622071 Loss train. : 249.03583526611328 Loss test. : 476.23558349609374, r :14, n :342, d : 32
# Avg computation time for HAVOK : 2.9915425777435303 [s], for sim. : 2.618535614013672 [s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-72-ca5edc02fd64> in <module>
#     104
#     105
# --> 106 opt.run_optimization(max_iter)
#
# ~\anaconda3\lib\site-packages\GPyOpt\core\bo.py in run_optimization(self, max_iter, max_time, eps, context, verbosity, save_models_parameters, report_file, evaluations_file, models_file)
#     149
#     150             # --- Evaluate *f* in X, augment Y and update cost function (if needed)
# --> 151             self.evaluate_objective()
#     152
#     153             # --- Update current evaluation time and function evaluations
#
# ~\anaconda3\lib\site-packages\GPyOpt\core\bo.py in evaluate_objective(self)
#     195         Evaluates the objective
#     196         """
# --> 197         self.Y_new, cost_new = self.objective.evaluate(self.suggested_sample)
#     198         self.cost.update_cost_model(self.suggested_sample, cost_new)
#     199         self.Y = np.vstack((self.Y,self.Y_new))
#
# ~\anaconda3\lib\site-packages\GPyOpt\core\task\objective.py in evaluate(self, x)
#      48
#      49         if self.n_procs == 1:
# ---> 50             f_evals, cost_evals = self._eval_func(x)
#      51         else:
#      52             try:
#
# ~\anaconda3\lib\site-packages\GPyOpt\core\task\objective.py in _eval_func(self, x)
#      72         for i in range(x.shape[0]):
#      73             st_time    = time.time()
# ---> 74             rlt = self.func(np.atleast_2d(x[i]))
#      75             f_evals     = np.vstack([f_evals,rlt])
#      76             cost_evals += [time.time()-st_time]
#
# <ipython-input-72-ca5edc02fd64> in loss(space)
#      57         timing[1,fold] = time.time() # Simulation time computation
#      58         # TESTING ######################################################
# ---> 59         model.Simulate(X0=delta_X[fold,:,0],
#      60                        horizon=nb_train,
#      61                        U=torch.cat((RobotSim.X[fold,:,:nb_train],
#
# ~\OneDrive\Documents\Mécanique - EPFL\Master III\Semester project\Software\My code\Subspace-learning-for-robot-application\LQR simulation\Utils\Functions.py in Simulate(self, X0, horizon, **kwargs)
#     452                         self.Y_prediction[:,i+1] = self.A @ self.Y_prediction[:,i] + self.B @ U[:,i]
#     453                 elif self.kwargs['mode'] == 'ELQR form':
# --> 454                     self.Y_prediction[:,i+1] = self.A @ self.Y_prediction[:,i] + torch.cat((self.Bd[:],
#     455                                                                                           self.B),axis=1) @ U[:,i]
#     456         elif self.kwargs['mode'] == 'prediction_i':
#
# KeyboardInterrupt:

# %% [markdown]
# ## LQR control of the Panda robot
# ### Model prediction capabilities in training

# %%
# Train linear model
traj = 1

n = 350
r = 26
d = 25

model = HAVOK(delta_X[traj,:,:nb_train], # state-wise difference
              torch.cat((RobotSim.X[traj,:,:nb_train-1],
                         RobotSim.U[traj,:,:nb_train-1],
                         delta_U[traj,:,:nb_train-1]),axis=0), # model predicted states
              mode='ELQR form',
              nb_U=28,
              nb_U_ex=21
             )
# model = HAVOK(pandaRobot.X[traj,:,:nb_train], # state-wise difference
#               pandaRobot.U[traj,:,nb_train-1], # model predicted states
#               mode='prediction'
#              )
traj = 1
model.HANKEL(n, d)
model.SVD(r)
model.LS(r,rcond=0)
model.Simulate(delta_X[traj,:,0],
               horizon=nb_train + nb_test,
               U=torch.cat((RobotSim.X[traj,:,:-1],
                          RobotSim.U[traj,:,:],
                          delta_U[traj,:,:]),axis=0),
               )
# model.Simulate(pandaRobot.X[traj,:,0],
#                horizon=nb_train,
#                U=pandaRobot.U[traj,:,:nb_train],
#                )
# X_pred = pandaRobot.X[traj] + model.X_prediction
loss_traj = model.RMSE(X_pred=model.X_prediction,
                       X_true=delta_X[traj,:,:])
# loss_traj = model.RMSE(X_pred=model.X_prediction[:,:],
#                        X_true=RobotSim.X[traj,:,:])
# loss_model = model.RMSE(X_pred=pandaRobot.X[traj],
#                                     X_true=pandaRobot2.X[traj])
print(loss_traj)
# print(loss_model)

# plt.rcParams['font.size'] = 20
# fig, ax = plt.subplots(1, 2, constrained_layout = True, figsize=(18,8))

# figA = snb.heatmap(model.A,cmap='Reds',ax=ax[0])
# figB = snb.heatmap(model.B,cmap='Reds',ax=ax[1])

plt.rcParams['font.size'] = 12
fig, ax = plt.subplots(7, 2, constrained_layout = True, figsize=(14,16))

for i in range(7):
    
    ax[i,0].plot(RobotSim.T[:], rad2deg(model.X_prediction[i,:]), label=r'$\delta \hat{q}$')
    ax[i,0].plot(RobotSim.T[:], rad2deg(delta_X[traj,i,:]), label=r'$\delta q$', linestyle='dashed')
    ax[i,1].plot(RobotSim.T[:], rad2deg(model.X_prediction[7+i,:]), label=r'$\delta \dot{\hat{q}}$')
    ax[i,1].plot(RobotSim.T[:], rad2deg(delta_X[traj,7+i,:]), label=r'$\delta \dot{q}$', linestyle='dashed')
    ax[i,0].set_ylabel('Pos. [deg]'), ax[i,1].set_ylabel('Vel. [deg/s]')
    ax[i,0].legend(), ax[i,1].legend()
    
ax[6,0].set_xlabel('Time [s]'), ax[6,1].set_xlabel('Time [s]')
# Out:
# tensor(127.6414)
# (Text(0.5, 0, 'Time [s]'), Text(0.5, 0, 'Time [s]'))

# %% [markdown]
# ### Leveraging ELQR for residual dynamics cancellation

# %%
# Train linear model #######################################
traj = 1
horizon = 5000
# Correct trajectories with ELQR ############################
u_d = torch.cat((RobotSim.X[traj,:,:horizon],
                 RobotSim.U[traj,:,:horizon]),axis=0)
model.toNumpy()
model.ConstructLQR(x_std=1e6*np.concatenate((np.ones([7]),np.zeros([7])),axis=0),
                   u_std=-2.,
                   dt=RobotSim.dt,
                   horizon=horizon,
                   mode='ELQR',
                   u_d=u_d,
                   Bd=model.Bd
                  )
model.LQR_simulate(delta_X[traj,:,0].numpy(),
                   mode='ELQR', 
                   u_d=u_d,
                   Bd=model.Bd
                  )

plt.rcParams['font.size'] = 20
fig, ax = plt.subplots(7, 3, constrained_layout = True, figsize=(18,17))

for i in range(7):
    
    ax[i,0].plot(RobotReal.T[:horizon-1], rad2deg(model.LQR_X[i,:]), label=r'$\Delta x_{LQR}$')
    ax[i,0].plot(RobotReal.T[:horizon], rad2deg(delta_X[traj,i,:horizon]), label=r'$\Delta x$')
    ax[i,1].plot(RobotReal.T[:horizon-1], rad2deg(model.LQR_X[7+i,:]), label=r'$\dot{\Delta x}_{LQR}$')
    ax[i,1].plot(RobotReal.T[:horizon], rad2deg(delta_X[traj,7+i,:horizon]), label=r'$\dot{\Delta x}$')
    ax[i,2].plot(RobotReal.T[:horizon-2], rad2deg(model.LQR_U[0,:,i]), label=r'$u_{LQR}$')
    ax[i,0].set_ylabel('Position [deg]'), ax[i,1].set_ylabel('Torque [Nm]')
    ax[i,0].legend(), ax[i,1].legend()
    
ax[6,0].set_xlabel('Time [s]'), ax[6,1].set_xlabel('Time [s]')
# Out:
# (Text(0.5, 0, 'Time [s]'), Text(0.5, 0, 'Time [s]'))

# %%
np.array(model.LQR.K).shape
# Out:
# (29998, 7, 22)

# %%
(np.concatenate((robot.q,robot.dq)) - RobotSim.X[traj,:,i].numpy()).shape
# Out:
# (14,)

# %% [markdown]
# ### Corrected trajectories

# %%
N = horizon
log_control = np.empty(shape=[7,N-1])
log_control_model = np.empty(shape=[7,N-1])
log_q = np.empty(shape=[7,N])
log_dq = np.empty(shape=[7,N])
log_ddq = np.empty(shape=[7,N])

log_error = []
sum_error = np.zeros(7)
log_q[:,0] = robot.q
log_dq[:,0] = robot.dq
log_ddq[:,0] = robot.ddq

K = (np.array(model.LQR.K) @ model.pinvC)

robot.default_q = RobotReal.ref[traj,:7,0]
robot.reset_q(max_iter=100)
robot.joints_free=True

for i in range(0, N-2):
    error_q = RobotReal.ref[traj,:7,i] - robot.q
    error_dq = RobotReal.ref[traj,7:,i] - robot.dq

#   Computed Torque Control
    control_input = configuration_ctc(Kp @ error_q + Ki @ sum_error + Kd @ error_dq + 
                                      RobotReal.desired_ddq[traj,:,i],
#                                       K[i,:,:] @ (np.concatenate((log_q[:,i-1],
#                                                                   log_dq[:,i-1])) - 
#                                                     RobotSim.X[traj,:,i].numpy()),
                                      robot,
                                      correction= + K[i,:,:] @ (np.concatenate((log_q[:,i-1],
                                                                                log_dq[:,i-1])) - 
                                                                RobotSim.X[traj,:,i].numpy()
                                                               )
                                     )
    # Add viscous friction
    add_friction = F_v@robot.dq
    control_input -= add_friction

    for j in range(7):
        if control_input[j] < robot.joint_torque_limits[j,0]:
            control_input[j] = robot.joint_torque_limits[j,0].copy()
        if control_input[j] > robot.joint_torque_limits[j,1]:
            control_input[j] = robot.joint_torque_limits[j,1].copy()

    robot.set_torque(control_input[:7]) # Simulation

    log_error.append(np.copy(error_q))
    log_q[:,i] = robot.q.copy()
    log_dq[:,i] = robot.dq.copy()
    log_ddq[:,i] = robot.ddq.copy()
    log_control[:,i] = np.copy(control_input)
#     time.sleep(dt)
    sum_error += error_q*dt
        
log_q[:,N-1] = log_q[:,N-2]
log_dq[:,N-1] = log_dq[:,N-2]
# Out:
# joints are free now

# %%
plt.rcParams['font.size'] = 12
fig, ax = plt.subplots(7, 2, constrained_layout = True, figsize=(14,16))

for i in range(7):
    
    ax[i,0].plot(RobotSim.T[:horizon], rad2deg(log_q[i,:]), label=r'$q_{corr}$')
    ax[i,0].plot(RobotSim.T[:horizon], rad2deg(RobotSim.X[traj,i,:horizon]), label=r'$q_{sim}$', linestyle='dashed')
    ax[i,0].plot(RobotSim.T[:horizon], rad2deg(RobotReal.X[traj,i,:horizon]), label=r'$q_{real}$', linestyle='dashdot')
    ax[i,1].plot(RobotSim.T[:horizon], rad2deg(log_dq[i,:]), label=r'$\dot{q}_{corr}$')
    ax[i,1].plot(RobotSim.T[:horizon], rad2deg(RobotSim.X[traj,7+i,:horizon]), label=r'$\dot{q}_{sim}$', linestyle='dashed')
    ax[i,1].plot(RobotSim.T[:horizon], rad2deg(RobotReal.X[traj,7+i,:horizon]), label=r'$\dot{q}_{real}$', linestyle='dashdot')
    ax[i,0].set_ylabel('Pos. [deg]'), ax[i,1].set_ylabel('Vel. [deg/s]')
    ax[i,0].legend(), ax[i,1].legend()
    
ax[6,0].set_xlabel('Time [s]'), ax[6,1].set_xlabel('Time [s]')
# Out:
# (Text(0.5, 0, 'Time [s]'), Text(0.5, 0, 'Time [s]'))
