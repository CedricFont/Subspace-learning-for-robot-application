# %% [markdown]
# # Panda robot identification and LQR control

# %%
import numpy as np
from numpy import random as rnd
from numpy.linalg import pinv
from numpy import linalg as lg
from scipy import linalg as slg
from importlib import reload
import seaborn as snb
import matplotlib.pyplot as plt
import Utils.Functions 
from Utils.Functions import *
import pbdlib as pbd
from scipy.linalg import hankel
import joblib
import pybullet
from pbdlib import LQR
from pbdlib.utils import get_canonical
import pandapybullet as ppb
import torch
import time
import GPy, GPyOpt
# %load_ext autoreload
# %autoreload 2
plt.style.use("default")
plt.rcParams['font.size'] = 13
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams['lines.linewidth'] = 2.5
np.set_printoptions(precision=5, suppress=False)

# %% [markdown]
# ## Gather training data
# ### Define random sine reference
#
# Run a LQR using desired joint position and velocity to retrieve jooitn acceleration

# %%
dt = 1e-3
world_sim = ppb.WorldSim()
world_sim.setup_scene()
world_sim.load_table()
robot = world_sim.load_panda()

# %%
N=15000
T = N*dt
n_training = 5
n_testing = 2
n_tot = n_training + n_testing
joint_limits = robot.joint_limits.copy()
joint_limits[1,:] = [-deg2rad(35),deg2rad(35)]
# joint_limits[3,0] = -deg2rad(60)

# Trajectories specifications
specs = {'phi': {'low': -np.pi, 'high': np.pi}, 
         'A': {'low': -np.pi, 'high': np.pi},
         'f': {'low': 1/20, 'high': .3},
         'nb_parts': 100, 'margin': .1, 'safety': .9}

pandaRobot = Robot(7, 7, dt, N, robot)
pandaRobot.drawTrajectories(nb_traj=n_tot, q_limits=joint_limits, specs=specs)

# %% [markdown]
# ## Gather training data using CTC + PD
#
# ### Tune PD controller

# %%
Kp = np.diag([200]*7)
Ki = np.eye(7)*5.
Kd = np.eye(7)*5.

robot.reset_q(max_iter=100)
robot.joints_free=True
# Out:
# joints are free now

# %% [markdown]
# ### Simulate using CTC + PD

# %%
log_control = np.empty(shape=[n_tot,7,N-1])
log_q = np.empty(shape=[n_tot,7,N])
log_dq = np.empty(shape=[n_tot,7,N])
log_ddq = np.empty(shape=[n_tot,7,N])

for n in range(n_tot):
    log_error = []
    sum_error = np.zeros(7)
    log_q[n,:,0] = robot.q
    log_dq[n,:,0] = robot.dq
    log_ddq[n,:,0] = robot.ddq
    
    robot.default_q = pandaRobot.ref[n,:7,0]
    robot.reset_q(max_iter=100)
    robot.joints_free=True
    for i in range(0, N-1):
        error_q = pandaRobot.ref[n,:7,i] - robot.q
        error_dq = pandaRobot.ref[n,7:,i] - robot.dq

    #   Computed Torque Control
        control_input = robot.configuration_ctc(Kp @ error_q + Ki @ sum_error + Kd @ error_dq + pandaRobot.desired_ddq[n,:,i])
        
        for j in range(7):
            if control_input[j] < robot.joint_torque_limits[j,0]:
                control_input[j] = robot.joint_torque_limits[j,0].copy()
            if control_input[j] > robot.joint_torque_limits[j,1]:
                control_input[j] = robot.joint_torque_limits[j,1].copy()

        robot.set_torque(control_input[:7])

        log_error.append(np.copy(error_q))
        log_q[n,:,i] = robot.q.copy()
        log_dq[n,:,i] = robot.dq.copy()
        log_ddq[n,:,i] = robot.ddq.copy()
        log_control[n,:,i] = np.copy(control_input)
    #     time.sleep(dt)
        sum_error += error_q*dt
# Out:
# joints are free now
# joints are free now
# joints are free now
# joints are free now
# joints are free now
# joints are free now
# joints are free now

# %% [markdown]
# ### Store data in state-space form

# %%
pandaRobot.toStateSpace(log_q, log_dq, log_control)

# %% [markdown]
# ## Model training

# %% [markdown]
# ### Using *GPyOpt*

# %%
traj_ratio = .02
n_low, n_high = 15, 120
d_low, d_high = 1, np.int((1-traj_ratio)/n_high*pandaRobot.N)

domain = [
    {'name': 'input_cost', 'type': 'continuous', 'domain': (0.,3.)},
    {'name': 'dimension', 'type': 'discrete', 'domain': np.arange(5,100,1)},
    {'name': 'nb_traj', 'type': 'discrete', 'domain': np.arange(n_low,n_high,1)},
    {'name': 'nb_delays', 'type': 'discrete', 'domain': np.arange(d_low,d_high,1)}
]

print('delay max : ',np.int((1-traj_ratio)/n_high*pandaRobot.N))
print('points min : ',pandaRobot.N- d_high*n_high)

# n_training = 5 # Number of trainings per epoch
loss_traj = np.empty(shape=[n_training])
loss_U = np.empty(shape=[n_training])
loss_LQR = np.empty(shape=[n_training])

# @use_named_args(SPACE)
def loss(space):
    # Model parameters
    n_params = space.shape[0] # If train by batch
    u_std = space[0,0]
    s = np.int(space[0,1])
    n = np.int(space[0,2])
    d = np.int(space[0,3])
    
    timing = np.empty([2,n_training])
    
    for fold in range(n_training):
        timing[0,fold] = time.time() # HAVOK computation time
        
        model = HAVOK(pandaRobot.dX[fold,:,:], pandaRobot.dU[fold,:,:], learnOnDiff=True)
#         model = HAVOK(pandaRobot.X[fold,:,:], pandaRobot.U[fold,:,:])
        model.HANKEL(n, d)
        model.SVD(s)
        model.LS(s,rcond=0)
#         model.Simulate(pandaRobot.ref[fold,:,0],U_testing = pandaRobot.U[fold,:]) # Learn on differences

        timing[0,fold] = time.time() - timing[0,fold]  
        timing[1,fold] = time.time() # LQR computation time
        
        # LQR loss ##############################
        model.ConstructLQR(x_std=1e6*np.ones(pandaRobot.nb_S), u_std=u_std, dt=dt, ref=pandaRobot.ref[fold,:,:]) # To learn on differences
        model.LQR_simulate(X0=pandaRobot.ref[fold,:,0])
        
#         loss_traj[fold] = model.RMSE(X_pred=model.X_traj, X_true=pandaRobot.X[fold,:,:]) 
        loss_LQR[fold] = model.RMSE(X_pred=torch.tensor(model.LQR_X[:7,:],dtype=torch.float), 
                                    X_true=torch.tensor(pandaRobot.ref[fold,:7,:],dtype=torch.float))
        loss_U[fold] = model.RMSE(X_pred=model.LQR_U[0,:,:].T, 
                                  X_true=pandaRobot.U[fold,:,:])
        
        timing[1,fold] = time.time() - timing[1,fold]  
        
    loss_LQR_sum = loss_LQR.sum()/n_training
    loss_U_sum = loss_U.sum()/n_training
    loss = loss_LQR_sum + loss_U_sum
    avg_time = [timing[0,:].sum()/n_training,timing[1,:].sum()/n_training]
    
    if np.isnan(loss) or np.isinf(loss):
        loss = 1e10
        
    print('Total loss : '+str(loss)+'Loss LQR : '+str(loss_LQR_sum)+'Loss U : '+str(loss_U_sum)+
          ', u_std : '+str(u_std)+', s :'+str(s)+', n :'+str(n)+', d : '+str(d))
    print('Avg computation time for HAVOK : '+str(avg_time[0])+' [s], for LQR : '+str(avg_time[1])+' [s]')
    
    return loss

max_iter = 1000
batch_size = 6
num_cores = 6

opt = GPyOpt.methods.BayesianOptimization(f = loss,            # function to optimize       
                                          domain = domain,         # box-constraints of the problem
                                          acquisition_type ='LCB',       # LCB acquisition
                                          acquisition_weight = 0.5)     # Exploration exploitation
 

opt.run_optimization(max_iter)
# Out:
# delay max :  122
# points min :  360
# Total loss : 878.0587219698015Loss LQR : 85.54727172851562Loss U : 792.5114502412858, u_std : 1.1819298646043066, s :6, n :116, d : 98
# Avg computation time for HAVOK : 2.4895357131958007 [s], for LQR : 1.5680036067962646 [s]
# Total loss : 1020.5590626135731Loss LQR : 74.77944488525391Loss U : 945.7796177283192, u_std : 1.1046432232273249, s :59, n :80, d : 47
# Avg computation time for HAVOK : 8.431049966812134 [s], for LQR : 9.888149309158326 [s]
# Total loss : 2352.109443954925Loss LQR : 74.24984512329101Loss U : 2277.8595988316342, u_std : 0.3153162702150438, s :48, n :35, d : 23
# Avg computation time for HAVOK : 2.987214374542236 [s], for LQR : 5.04617919921875 [s]
# Total loss : 1136.1456009733427Loss LQR : 83.95902557373047Loss U : 1052.1865753996121, u_std : 0.9701750713640199, s :33, n :96, d : 10
# Avg computation time for HAVOK : 14.181917762756347 [s], for LQR : 2.2511774063110352 [s]
# Total loss : 665.0363926905122Loss LQR : 86.19512939453125Loss U : 578.841263295981, u_std : 2.134828304934791, s :73, n :23, d : 98
# Avg computation time for HAVOK : 2.4574318408966063 [s], for LQR : 27.83255624771118 [s]
# Total loss : 824.0173595163905Loss LQR : 84.91777801513672Loss U : 739.0995815012537, u_std : 1.2455470996223175, s :6, n :115, d : 98
# Avg computation time for HAVOK : 2.657685089111328 [s], for LQR : 1.6033108711242676 [s]
# Total loss : 407.6645863011044Loss LQR : 90.30647583007813Loss U : 317.3581104710263, u_std : 1.9151237980688667, s :6, n :104, d : 98
# Avg computation time for HAVOK : 3.2243773460388185 [s], for LQR : 1.5496524810791015 [s]
# Total loss : 227.14999883689893Loss LQR : 90.67227478027344Loss U : 136.4777240566255, u_std : 3.0, s :12, n :95, d : 99
# Avg computation time for HAVOK : 3.6530282974243162 [s], for LQR : 1.6477919101715088 [s]
# Total loss : 210.45358258988855Loss LQR : 94.30653381347656Loss U : 116.14704877641199, u_std : 3.0, s :5, n :83, d : 103
# Avg computation time for HAVOK : 3.734411525726318 [s], for LQR : 1.5622204303741456 [s]
# Total loss : 212.43741536315073Loss LQR : 92.33783874511718Loss U : 120.09957661803355, u_std : 3.0, s :7, n :86, d : 89
# Avg computation time for HAVOK : 4.772640180587769 [s], for LQR : 1.5508449077606201 [s]
# Total loss : 2441.295875026965Loss LQR : 81.60260772705078Loss U : 2359.693267299914, u_std : 0.0, s :17, n :83, d : 99
# Avg computation time for HAVOK : 4.0168561935424805 [s], for LQR : 1.7910080432891846 [s]
# Total loss : 218.87723297103707Loss LQR : 90.84520416259765Loss U : 128.0320288084394, u_std : 3.0, s :7, n :94, d : 97
# Avg computation time for HAVOK : 4.131748390197754 [s], for LQR : 1.6274455547332765 [s]
# Total loss : 215.53221267282544Loss LQR : 94.72977752685547Loss U : 120.80243514596998, u_std : 3.0, s :5, n :88, d : 93
# Avg computation time for HAVOK : 4.276759004592895 [s], for LQR : 1.5524473667144776 [s]
# Total loss : 209.89336249795417Loss LQR : 94.55840911865235Loss U : 115.33495337930181, u_std : 3.0, s :5, n :92, d : 105
# Avg computation time for HAVOK : 3.306355857849121 [s], for LQR : 1.5548407554626464 [s]
# Total loss : 210.38692891554513Loss LQR : 95.40500946044922Loss U : 114.98191945509589, u_std : 3.0, s :5, n :89, d : 84
# Avg computation time for HAVOK : 5.155410194396973 [s], for LQR : 1.5572337627410888 [s]
# Total loss : 226.43462660218833Loss LQR : 93.73766174316407Loss U : 132.69696485902426, u_std : 3.0, s :12, n :100, d : 102
# Avg computation time for HAVOK : 3.2317550659179686 [s], for LQR : 1.6302398681640624 [s]
# Total loss : 204.25582992897802Loss LQR : 95.27462310791016Loss U : 108.98120682106787, u_std : 3.0, s :5, n :82, d : 85
# Avg computation time for HAVOK : 5.053676271438599 [s], for LQR : 1.5518482685089112 [s]
# Total loss : 271.6349963026026Loss LQR : 96.1195556640625Loss U : 175.51544063854007, u_std : 3.0, s :13, n :100, d : 93
# Avg computation time for HAVOK : 4.178217983245849 [s], for LQR : 1.6374196529388427 [s]
# Total loss : 208.40628098858195Loss LQR : 95.36074829101562Loss U : 113.04553269756634, u_std : 3.0, s :5, n :86, d : 88
# Avg computation time for HAVOK : 4.832872676849365 [s], for LQR : 1.540478563308716 [s]
# Total loss : 237.00206694379472Loss LQR : 88.55133361816407Loss U : 148.45073332563067, u_std : 3.0, s :9, n :85, d : 73
# Avg computation time for HAVOK : 6.239509534835816 [s], for LQR : 1.6150792598724366 [s]
# Total loss : 227.92862167209856Loss LQR : 89.75414276123047Loss U : 138.1744789108681, u_std : 3.0, s :12, n :92, d : 79
# Avg computation time for HAVOK : 5.837783622741699 [s], for LQR : 1.840477180480957 [s]
# Total loss : 215.89034212613075Loss LQR : 93.12825775146484Loss U : 122.76208437466589, u_std : 3.0, s :5, n :71, d : 71
# Avg computation time for HAVOK : 5.940310716629028 [s], for LQR : 1.7489208698272705 [s]
# Total loss : 216.42891068193813Loss LQR : 94.75264892578124Loss U : 121.67626175615688, u_std : 3.0, s :5, n :71, d : 57
# Avg computation time for HAVOK : 6.717232418060303 [s], for LQR : 1.607100534439087 [s]
# Total loss : 212.4557613524015Loss LQR : 94.86346893310547Loss U : 117.59229241929604, u_std : 3.0, s :5, n :57, d : 61
# Avg computation time for HAVOK : 5.129677772521973 [s], for LQR : 1.5370885372161864 [s]
# Total loss : 1504.450729186345Loss LQR : 88.40785064697266Loss U : 1416.0428785393722, u_std : 0.0, s :5, n :60, d : 48
# Avg computation time for HAVOK : 5.874884796142578 [s], for LQR : 1.5807717800140382 [s]
# Total loss : 222.62996254865783Loss LQR : 93.22864227294922Loss U : 129.40132027570863, u_std : 3.0, s :5, n :54, d : 71
# Avg computation time for HAVOK : 4.450695276260376 [s], for LQR : 1.571195936203003 [s]
# Total loss : 217.10064445893732Loss LQR : 94.65184020996094Loss U : 122.44880424897637, u_std : 3.0, s :5, n :64, d : 65
# Avg computation time for HAVOK : 5.523220252990723 [s], for LQR : 1.5789756774902344 [s]
# Total loss : 221.826258141474Loss LQR : 93.63095550537109Loss U : 128.19530263610292, u_std : 3.0, s :5, n :82, d : 59
# Avg computation time for HAVOK : 7.186374044418335 [s], for LQR : 1.5494540691375733 [s]
# Total loss : 204.64572078481893Loss LQR : 94.42425079345703Loss U : 110.22146999136189, u_std : 3.0, s :5, n :42, d : 67
# Avg computation time for HAVOK : 2.3160047054290773 [s], for LQR : 1.5600270748138427 [s]
# Total loss : 204.22636437875633Loss LQR : 94.01638488769531Loss U : 110.20997949106103, u_std : 3.0, s :5, n :22, d : 78
# Avg computation time for HAVOK : 1.5494575500488281 [s], for LQR : 1.5534422874450684 [s]
# Total loss : 206.0025152792028Loss LQR : 93.62089233398437Loss U : 112.38162294521844, u_std : 3.0, s :5, n :15, d : 93
# Avg computation time for HAVOK : 1.1852296829223632 [s], for LQR : 1.5853584289550782 [s]
# Total loss : 223.43322491871334Loss LQR : 88.82253875732422Loss U : 134.6106861613891, u_std : 3.0, s :18, n :15, d : 84
# Avg computation time for HAVOK : 1.1874252319335938 [s], for LQR : 1.7563005447387696 [s]
# Total loss : 236.21384034145618Loss LQR : 92.03490600585937Loss U : 144.1789343355968, u_std : 3.0, s :11, n :28, d : 90
# Avg computation time for HAVOK : 2.470790958404541 [s], for LQR : 1.6529780864715575 [s]
# Total loss : 3641.805339157633Loss LQR : 77.99053955078125Loss U : 3563.814799606852, u_std : 0.0, s :18, n :15, d : 102
# Avg computation time for HAVOK : 1.146932029724121 [s], for LQR : 1.7040413856506347 [s]
# Total loss : 232.17723432379648Loss LQR : 83.41663818359375Loss U : 148.76059614020272, u_std : 3.0, s :21, n :15, d : 72
# Avg computation time for HAVOK : 1.207763910293579 [s], for LQR : 1.8125508308410645 [s]
# Total loss : 205.81429862155642Loss LQR : 93.6626480102539Loss U : 112.15165061130253, u_std : 3.0, s :5, n :15, d : 85
# Avg computation time for HAVOK : 1.1876227378845214 [s], for LQR : 1.5552398204803466 [s]
# Total loss : 239.56111532944863Loss LQR : 93.87828521728515Loss U : 145.68283011216346, u_std : 3.0, s :16, n :28, d : 78
# Avg computation time for HAVOK : 2.4759836196899414 [s], for LQR : 1.5518417358398438 [s]
# Total loss : 205.41564484010672Loss LQR : 94.62852325439454Loss U : 110.7871215857122, u_std : 3.0, s :5, n :31, d : 87
# Avg computation time for HAVOK : 1.7850253582000732 [s], for LQR : 1.5516494274139405 [s]
# Total loss : 12172.004503292199Loss LQR : 1115.4774047851563Loss U : 11056.527098507042, u_std : 3.0, s :99, n :119, d : 121
# Avg computation time for HAVOK : 1.4263857841491698 [s], for LQR : 42.324583005905154 [s]
# Total loss : 302.304270945246Loss LQR : 75.78601379394532Loss U : 226.5182571513007, u_std : 3.0, s :99, n :15, d : 61
# Avg computation time for HAVOK : 2.7951238632202147 [s], for LQR : 51.05157842636108 [s]
# Total loss : 213.94157278991648Loss LQR : 96.18900604248047Loss U : 117.752566747436, u_std : 3.0, s :5, n :62, d : 1
# Avg computation time for HAVOK : 9.639615535736084 [s], for LQR : 2.0140114784240724 [s]
# Total loss : 289.216550415779Loss LQR : 90.02701721191406Loss U : 199.18953320386498, u_std : 3.0, s :72, n :30, d : 73
# Avg computation time for HAVOK : 2.799312925338745 [s], for LQR : 37.08249878883362 [s]
# Total loss : 339.794250309233Loss LQR : 91.06185302734374Loss U : 248.7323972818893, u_std : 3.0, s :99, n :15, d : 106
# Avg computation time for HAVOK : 2.3441418647766112 [s], for LQR : 42.16760287284851 [s]
# Total loss : 267.4433524343556Loss LQR : 86.10038452148437Loss U : 181.34296791287122, u_std : 3.0, s :30, n :72, d : 30
# Avg computation time for HAVOK : 7.3913225650787355 [s], for LQR : 1.8974909782409668 [s]
# Total loss : 297.73066714538265Loss LQR : 71.36250915527344Loss U : 226.36815799010918, u_std : 3.0, s :99, n :88, d : 1
# Avg computation time for HAVOK : 13.818454217910766 [s], for LQR : 41.9052517414093 [s]
# Total loss : 279.25532636119317Loss LQR : 97.91873931884766Loss U : 181.33658704234554, u_std : 3.0, s :5, n :15, d : 1
# Avg computation time for HAVOK : 1.3878275871276855 [s], for LQR : 1.5099947452545166 [s]
# Total loss : 276.86971415740896Loss LQR : 84.67348556518554Loss U : 192.1962285922234, u_std : 3.0, s :79, n :15, d : 89
# Avg computation time for HAVOK : 2.2390053272247314 [s], for LQR : 39.75505690574646 [s]
# Total loss : 252.96340425996559Loss LQR : 61.376947021484376Loss U : 191.58645723848122, u_std : 3.0, s :99, n :15, d : 1
# Avg computation time for HAVOK : 2.618603563308716 [s], for LQR : 40.58758554458618 [s]
# Total loss : 269.7251362879863Loss LQR : 75.25525283813477Loss U : 194.46988344985152, u_std : 3.0, s :99, n :55, d : 1
# Avg computation time for HAVOK : 8.078643321990967 [s], for LQR : 41.76720881462097 [s]
# Total loss : 302.265332285759Loss LQR : 91.6738052368164Loss U : 210.59152704894254, u_std : 3.0, s :84, n :38, d : 95
# Avg computation time for HAVOK : 4.4548835277557375 [s], for LQR : 41.08330416679382 [s]
# Total loss : 217.75410804694303Loss LQR : 93.85657196044922Loss U : 123.8975360864938, u_std : 3.0, s :5, n :48, d : 26
# Avg computation time for HAVOK : 6.786781692504883 [s], for LQR : 1.5357064723968505 [s]
# Total loss : 206.68790180367986Loss LQR : 91.45527801513671Loss U : 115.23262378854315, u_std : 3.0, s :5, n :111, d : 103
# Avg computation time for HAVOK : 2.2816969871521 [s], for LQR : 1.54107723236084 [s]
# Total loss : 304.04605403760627Loss LQR : 94.93777160644531Loss U : 209.10828243116097, u_std : 3.0, s :67, n :28, d : 100
# Avg computation time for HAVOK : 3.143566846847534 [s], for LQR : 26.765371894836427 [s]
# Total loss : 216.6858302815206Loss LQR : 93.88532257080078Loss U : 122.80050771071981, u_std : 3.0, s :5, n :119, d : 74
# Avg computation time for HAVOK : 5.775021171569824 [s], for LQR : 1.5005808353424073 [s]
# Total loss : 313.1944590842643Loss LQR : 95.9468765258789Loss U : 217.24758255838537, u_std : 3.0, s :99, n :56, d : 32
# Avg computation time for HAVOK : 7.013123941421509 [s], for LQR : 41.68474869728088 [s]
# Total loss : 220.74423614512813Loss LQR : 93.60424194335937Loss U : 127.13999420176876, u_std : 3.0, s :5, n :107, d : 91
# Avg computation time for HAVOK : 3.7196856498718263 [s], for LQR : 1.4824348449707032 [s]
# Total loss : 257.44101184529836Loss LQR : 86.51410827636718Loss U : 170.9269035689312, u_std : 3.0, s :37, n :98, d : 45
# Avg computation time for HAVOK : 9.262622976303101 [s], for LQR : 2.3449275493621826 [s]
# Total loss : 204.70150705902915Loss LQR : 93.71316833496094Loss U : 110.9883387240682, u_std : 3.0, s :5, n :15, d : 69
# Avg computation time for HAVOK : 1.2163474559783936 [s], for LQR : 1.5161427021026612 [s]
# Total loss : 215.57354100785483Loss LQR : 94.23698272705079Loss U : 121.33655828080404, u_std : 3.0, s :5, n :68, d : 33
# Avg computation time for HAVOK : 7.400005531311035 [s], for LQR : 1.5566357135772706 [s]
# Total loss : 342.0302547158608Loss LQR : 102.23594970703125Loss U : 239.79430500882955, u_std : 3.0, s :99, n :22, d : 86
# Avg computation time for HAVOK : 2.763402223587036 [s], for LQR : 42.41195034980774 [s]
# Total loss : 241.93888609648272Loss LQR : 83.80063018798828Loss U : 158.13825590849444, u_std : 3.0, s :36, n :73, d : 50
# Avg computation time for HAVOK : 6.835715293884277 [s], for LQR : 2.2392099380493162 [s]
# Total loss : 245.83747331735213Loss LQR : 83.8116683959961Loss U : 162.02580492135604, u_std : 3.0, s :71, n :84, d : 21
# Avg computation time for HAVOK : 11.176903867721558 [s], for LQR : 34.37664275169372 [s]
# Total loss : 208.92343568511876Loss LQR : 93.87456512451172Loss U : 115.04887056060704, u_std : 3.0, s :5, n :106, d : 97
# Avg computation time for HAVOK : 3.023511362075806 [s], for LQR : 1.3968847274780274 [s]
# Total loss : 208.74863060731582Loss LQR : 94.26711578369141Loss U : 114.4815148236244, u_std : 3.0, s :5, n :104, d : 99
# Avg computation time for HAVOK : 2.8519246101379396 [s], for LQR : 1.388580560684204 [s]
# Total loss : 212.58551098987238Loss LQR : 94.14946746826172Loss U : 118.43604352161064, u_std : 3.0, s :5, n :58, d : 44
# Avg computation time for HAVOK : 5.366067266464233 [s], for LQR : 1.4122394561767577 [s]
# Total loss : 205.23718004473236Loss LQR : 97.25506134033203Loss U : 107.98211870440032, u_std : 3.0, s :5, n :43, d : 1
# Avg computation time for HAVOK : 3.3306033611297607 [s], for LQR : 1.5380160331726074 [s]
# Total loss : 306.83149983761757Loss LQR : 87.17904815673828Loss U : 219.65245168087927, u_std : 3.0, s :80, n :24, d : 96
# Avg computation time for HAVOK : 2.5106849193573 [s], for LQR : 38.83192639350891 [s]
# Total loss : 205.26855783016453Loss LQR : 93.62829284667968Loss U : 111.64026498348483, u_std : 3.0, s :5, n :20, d : 78
# Avg computation time for HAVOK : 4.12835054397583 [s], for LQR : 1.51714129447937 [s]
# Total loss : 211.883301766695Loss LQR : 93.8416976928711Loss U : 118.04160407382392, u_std : 3.0, s :5, n :62, d : 44
# Avg computation time for HAVOK : 6.04044246673584 [s], for LQR : 1.5081655025482177 [s]
# Total loss : 292.3434309597228Loss LQR : 92.11774597167968Loss U : 200.2256849880431, u_std : 3.0, s :67, n :32, d : 87
# Avg computation time for HAVOK : 2.526236343383789 [s], for LQR : 28.118184804916382 [s]
# Total loss : 208.91200867943002Loss LQR : 93.87466278076172Loss U : 115.03734589866829, u_std : 3.0, s :5, n :106, d : 97
# Avg computation time for HAVOK : 3.11167049407959 [s], for LQR : 1.4249876022338868 [s]
# Total loss : 286.89288026270134Loss LQR : 71.33584213256836Loss U : 215.55703813013298, u_std : 3.0, s :99, n :72, d : 1
# Avg computation time for HAVOK : 10.88368263244629 [s], for LQR : 41.29070239067077 [s]
# Total loss : 249.41822814662243Loss LQR : 84.06247406005859Loss U : 165.35575408656382, u_std : 3.0, s :53, n :82, d : 37
# Avg computation time for HAVOK : 8.822410106658936 [s], for LQR : 7.66598687171936 [s]
# Total loss : 205.64701922760366Loss LQR : 93.49789276123047Loss U : 112.14912646637318, u_std : 3.0, s :5, n :19, d : 80
# Avg computation time for HAVOK : 2.415805625915527 [s], for LQR : 1.3848284244537354 [s]
# Total loss : 206.69333992546802Loss LQR : 94.52996520996093Loss U : 112.16337471550708, u_std : 3.0, s :5, n :103, d : 99
# Avg computation time for HAVOK : 3.1798941135406493 [s], for LQR : 1.5330990314483643 [s]
# Total loss : 270.1372759935819Loss LQR : 93.69381256103516Loss U : 176.44346343254674, u_std : 3.0, s :18, n :117, d : 70
# Avg computation time for HAVOK : 6.508148097991944 [s], for LQR : 1.7740506172180175 [s]
# Total loss : 208.90001625153855Loss LQR : 94.64475708007812Loss U : 114.25525917146044, u_std : 3.0, s :5, n :103, d : 98
# Avg computation time for HAVOK : 3.4950541973114015 [s], for LQR : 1.6912726879119873 [s]
# Total loss : 206.69912705953027Loss LQR : 94.52958068847656Loss U : 112.16954637105371, u_std : 3.0, s :5, n :103, d : 99
# Avg computation time for HAVOK : 3.2171870708465575 [s], for LQR : 1.6003199577331544 [s]
# Total loss : 207.44388635548324Loss LQR : 94.72386322021484Loss U : 112.72002313526839, u_std : 3.0, s :5, n :102, d : 99
# Avg computation time for HAVOK : 3.2776325225830076 [s], for LQR : 1.5833648204803468 [s]
# Total loss : 208.2887179073282Loss LQR : 93.79375305175782Loss U : 114.49496485557037, u_std : 3.0, s :5, n :21, d : 82
# Avg computation time for HAVOK : 1.4341646671295165 [s], for LQR : 1.5328982830047608 [s]
# Total loss : 215.04604386408488Loss LQR : 91.92391357421874Loss U : 123.12213028986612, u_std : 3.0, s :5, n :119, d : 28
# Avg computation time for HAVOK : 14.593762969970703 [s], for LQR : 1.5819681644439698 [s]
# Total loss : 226.7001370256657Loss LQR : 96.03167266845703Loss U : 130.66846435720865, u_std : 3.0, s :5, n :119, d : 121
# Avg computation time for HAVOK : 0.17732009887695313 [s], for LQR : 1.5995209693908692 [s]
# Total loss : 440.5192028530367Loss LQR : 99.64492340087891Loss U : 340.8742794521578, u_std : 3.0, s :13, n :119, d : 49
# Avg computation time for HAVOK : 10.4757719039917 [s], for LQR : 1.6783108234405517 [s]
# Total loss : 216.79225327243978Loss LQR : 96.48407897949218Loss U : 120.3081742929476, u_std : 3.0, s :5, n :119, d : 1
# Avg computation time for HAVOK : 20.92782006263733 [s], for LQR : 1.5799731731414794 [s]
# Total loss : 5197.020546022433Loss LQR : 89.24009780883789Loss U : 5107.780448213595, u_std : 3.0, s :79, n :119, d : 1
# Avg computation time for HAVOK : 21.16993899345398 [s], for LQR : 38.0844925403595 [s]
# Total loss : 226.44565338330804Loss LQR : 91.3321746826172Loss U : 135.11347870069085, u_std : 3.0, s :5, n :98, d : 7
# Avg computation time for HAVOK : 13.992392253875732 [s], for LQR : 1.392753505706787 [s]
# Total loss : 308.7368313100907Loss LQR : 85.74234466552734Loss U : 222.99448664456335, u_std : 3.0, s :99, n :83, d : 25
# Avg computation time for HAVOK : 10.868113946914672 [s], for LQR : 41.38129725456238 [s]
# Total loss : 256.7126242453628Loss LQR : 83.07921142578125Loss U : 173.63341281958157, u_std : 3.0, s :78, n :69, d : 28
# Avg computation time for HAVOK : 8.521632671356201 [s], for LQR : 42.763868761062625 [s]
# Total loss : 340.6631835468706Loss LQR : 87.64043579101562Loss U : 253.02274775585497, u_std : 3.0, s :22, n :89, d : 44
# Avg computation time for HAVOK : 8.107330083847046 [s], for LQR : 1.6776169776916503 [s]
# Total loss : 357.23945340986984Loss LQR : 101.78428192138672Loss U : 255.45517148848313, u_std : 3.0, s :99, n :46, d : 64
# Avg computation time for HAVOK : 5.194445705413818 [s], for LQR : 42.83997859954834 [s]
# Total loss : 204.85345908061413Loss LQR : 94.14715118408203Loss U : 110.70630789653208, u_std : 3.0, s :5, n :15, d : 32
# Avg computation time for HAVOK : 1.2064934730529786 [s], for LQR : 1.356604242324829 [s]
# Total loss : 288.0885101980554Loss LQR : 80.7042007446289Loss U : 207.3843094534265, u_std : 3.0, s :99, n :26, d : 21
# Avg computation time for HAVOK : 3.1850781440734863 [s], for LQR : 43.229020500183104 [s]
# Total loss : 292.6375432724093Loss LQR : 88.95668182373046Loss U : 203.6808614486788, u_std : 3.0, s :59, n :15, d : 76
# Avg computation time for HAVOK : 1.8161489486694335 [s], for LQR : 15.737508583068848 [s]
# Total loss : 14366.859729860922Loss LQR : 104.68650970458984Loss U : 14262.173220156332, u_std : 3.0, s :56, n :70, d : 1
# Avg computation time for HAVOK : 10.128506755828857 [s], for LQR : 12.626825094223022 [s]
# Total loss : 270.12052289860424Loss LQR : 84.00732727050782Loss U : 186.1131956280964, u_std : 3.0, s :34, n :115, d : 22
# Avg computation time for HAVOK : 15.268164730072021 [s], for LQR : 2.3181930065155028 [s]
# Total loss : 279.9973278758305Loss LQR : 79.58171997070312Loss U : 200.4156079051274, u_std : 3.0, s :50, n :15, d : 39
# Avg computation time for HAVOK : 1.794001293182373 [s], for LQR : 6.293165874481201 [s]
# Total loss : 237.46325574065273Loss LQR : 83.43438110351562Loss U : 154.0288746371371, u_std : 3.0, s :74, n :93, d : 30
# Avg computation time for HAVOK : 11.465732622146607 [s], for LQR : 37.89489126205444 [s]
# Total loss : 224.22019996886632Loss LQR : 87.3794189453125Loss U : 136.84078102355383, u_std : 3.0, s :41, n :41, d : 46
# Avg computation time for HAVOK : 2.40818567276001 [s], for LQR : 3.202673149108887 [s]
# Total loss : 256.343965200616Loss LQR : 85.33156127929688Loss U : 171.01240392131916, u_std : 3.0, s :27, n :100, d : 23
# Avg computation time for HAVOK : 12.276612663269043 [s], for LQR : 2.035550355911255 [s]
# Total loss : 3008.5892646257594Loss LQR : 73.19290771484376Loss U : 2935.3963569109155, u_std : 0.0, s :99, n :75, d : 14
# Avg computation time for HAVOK : 10.764549350738525 [s], for LQR : 42.8971809387207 [s]
# Total loss : 266.84286474967143Loss LQR : 85.05777130126953Loss U : 181.78509344840188, u_std : 3.0, s :81, n :68, d : 44
# Avg computation time for HAVOK : 7.519946718215943 [s], for LQR : 40.516527605056766 [s]
# Total loss : 233.6489001097462Loss LQR : 82.3309555053711Loss U : 151.3179446043751, u_std : 3.0, s :77, n :81, d : 31
# Avg computation time for HAVOK : 9.805077362060548 [s], for LQR : 43.35253486633301 [s]
# Total loss : 284.45144654462695Loss LQR : 86.4833740234375Loss U : 197.9680725211894, u_std : 3.0, s :73, n :43, d : 42
# Avg computation time for HAVOK : 3.4543825149536134 [s], for LQR : 35.57501473426819 [s]
# Total loss : 287.19728560201696Loss LQR : 86.75389556884765Loss U : 200.4433900331693, u_std : 3.0, s :28, n :15, d : 28
# Avg computation time for HAVOK : 1.3059146881103516 [s], for LQR : 1.7465200901031495 [s]
# Total loss : 253.53842441725186Loss LQR : 84.06186065673828Loss U : 169.47656376051359, u_std : 3.0, s :51, n :101, d : 24
# Avg computation time for HAVOK : 13.098351097106933 [s], for LQR : 8.182801961898804 [s]
# Total loss : 265.2468807028077Loss LQR : 90.45671691894532Loss U : 174.79016378386237, u_std : 3.0, s :23, n :113, d : 8
# Avg computation time for HAVOK : 17.948189067840577 [s], for LQR : 1.90929274559021 [s]
# Total loss : 237.75200700152766Loss LQR : 84.55441741943359Loss U : 153.19758958209405, u_std : 3.0, s :63, n :61, d : 44
# Avg computation time for HAVOK : 6.90453085899353 [s], for LQR : 20.076097345352174 [s]
# Total loss : 319.6475370312116Loss LQR : 91.32159729003907Loss U : 228.32593974117253, u_std : 3.0, s :22, n :61, d : 39
# Avg computation time for HAVOK : 6.2770094871521 [s], for LQR : 1.8203304290771485 [s]
# Total loss : 238.39153018105338Loss LQR : 81.7971694946289Loss U : 156.5943606864245, u_std : 3.0, s :40, n :28, d : 36
# Avg computation time for HAVOK : 3.0829529762268066 [s], for LQR : 2.403570365905762 [s]
# Total loss : 223.62059954406985Loss LQR : 93.06549072265625Loss U : 130.5551088214136, u_std : 3.0, s :5, n :72, d : 12
# Avg computation time for HAVOK : 9.47705020904541 [s], for LQR : 1.7618863582611084 [s]
# Total loss : 239.66911463056292Loss LQR : 83.4936508178711Loss U : 156.17546381269182, u_std : 3.0, s :78, n :91, d : 22
# Avg computation time for HAVOK : 12.248691320419312 [s], for LQR : 38.90702176094055 [s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-5871f73ebb48> in <module>
#      78
#      79
# ---> 80 opt.run_optimization(max_iter)
#
# ~\anaconda3\lib\site-packages\GPyOpt\core\bo.py in run_optimization(self, max_iter, max_time, eps, context, verbosity, save_models_parameters, report_file, evaluations_file, models_file)
#     149
#     150             # --- Evaluate *f* in X, augment Y and update cost function (if needed)
# --> 151             self.evaluate_objective()
#     152
#     153             # --- Update current evaluation time and function evaluations
#
# ~\anaconda3\lib\site-packages\GPyOpt\core\bo.py in evaluate_objective(self)
#     195         Evaluates the objective
#     196         """
# --> 197         self.Y_new, cost_new = self.objective.evaluate(self.suggested_sample)
#     198         self.cost.update_cost_model(self.suggested_sample, cost_new)
#     199         self.Y = np.vstack((self.Y,self.Y_new))
#
# ~\anaconda3\lib\site-packages\GPyOpt\core\task\objective.py in evaluate(self, x)
#      48
#      49         if self.n_procs == 1:
# ---> 50             f_evals, cost_evals = self._eval_func(x)
#      51         else:
#      52             try:
#
# ~\anaconda3\lib\site-packages\GPyOpt\core\task\objective.py in _eval_func(self, x)
#      72         for i in range(x.shape[0]):
#      73             st_time    = time.time()
# ---> 74             rlt = self.func(np.atleast_2d(x[i]))
#      75             f_evals     = np.vstack([f_evals,rlt])
#      76             cost_evals += [time.time()-st_time]
#
# <ipython-input-13-5871f73ebb48> in loss(space)
#      44         # LQR loss ##############################
#      45         model.ConstructLQR(x_std=1e6*np.ones(pandaRobot.nb_S), u_std=u_std, dt=dt, ref=pandaRobot.ref[fold,:,:]) # To learn on differences
# ---> 46         model.LQR_simulate(X0=pandaRobot.ref[fold,:,0])
#      47
#      48 #         loss_traj[fold] = model.RMSE(X_pred=model.X_traj, X_true=pandaRobot.X[fold,:,:])
#
# ~\OneDrive\Documents\Mécanique - EPFL\Master III\Semester project\Software\My code\Subspace-learning-for-robot-application\LQR simulation\Utils\Functions.py in LQR_simulate(self, X0)
#     490 #         Y0[0,:] = np.concatenate((self.Y[:,0],np.ones([1])))
#     491
# --> 492         ys, self.LQR_U = self.LQR.make_rollout(Y0)
#     493         xs = self.C@ys[0,:,:].T # Map back to original space
#     494         self.LQR_X = xs
#
# c:\users\cedri\onedrive\documents\mécanique - epfl\master iii\semester project\software\my code\subspace-learning-for-robot-application\pbdlib-python\pbdlib\poglqr.py in make_rollout(self, x0)
#     429             A = self.get_A(i)
#     430
# --> 431             next_us = self.get_command(xs[i], i)
#     432             next_xs = np.einsum('ij,aj->ai', A, xs[i]) + np.einsum('ij,aj->ai', B, next_us)
#     433             xs[i+1] = next_xs
#
# c:\users\cedri\onedrive\documents\mécanique - epfl\master iii\semester project\software\my code\subspace-learning-for-robot-application\pbdlib-python\pbdlib\poglqr.py in get_command(self, xi, i)
#     321             return -self._K[i].dot(xi) + self._Kv[i].dot(self._v[i+1])
#     322         else:
# --> 323             return np.einsum('ij,aj->ai', -self.K[i], xi) + self._Kv[i].dot(self._v[i + 1])
#     324
#     325     def policy(self, xi, t):
#
# KeyboardInterrupt:

# %% [markdown]
# ## LQR control of the Panda robot
# ### Construct LQR planner

# %%
# Train linear model
traj = 0

n = 15
r = 68
d = 1
u_std = 3.0

model = HAVOK(pandaRobot.dX[traj,:,:], pandaRobot.dU[traj,:,:], learnOnDiff=True)
model.HANKEL(n, d)
model.SVD(r)
model.LS(r,rcond=0)
model.Simulate(pandaRobot.X[traj,:,0], U_testing = pandaRobot.U[traj,:])

loss_traj_train = model.RMSE(X_pred=model.X_traj, X_true=pandaRobot.X[traj,:,:])
print('Forward prediction RMSE : '+str(loss_traj_train))

# Train LQR controller
model.ConstructLQR(x_std=1e6*np.ones(pandaRobot.nb_S), u_std=u_std, dt=dt, ref=pandaRobot.ref[traj,:,:]) # To learn on differences
model.LQR_simulate(X0=pandaRobot.ref[traj,:,0])

loss_LQR_subspace = model.RMSE(X_pred=torch.tensor(model.LQR_X[:7,:]), 
                                    X_true=torch.tensor(pandaRobot.ref[traj,:7,:]))
print('LQR RMSE : '+str(loss_LQR_subspace))

# plt.rcParams['font.size'] = 20
# fig, ax = plt.subplots(1, 2, constrained_layout = True, figsize=(18,8))

# figA = snb.heatmap(model.A,cmap='Reds',ax=ax[0])
# figB = snb.heatmap(model.B,cmap='Reds',ax=ax[1])

plt.rcParams['font.size'] = 20
fig, ax = plt.subplots(7, 3, constrained_layout = True, figsize=(18,13))

for i in range(7):
    
    ax[i,0].plot(pandaRobot.T, rad2deg(model.LQR_X[i,:]), label='Joint '+str(i+1)+' pos.')
    ax[i,0].plot(pandaRobot.T, rad2deg(pandaRobot.ref[traj,i,:]), label='Pos. ref.')
    ax[i,1].plot(pandaRobot.T, rad2deg(model.LQR_X[7+i,:]), label='Joint '+str(i+1)+' vel.')
    ax[i,1].plot(pandaRobot.T, rad2deg(pandaRobot.X[traj,7+i,:]), label='Vel. CTC.')
    ax[i,2].plot(pandaRobot.T[:len(pandaRobot.T)-1], model.LQR_U[0,:,i], label='Joint '+str(i+1)+' torque LQR')
    ax[i,2].plot(pandaRobot.T[:len(pandaRobot.T)-1], pandaRobot.U[traj,i,:], label='Joint '+str(i+1)+' torque CTC')
    ax[i,0].set_ylabel('Pos. [deg]'), ax[i,1].set_ylabel('Vel. [deg/s]'), ax[i,2].set_ylabel('Torque [Nm]')
    ax[i,0].legend(), ax[i,1].legend(), ax[i,2].legend()
    
ax[6,0].set_xlabel('Time [s]'), ax[6,1].set_xlabel('Time [s]')
# Out:
# Forward prediction RMSE : tensor(nan)
# LQR RMSE : tensor(64.5608, dtype=torch.float64)
# (Text(0.5, 0, 'Time [s]'), Text(0.5, 0, 'Time [s]'))

# %% [markdown]
# ### Plot CTC trajectory

# %%
traj = 4
plt.rcParams['font.size'] = 20
fig, ax = plt.subplots(7, 3, constrained_layout = True, figsize=(18,11))

for i in range(7):
    
    ax[i,0].plot(pandaRobot.T, rad2deg(pandaRobot.X[traj,i,:]), label='Joint '+str(i+1)+' pos.')
    ax[i,0].plot(pandaRobot.T, rad2deg(pandaRobot.ref[traj,i,:]), label='Pos. ref.')
    ax[i,1].plot(pandaRobot.T, rad2deg(pandaRobot.X[traj,i+7,:]), label='Joint '+str(i+1)+' vel.')
    ax[i,1].plot(pandaRobot.T, rad2deg(pandaRobot.ref[traj,i+7,:]), label='Vel. ref.')
    ax[i,2].plot(pandaRobot.T[:len(pandaRobot.T)-1], pandaRobot.U[traj,i,:], label='Joint '+str(i+1)+' torque')
    ax[i,0].set_ylabel('Position [deg]'), ax[i,1].set_ylabel('Velocity [deg/s]'), ax[i,2].set_ylabel('Torque [Nm]')
    ax[i,0].legend(), ax[i,1].legend(), ax[i,2].legend()
    
ax[6,0].set_xlabel('Time [s]'), ax[6,1].set_xlabel('Time [s]')
# Out:
# (Text(0.5, 0, 'Time [s]'), Text(0.5, 0, 'Time [s]'))

# %% [markdown]
# ### Apply LQR planner onto real robot dynamics

# %%
X0 = pandaRobot.ref[traj,:,0]
Xc, Yc = np.zeros(shape=[model.nb_S,model.N]), np.zeros(shape=[model.tau,model.N])
Uc = np.empty(shape=[model.nb_U,model.N-1])

# Initial condition
Xc[:,0] = X0
# N = np.eye(model.tau) - pinv(model.C) @ model.C
Y0 = pinv(model.C)@X0
# Y0 = Y0 + N@(model.Y[:,0] - Y0) # Nullspace projection into subspace 
Yc[:,0] = Y0

robot.default_q = Xc[:7,0]
robot.reset_q(max_iter=100)
robot.joints_free=True

sum_error = np.zeros(7)

# Simulate the closed-loop trajectory for the non-linear dynamics
for i in range(model.N-1):

#   LQR planner control input
    control_input = model.LQR.get_command(Yc[:,i],i)

    robot.set_torque(control_input[:7])

    log_error.append(np.copy(error_q))
    Xc[0:7,i] = robot.q
    Xc[7:,i] = robot.dq
#     log_ddq[n,:,i] = robot.ddq
    Uc[:,i] = np.copy(control_input)
#     time.sleep(dt) # Real-time rendering
    sum_error += error_q*dt
    
    Yc[:,i+1] = pinv(model.C)@Xc[:,i+1]
    
loss_LQR_true = model.RMSE(X_pred=Xc[, 
                                    X_true=pandaRobot.ref[traj,:,:])
print('LQR RMSE : '+str(loss_LQR_true))
    
plt.rcParams['font.size'] = 20
fig,ax = plt.subplots(7, 3, constrained_layout = True, figsize=(18,13))

for i in range(7):
    
    ax[i,0].plot(pandaRobot.T, rad2deg(Xc[i,:]), label='Joint '+str(i+1)+' pos.')
    ax[i,0].plot(pandaRobot.T, rad2deg(pandaRobot.ref[traj,i,:]), label='Pos. ref.')
    ax[i,1].plot(pandaRobot.T, rad2deg(Xc[i+7,:]), label='Joint '+str(i+1)+' vel.')
    ax[i,1].plot(pandaRobot.T, rad2deg(pandaRobot.ref[traj,i+7,:]), label='Vel. ref.')
    ax[i,2].plot(pandaRobot.T[:len(pandaRobot.T)-1], Uc[i,:], label='Joint '+str(i+1)+' control')
    
    ax[i,0].set_ylabel('Position [deg]'), ax[i,1].set_ylabel('Velocity [deg/s]')
    ax[i,2].set_ylabel('Torque [Nm]')
    ax[i,0].legend(), ax[i,1].legend(), ax[i,2].legend()
    
ax[6,0].set_xlabel('Time [s]'), ax[6,1].set_xlabel('Time [s]')
# Out:
# C:\Users\cedri\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# joints are free now
# LQR RMSE : 497.4645270185171
# (Text(0.5, 0, 'Time [s]'), Text(0.5, 0, 'Time [s]'))

# %%
print(Xc[:,0],pandaRobot.ref[traj,:,0])
# Out:
# [ 1.92311 -0.84735  1.12334 -1.5787   1.15286 -0.00617 -1.87547  0.32676
#  -0.18946 -0.40925 -0.64609  0.71115 -0.24451 -1.27567] [-1.00575 -0.67185  1.75852 -0.44156 -1.78396  1.44367  0.94552  0.
#   0.       0.       0.       0.       0.       0.     ]
