# %% [markdown]
# # Hyperparameters search with Bayesian optimisation

# %%
import numpy as np
from numpy import random as rnd
from numpy.linalg import pinv
from numpy import linalg as lg
from scipy import linalg as slg
from importlib import reload
import seaborn as snb
import matplotlib.pyplot as plt
import Utils.Functions 
from Utils.Functions import *
import pbdlib as pbd
from scipy.linalg import hankel
from hyperopt import tpe, hp, fmin, STATUS_OK, Trials
import joblib
# %load_ext autoreload
# %autoreload 2
plt.style.use("default")
plt.rcParams['font.size'] = 13
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams['lines.linewidth'] = 2.5
np.set_printoptions(precision=5, suppress=False)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 1) Data gathering

# %%
###############################
N = 5000
dt = 1e-2
pi = np.pi
nb_parts = 100
n_training = 8
n_testing = 5
n_folds = n_training + n_testing
###############################
phi = rnd.uniform(low=-pi, high=pi, size=nb_parts)
f = rnd.uniform(low=.02, high=.2, size=nb_parts)*dt
A = rnd.uniform(low=-pi, high=pi, size=nb_parts)
###############################
time = np.arange(0,N,1)
t = np.arange(0,N*dt,dt)
pend = SimplePendulum(mass=1, length=1, time=time, X0=np.array([deg2rad(0),0]), dt=dt)
###############################
pend.ref = np.empty(shape=[n_folds,N])
for j in range(n_folds):
    x_train = 0
    phi = rnd.uniform(low=-pi, high=pi, size=nb_parts)
    f = rnd.uniform(low=.02, high=.15, size=nb_parts)*dt
    A = rnd.uniform(low=-pi, high=pi, size=nb_parts)
    for i in range(nb_parts):
        x_train = x_train + A[i]*np.sin(2*pi*f[i]*time + phi[i])
    x_train = x_train/max(max(x_train),-min(x_train))*pi
    pend.ref[j,:] = x_train
###############################
Kp, Ki, Kd = 50, 20, 5
pend.U = np.zeros(shape=[n_folds,N-1])
pend.X = np.zeros(shape=[n_folds,2,N])
###############################
for j in range(n_folds):
    pend.X[j,0,0] = pend.ref[j,0]
    for i in range(N-1):
        pend.U[j,i] = PID(pend.X[j,:,:], i, pend.ref[j,i], Kp, Kd, Ki, pend.dt, 20, limit=[-20,20])[0] 
        pend.X[j,:,i+1] = RK4(pend.dynamics, pend.X[j,:,i], pend.U[j,i], pend.dt, type='controller-step-by-step')
        
# Learn on differences ########
pend.dX = np.diff(pend.X, axis=2) # Delta X's
pend.dU = np.diff(pend.U, axis=1) # Delta U's

# %% [markdown]
# ## Hyperparameters tuning using *hyperopt*

# %%
# Hyperparameters space
traj_ratio = .02
n_low, n_high = 15,60
d_low, d_high = 1, np.int((1-traj_ratio)/n_high*pend.N)
print(pend.N- d_high*n_high)
print(d_high)
#######################################################
space = {
    "dimension": hp.quniform("dimension", 4, 15, 1),
    "nb_trajectories": hp.quniform("nb_trajectories", n_low, n_high, 1),
    "nb_delays": hp.quniform("nb_delays", d_low, d_high, 1),
}
#######################################################
loss_traj = np.empty(shape=[n_training])
loss_U = np.empty(shape=[n_training])
loss_LQR = np.empty(shape=[n_training])

# LQR simulation settings
model = SLFC(pend.X[0,:,:], pend.U[0,:]) # Initialize model paramters

f = lambda theta, u : pend.dynamics(theta, u)
u_max = [-15,15] # Limiting contol input size

t_interval = pend.dt

def hyperparameters_tuning(params):
    
    # Model parameters
    n = np.int(params["nb_trajectories"])
    d = np.int(params["nb_delays"])
    s = np.int(params["dimension"])
    
    for fold in range(n_training):
        model = HAVOK(pend.dX[fold,:,:], pend.dU[fold,:], learnOnDiff=True)
        model.HANKEL(n, d)
        model.SVD(s)
        model.LS(s,rcond=0)
#         model.Simulate(pend.X[fold,:,0],U_testing = pend.U[fold,:])
        model.Simulate(pend.X[fold,:,0],U_testing = pend.U[fold,:]) # Learn on differences
        
        # LQR loss ##############################
        Xc, X_lift = np.zeros(shape=[model.nb_S,model.N]), np.zeros(shape=[model.tau,model.N])
        Xc[:,0], X_lift[:,0] = pend.X[fold,:,0], pinv(model.C)@Xc[:,0]
        Uc = np.empty(shape=[model.N-1])
        
#         model.ConstructLQR(x_std=1e6, u_std=2., dt=pend.dt, ref=pend.ref[fold,:])
        model.ConstructLQR(x_std=1e6, u_std=2., dt=pend.dt, ref=pend.ref[fold,:]) # To learn on differences
        model.LQR_simulate(X0=pend.X[fold,:,0])
        
#         # Simulate the closed-loop trajectory for the non-linear dynamics
#         for i in range(model.N-1):

#             Uc[i] = (model.LQR.get_command(X_lift[:,i],i))
# #             Uc[i] = (model.C@model.LQR.get_command(X_lift[:,i],i))[1]
#             if Uc[i] >= u_max[1]: Uc[i] = u_max[1]
#             if Uc[i] <= u_max[0]: Uc[i] = u_max[0]

#             Xc[:,i+1]= RK4(f, Xc[:,i], Uc[i], t_interval, type='controller-step-by-step')
#             X_lift[:,i+1] = pinv(model.C)@Xc[:,i+1]
            
#         loss_traj[fold] = model.RMSE(X_pred=model.X_traj, X_true=pend.X[fold,:,:]) 
#         loss_LQR[fold] = model.RMSE(X_pred=Xc[0,:,np.newaxis].T, X_true=pend.ref[fold,:,np.newaxis].T)
        loss_traj[fold] = model.RMSE(X_pred=model.X_traj, X_true=pend.X[fold,:,:]) 
        loss_LQR[fold] = model.RMSE(X_pred=model.LQR_X[:,0,np.newaxis].T, X_true=pend.ref[fold,:,np.newaxis].T)
        loss_U[fold] = model.RMSE(X_pred=model.LQR_U[:,:,0], X_true=pend.U[fold,:,np.newaxis].T)

    loss = (loss_LQR.sum() + loss_U.sum())/n_training
    
    print('Hyperparameters {}'.format(params), 'Loss {}'.format(loss))
    print('loss : '+str(loss)+' traj : '+str(loss_traj.sum()/n_training)+' LQR : '+str(loss_LQR.sum()/n_training)+' U :'+str(loss_U.sum()/n_training))
    
    return {"loss":loss, "status":STATUS_OK}
#######################################################
# trials = joblib.load('hyperopt_trials.pkl')
trials = Trials()

best = fmin(
    fn = hyperparameters_tuning,
    space = space, 
    algo = tpe.suggest, 
    max_evals = 500, 
    trials = trials
)

joblib.dump(trials, 'hyperopt_trials.pkl')

print('Best hyperparameters {}'.format(best))
# Out:
# 140
# 81
# Hyperparameters {'dimension': 6.0, 'nb_delays': 23.0, 'nb_trajectories': 38.0}
# Loss 154.87615849670513
# loss : 154.87615849670513 traj : 2.430792763995733e+16 LQR : 18.032551086023226 U :136.8436074106819
# Hyperparameters {'dimension': 7.0, 'nb_delays': 14.0, 'nb_trajectories': 47.0}
# Loss 135.65500642493242
# loss : 135.65500642493242 traj : 1313006.9874768397 LQR : 15.907470066117856 U :119.74753635881457
# Hyperparameters {'dimension': 14.0, 'nb_delays': 11.0, 'nb_trajectories': 39.0}
# Loss 133.45331675852955
# loss : 133.45331675852955 traj : 1.93572668146514e+37 LQR : 9.619676943442137 U :123.83363981508742
# Hyperparameters {'dimension': 13.0, 'nb_delays': 48.0, 'nb_trajectories': 23.0}
# Loss 207.16536346218436
# loss : 207.16536346218436 traj : 1.5181702344743586e+40 LQR : 21.857727442870505 U :185.30763601931386
# Hyperparameters {'dimension': 7.0, 'nb_delays': 51.0, 'nb_trajectories': 54.0}
# Loss 206.51752002424837
# loss : 206.51752002424837 traj : 57023462.12208207 LQR : 8.5622446141611 U :197.95527541008727
# Hyperparameters {'dimension': 13.0, 'nb_delays': 26.0, 'nb_trajectories': 18.0}
# Loss 119.74711837419483
# loss : 119.74711837419483 traj : 3.1080583941776217e+74 LQR : 9.589754530498745 U :110.15736384369607
# Hyperparameters {'dimension': 7.0, 'nb_delays': 6.0, 'nb_trajectories': 46.0}
# Loss 119.4637148784184
# loss : 119.4637148784184 traj : 1.3209856704855832e+16 LQR : 5.69712722673019 U :113.76658765168821
# Hyperparameters {'dimension': 9.0, 'nb_delays': 42.0, 'nb_trajectories': 25.0}
# Loss 211.9657893086928
# loss : 211.9657893086928 traj : 2.2715909951868065e+38 LQR : 24.13889543778955 U :187.82689387090323
# Hyperparameters {'dimension': 5.0, 'nb_delays': 5.0, 'nb_trajectories': 29.0}
# Loss 109.50226197279508
# loss : 109.50226197279508 traj : 802754.6061355283 LQR : 2.513684197070008 U :106.98857777572508
# Hyperparameters {'dimension': 5.0, 'nb_delays': 47.0, 'nb_trajectories': 53.0}
# Loss 336.3015806349717
# loss : 336.3015806349717 traj : 4075.1037114861747 LQR : 15.02831932959566 U :321.273261305376
# Hyperparameters {'dimension': 5.0, 'nb_delays': 22.0, 'nb_trajectories': 31.0}
# Loss 177.62744447763077
# loss : 177.62744447763077 traj : 4053452872.5388565 LQR : 13.695640108276951 U :163.9318043693538
# Hyperparameters {'dimension': 11.0, 'nb_delays': 35.0, 'nb_trajectories': 48.0}
# Loss 284.58566122953323
# loss : 284.58566122953323 traj : 9.996912747158985e+27 LQR : 18.42496116597595 U :266.1607000635573
# Hyperparameters {'dimension': 12.0, 'nb_delays': 71.0, 'nb_trajectories': 25.0}
# Loss 317.5968994088643
# loss : 317.5968994088643 traj : 1.9724648667659105e+52 LQR : 23.87958810766471 U :293.71731130119963
# Hyperparameters {'dimension': 9.0, 'nb_delays': 64.0, 'nb_trajectories': 33.0}
# Loss 276.3521703254147
# loss : 276.3521703254147 traj : 2.963633470479678e+39 LQR : 18.212792405990687 U :258.139377919424
# Hyperparameters {'dimension': 10.0, 'nb_delays': 50.0, 'nb_trajectories': 43.0}
# Loss 207.6604703807342
# loss : 207.6604703807342 traj : 3.694088838527257e+28 LQR : 5.001735273867594 U :202.65873510686663
# Hyperparameters {'dimension': 10.0, 'nb_delays': 13.0, 'nb_trajectories': 24.0}
# Loss 145.61321253201348
# loss : 145.61321253201348 traj : 2.923792337621201e+120 LQR : 8.126224787707507 U :137.48698774430596
# Hyperparameters {'dimension': 7.0, 'nb_delays': 61.0, 'nb_trajectories': 32.0}
# Loss 216.13335933702527
# loss : 216.13335933702527 traj : 1.4228652686748713e+18 LQR : 11.018110267281859 U :205.1152490697434
# Hyperparameters {'dimension': 4.0, 'nb_delays': 64.0, 'nb_trajectories': 42.0}
# Loss 384.1244127467493
# loss : 384.1244127467493 traj : 142.33122003543195 LQR : 17.712935388470445 U :366.41147735827883
# Hyperparameters {'dimension': 13.0, 'nb_delays': 61.0, 'nb_trajectories': 50.0}
# Loss 208.8428084576973
# loss : 208.8428084576973 traj : 681471547237387.1 LQR : 7.0314585669519944 U :201.8113498907453
# Hyperparameters {'dimension': 14.0, 'nb_delays': 5.0, 'nb_trajectories': 46.0}
# Loss 150.02079812150666
# loss : 150.02079812150666 traj : 2085398.3253436757 LQR : 6.484804450525441 U :143.5359936709812
# Hyperparameters {'dimension': 8.0, 'nb_delays': 5.0, 'nb_trajectories': 58.0}
# Loss 118.21820342521994
# loss : 118.21820342521994 traj : 3.676705631045042e+30 LQR : 5.977445263477481 U :112.24075816174246
# Hyperparameters {'dimension': 8.0, 'nb_delays': 2.0, 'nb_trajectories': 20.0}
# Loss 114.45201468438347
# loss : 114.45201468438347 traj : 195.04928889738449 LQR : 0.6889357886354177 U :113.76307889574805
# Hyperparameters {'dimension': 5.0, 'nb_delays': 32.0, 'nb_trajectories': 16.0}
# Loss 158.52385861445555
# loss : 158.52385861445555 traj : 1.509776134866373e+25 LQR : 10.594991880210543 U :147.928866734245
# Hyperparameters {'dimension': 4.0, 'nb_delays': 18.0, 'nb_trajectories': 20.0}
# Loss 153.91188893428824
# loss : 153.91188893428824 traj : 3.8569128996992694e+25 LQR : 10.867516575476497 U :143.04437235881176
# Hyperparameters {'dimension': 8.0, 'nb_delays': 2.0, 'nb_trajectories': 29.0}
# Loss 159.76697956693883
# loss : 159.76697956693883 traj : 121.15147874873736 LQR : 1.8783117175392121 U :157.8886678493996
# Hyperparameters {'dimension': 6.0, 'nb_delays': 31.0, 'nb_trajectories': 28.0}
# Loss 166.68971455641886
# loss : 166.68971455641886 traj : 4.5175801898850236e+21 LQR : 20.62901187009348 U :146.06070268632539
# Hyperparameters {'dimension': 8.0, 'nb_delays': 1.0, 'nb_trajectories': 35.0}
# Loss 118.73473379124911
# loss : 118.73473379124911 traj : 177.1510931574566 LQR : 0.7417428038736797 U :117.99299098737544
# Hyperparameters {'dimension': 6.0, 'nb_delays': 78.0, 'nb_trajectories': 20.0}
# Loss 272.9382585519388
# loss : 272.9382585519388 traj : 2.702445099786472e+22 LQR : 24.135828379168565 U :248.80243017277024
# Hyperparameters {'dimension': 11.0, 'nb_delays': 22.0, 'nb_trajectories': 37.0}
# Loss 138.40628050711544
# loss : 138.40628050711544 traj : 8.758283179389723e+50 LQR : 18.121903844957245 U :120.2843766621582
# Hyperparameters {'dimension': 4.0, 'nb_delays': 9.0, 'nb_trajectories': 15.0}
# Loss 135.02665180862425
# loss : 135.02665180862425 traj : 13686.349874759713 LQR : 1.9414275070461229 U :133.08522430157814
# Hyperparameters {'dimension': 6.0, 'nb_delays': 15.0, 'nb_trajectories': 28.0}
# Loss 117.50583170616008
# loss : 117.50583170616008 traj : 51263740558331.5 LQR : 8.612434120800945 U :108.89339758535914
# Hyperparameters {'dimension': 5.0, 'nb_delays': 27.0, 'nb_trajectories': 21.0}
# Loss 128.1625704173527
# loss : 128.1625704173527 traj : 1.2457463663695743e+23 LQR : 12.75223215167241 U :115.41033826568028
# Hyperparameters {'dimension': 9.0, 'nb_delays': 18.0, 'nb_trajectories': 39.0}
# Loss 132.48224955734474
# loss : 132.48224955734474 traj : 5.483739381616137e+21 LQR : 15.368380460480259 U :117.11386909686448
# Hyperparameters {'dimension': 7.0, 'nb_delays': 38.0, 'nb_trajectories': 17.0}
# Loss 154.02207666540878
# loss : 154.02207666540878 traj : 4.62575136738895e+36 LQR : 15.608486712779115 U :138.41358995262965
# Hyperparameters {'dimension': 11.0, 'nb_delays': 9.0, 'nb_trajectories': 22.0}
# Loss 266.9671843605714
# loss : 266.9671843605714 traj : 1.6045363615384353e+18 LQR : 11.277039172586445 U :255.69014518798497
# Hyperparameters {'dimension': 8.0, 'nb_delays': 1.0, 'nb_trajectories': 27.0}
# Loss 121.81005286574883
# loss : 121.81005286574883 traj : 158.05881868216102 LQR : 0.5998782103864473 U :121.21017465536238
# Hyperparameters {'dimension': 7.0, 'nb_delays': 17.0, 'nb_trajectories': 36.0}
# Loss 136.40354990478855
# loss : 136.40354990478855 traj : 271300923856765.34 LQR : 14.393886889507183 U :122.00966301528136
# Hyperparameters {'dimension': 10.0, 'nb_delays': 27.0, 'nb_trajectories': 18.0}
# Loss 120.25445384769338
# loss : 120.25445384769338 traj : 8.172090291359066e+65 LQR : 9.3518661635149 U :110.90258768417849
# Hyperparameters {'dimension': 15.0, 'nb_delays': 41.0, 'nb_trajectories': 30.0}
# Loss 271.9158859201633
# loss : 271.9158859201633 traj : 7.605255309688109e+103 LQR : 31.546667620220713 U :240.3692182999426
# Hyperparameters {'dimension': 5.0, 'nb_delays': 9.0, 'nb_trajectories': 34.0}
# Loss 126.81162356929693
# loss : 126.81162356929693 traj : 553.8026970291472 LQR : 6.525615846854175 U :120.28600772244275
# Hyperparameters {'dimension': 12.0, 'nb_delays': 12.0, 'nb_trajectories': 41.0}
# Loss 115.42084078660096
# loss : 115.42084078660096 traj : 3.826740194202242e+28 LQR : 9.302947254287702 U :106.11789353231326
# Hyperparameters {'dimension': 6.0, 'nb_delays': 22.0, 'nb_trajectories': 25.0}
# Loss 121.1659147277547
# loss : 121.1659147277547 traj : 1311206123613.3171 LQR : 11.106243609663393 U :110.0596711180913
# Hyperparameters {'dimension': 9.0, 'nb_delays': 47.0, 'nb_trajectories': 26.0}
# Loss 300.932629457605
# loss : 300.932629457605 traj : 9.607186541716668e+28 LQR : 15.971937405941643 U :284.9606920516634
# Hyperparameters {'dimension': 4.0, 'nb_delays': 53.0, 'nb_trajectories': 22.0}
# Loss 198.4713054375592
# loss : 198.4713054375592 traj : 143353.4665373346 LQR : 14.51872462889866 U :183.95258080866054
# Hyperparameters {'dimension': 7.0, 'nb_delays': 5.0, 'nb_trajectories': 31.0}
# Loss 109.31625696956775
# loss : 109.31625696956775 traj : 1523202923681983.8 LQR : 2.658895156542897 U :106.65736181302485
# Hyperparameters {'dimension': 5.0, 'nb_delays': 55.0, 'nb_trajectories': 32.0}
# Loss 226.467335215632
# loss : 226.467335215632 traj : 10629868502.827143 LQR : 10.244178463195599 U :216.2231567524364
# Hyperparameters {'dimension': 7.0, 'nb_delays': 78.0, 'nb_trajectories': 40.0}
# Loss 236.97093633301733
# loss : 236.97093633301733 traj : 3108688976983489.0 LQR : 12.44734064574193 U :224.52359568727542
# Hyperparameters {'dimension': 7.0, 'nb_delays': 31.0, 'nb_trajectories': 44.0}
# Loss 220.12557259917463
# loss : 220.12557259917463 traj : 6007817922.8211155 LQR : 17.966778234915424 U :202.15879436425922
# Hyperparameters {'dimension': 5.0, 'nb_delays': 37.0, 'nb_trajectories': 38.0}
# Loss 234.6641539049899
# loss : 234.6641539049899 traj : 153340284086.3964 LQR : 13.889985000446416 U :220.77416890454347
# Hyperparameters {'dimension': 6.0, 'nb_delays': 44.0, 'nb_trajectories': 52.0}
# Loss 213.7655939044664
# loss : 213.7655939044664 traj : 3369.7681442152384 LQR : 4.999160942011305 U :208.7664329624551
# Hyperparameters {'dimension': 4.0, 'nb_delays': 6.0, 'nb_trajectories': 58.0}
# Loss 198.13171775058058
# loss : 198.13171775058058 traj : 2214.9504395982076 LQR : 12.992034078860291 U :185.1396836717203
# Hyperparameters {'dimension': 6.0, 'nb_delays': 20.0, 'nb_trajectories': 31.0}
# Loss 125.57572692163176
# loss : 125.57572692163176 traj : 3.803058496601435e+23 LQR : 12.091824837482202 U :113.48390208414955
# Hyperparameters {'dimension': 9.0, 'nb_delays': 25.0, 'nb_trajectories': 45.0}
# Loss 204.72152623907203
# loss : 204.72152623907203 traj : 1.6421384619902478e+20 LQR : 25.020954437865562 U :179.70057180120648
# Hyperparameters {'dimension': 10.0, 'nb_delays': 72.0, 'nb_trajectories': 33.0}
# Loss 270.17594245751866
# loss : 270.17594245751866 traj : 1.5344319041778998e+37 LQR : 22.506497528540116 U :247.66944492897852
# Hyperparameters {'dimension': 8.0, 'nb_delays': 15.0, 'nb_trajectories': 48.0}
# Loss 129.39694339131808
# loss : 129.39694339131808 traj : 37372368.451491185 LQR : 15.7246457158333 U :113.67229767548478
# Hyperparameters {'dimension': 7.0, 'nb_delays': 4.0, 'nb_trajectories': 24.0}
# Loss 109.73954171710072
# loss : 109.73954171710072 traj : 2.075553326071482e+29 LQR : 1.5948913459491016 U :108.14465037115161
# Hyperparameters {'dimension': 4.0, 'nb_delays': 35.0, 'nb_trajectories': 36.0}
# Loss 263.67943875523713
# loss : 263.67943875523713 traj : 248.33441880814627 LQR : 16.177850283132113 U :247.501588472105
# Hyperparameters {'dimension': 5.0, 'nb_delays': 11.0, 'nb_trajectories': 43.0}
# Loss 137.25556818478142
# loss : 137.25556818478142 traj : 562.3858918989794 LQR : 10.02870206305781 U :127.2268661217236
# Hyperparameters {'dimension': 12.0, 'nb_delays': 57.0, 'nb_trajectories': 30.0}
# Loss 267.44791786188125
# loss : 267.44791786188125 traj : 8.74055046536105e+36 LQR : 12.271694599556701 U :255.17622326232456
# Hyperparameters {'dimension': 14.0, 'nb_delays': 7.0, 'nb_trajectories': 55.0}
# Loss 136.8615829075422
# loss : 136.8615829075422 traj : 1.3432165574006352e+19 LQR : 9.065728280585152 U :127.79585462695707
# Hyperparameters {'dimension': 8.0, 'nb_delays': 29.0, 'nb_trajectories': 34.0}
# Loss 180.60372436934125
# loss : 180.60372436934125 traj : 1.8853349926599905e+25 LQR : 20.00658252496158 U :160.59714184437968
# Hyperparameters {'dimension': 6.0, 'nb_delays': 70.0, 'nb_trajectories': 27.0}
# Loss 256.6369887018092
# loss : 256.6369887018092 traj : 4.004639833229862e+40 LQR : 12.321366479575978 U :244.31562222223317
# Hyperparameters {'dimension': 9.0, 'nb_delays': 24.0, 'nb_trajectories': 18.0}
# Loss 133.79143755678308
# loss : 133.79143755678308 traj : 9.188232176083639e+52 LQR : 9.634713590608403 U :124.15672396617468
# Hyperparameters {'dimension': 7.0, 'nb_delays': 14.0, 'nb_trajectories': 23.0}
# Loss 119.68019588536185
# loss : 119.68019588536185 traj : 1.6905521581651056e+32 LQR : 6.624464794700721 U :113.05573109066113
# Hyperparameters {'dimension': 15.0, 'nb_delays': 20.0, 'nb_trajectories': 39.0}
# Loss 134.07345377725753
# loss : 134.07345377725753 traj : 2.241443784043382e+68 LQR : 17.47012105311173 U :116.60333272414579
# Hyperparameters {'dimension': 7.0, 'nb_delays': 3.0, 'nb_trajectories': 24.0}
# Loss 108.39350853998711
# loss : 108.39350853998711 traj : 7.940184022681723e+58 LQR : 1.1222816402576083 U :107.2712268997295
# Hyperparameters {'dimension': 6.0, 'nb_delays': 3.0, 'nb_trajectories': 29.0}
# Loss 121.65324512239391
# loss : 121.65324512239391 traj : 152.993326715373 LQR : 1.474837674506949 U :120.17840744788697
# Hyperparameters {'dimension': 8.0, 'nb_delays': 8.0, 'nb_trajectories': 26.0}
# Loss 124.87333214395868
# loss : 124.87333214395868 traj : 1.1870756380383327e+43 LQR : 4.572514286774184 U :120.3008178571845
# Hyperparameters {'dimension': 4.0, 'nb_delays': 12.0, 'nb_trajectories': 32.0}
# Loss 162.84752985864307
# loss : 162.84752985864307 traj : 1029926.4988544415 LQR : 8.098776745130046 U :154.74875311351303
# Hyperparameters {'dimension': 5.0, 'nb_delays': 1.0, 'nb_trajectories': 19.0}
# Loss 253.9227249502002
# loss : 253.9227249502002 traj : 543.1658971623979 LQR : 8.52942003808989 U :245.39330491211032
# Hyperparameters {'dimension': 7.0, 'nb_delays': 4.0, 'nb_trajectories': 24.0}
# Loss 109.73954171710072
# loss : 109.73954171710072 traj : 2.075553326071482e+29 LQR : 1.5948913459491016 U :108.14465037115161
# Hyperparameters {'dimension': 10.0, 'nb_delays': 10.0, 'nb_trajectories': 28.0}
# Loss 218.50425070063343
# loss : 218.50425070063343 traj : 1.458452866242546e+58 LQR : 17.040024973251985 U :201.46422572738146
# Hyperparameters {'dimension': 6.0, 'nb_delays': 18.0, 'nb_trajectories': 16.0}
# Loss 114.58144344956308
# loss : 114.58144344956308 traj : 1.578219678449899e+44 LQR : 5.809787022753805 U :108.77165642680927
# Hyperparameters {'dimension': 9.0, 'nb_delays': 6.0, 'nb_trajectories': 22.0}
# Loss 218.19705508283124
# loss : 218.19705508283124 traj : 2137758313146.6895 LQR : 7.417977530795162 U :210.77907755203609
# Hyperparameters {'dimension': 5.0, 'nb_delays': 16.0, 'nb_trajectories': 26.0}
# Loss 135.2026581467537
# loss : 135.2026581467537 traj : 1743101957639.4922 LQR : 8.726713233053326 U :126.47594491370037
# Hyperparameters {'dimension': 8.0, 'nb_delays': 44.0, 'nb_trajectories': 37.0}
# Loss 241.58315314421384
# loss : 241.58315314421384 traj : 1.5529216131364494e+26 LQR : 6.799501427278013 U :234.78365171693582
# Hyperparameters {'dimension': 7.0, 'nb_delays': 29.0, 'nb_trajectories': 30.0}
# Loss 220.27963924702223
# loss : 220.27963924702223 traj : 1.4126329979225627e+20 LQR : 26.413222324695624 U :193.8664169223266
# Hyperparameters {'dimension': 6.0, 'nb_delays': 13.0, 'nb_trajectories': 35.0}
# Loss 119.09168998204167
# loss : 119.09168998204167 traj : 35771143.61687877 LQR : 9.22428162991666 U :109.86740835212501
# Hyperparameters {'dimension': 11.0, 'nb_delays': 1.0, 'nb_trajectories': 23.0}
# Loss 356.14624278854296
# loss : 356.14624278854296 traj : 211.01376132309372 LQR : 7.347034951143331 U :348.79920783739965
# Hyperparameters {'dimension': 4.0, 'nb_delays': 20.0, 'nb_trajectories': 21.0}
# Loss 116.81713566088993
# loss : 116.81713566088993 traj : 2.305772737221071e+28 LQR : 7.280389679195366 U :109.53674598169457
# Hyperparameters {'dimension': 5.0, 'nb_delays': 22.0, 'nb_trajectories': 41.0}
# Loss 186.12916537761149
# loss : 186.12916537761149 traj : 1344369944552.7097 LQR : 19.914118139169535 U :166.21504723844194
# Hyperparameters {'dimension': 7.0, 'nb_delays': 8.0, 'nb_trajectories': 33.0}
# Loss 115.43581467491747
# loss : 115.43581467491747 traj : 3.2245061496518466e+23 LQR : 5.321973839218639 U :110.11384083569882
# Hyperparameters {'dimension': 8.0, 'nb_delays': 3.0, 'nb_trajectories': 29.0}
# Loss 126.72558474909205
# loss : 126.72558474909205 traj : 135310008.81180778 LQR : 2.0000030110292495 U :124.7255817380628
# Hyperparameters {'dimension': 4.0, 'nb_delays': 34.0, 'nb_trajectories': 31.0}
# Loss 165.64849950107057
# loss : 165.64849950107057 traj : 967.4682498294093 LQR : 18.23909741264063 U :147.40940208842994
# Hyperparameters {'dimension': 9.0, 'nb_delays': 39.0, 'nb_trajectories': 25.0}
# Loss 179.76484230045563
# loss : 179.76484230045563 traj : 3.8013092385214227e+37 LQR : 25.422724110435933 U :154.3421181900197
# Hyperparameters {'dimension': 6.0, 'nb_delays': 11.0, 'nb_trajectories': 27.0}
# Loss 116.61985845146268
# loss : 116.61985845146268 traj : 7.698549933815659e+28 LQR : 6.060903177658924 U :110.55895527380375
# Hyperparameters {'dimension': 11.0, 'nb_delays': 49.0, 'nb_trajectories': 16.0}
# Loss 169.48880351990795
# loss : 169.48880351990795 traj : 7.158026269740524e+44 LQR : 19.84014172571289 U :149.64866179419505
# Hyperparameters {'dimension': 8.0, 'nb_delays': 81.0, 'nb_trajectories': 38.0}
# Loss 251.40776706693774
# loss : 251.40776706693774 traj : 2.4552533343569547e+30 LQR : 13.373943584449119 U :238.03382348248863
# Hyperparameters {'dimension': 5.0, 'nb_delays': 16.0, 'nb_trajectories': 19.0}
# Loss 118.60393081935041
# loss : 118.60393081935041 traj : 5294470261.529427 LQR : 6.312585289858643 U :112.29134552949176
# Hyperparameters {'dimension': 7.0, 'nb_delays': 6.0, 'nb_trajectories': 36.0}
# Loss 112.5376833572425
# loss : 112.5376833572425 traj : 8.546959717799714e+16 LQR : 4.148257764806987 U :108.38942559243552
# Hyperparameters {'dimension': 10.0, 'nb_delays': 26.0, 'nb_trajectories': 35.0}
# Loss 160.6633985001858
# loss : 160.6633985001858 traj : 357845065367766.56 LQR : 24.07858970908635 U :136.58480879109945
# Hyperparameters {'dimension': 6.0, 'nb_delays': 29.0, 'nb_trajectories': 21.0}
# Loss 144.94284671433522
# loss : 144.94284671433522 traj : 2.156464563182702e+24 LQR : 14.735371836449168 U :130.20747487788606
# Hyperparameters {'dimension': 12.0, 'nb_delays': 14.0, 'nb_trajectories': 34.0}
# Loss 115.20041214894138
# loss : 115.20041214894138 traj : 1.2666169215649776e+34 LQR : 9.401906483384362 U :105.79850566555702
# Hyperparameters {'dimension': 5.0, 'nb_delays': 68.0, 'nb_trajectories': 32.0}
# Loss 219.29881739865309
# loss : 219.29881739865309 traj : 684.7955362562681 LQR : 6.916640879647129 U :212.38217651900595
# Hyperparameters {'dimension': 4.0, 'nb_delays': 59.0, 'nb_trajectories': 28.0}
# Loss 246.84115562175268
# loss : 246.84115562175268 traj : 1622.1506759082456 LQR : 5.5871848212207915 U :241.25397080053187
# Hyperparameters {'dimension': 7.0, 'nb_delays': 33.0, 'nb_trajectories': 24.0}
# Loss 192.89785425190453
# loss : 192.89785425190453 traj : 1.3765972663544448e+25 LQR : 20.213566799281118 U :172.6842874526234
# Hyperparameters {'dimension': 8.0, 'nb_delays': 23.0, 'nb_trajectories': 42.0}
# Loss 170.67392189806935
# loss : 170.67392189806935 traj : 552734155838501.4 LQR : 24.997579130598304 U :145.67634276747106
# Hyperparameters {'dimension': 13.0, 'nb_delays': 20.0, 'nb_trajectories': 15.0}
# Loss 120.85154153698599
# loss : 120.85154153698599 traj : 4.0142274058857763e+45 LQR : 6.591646492405031 U :114.25989504458096
# Hyperparameters {'dimension': 6.0, 'nb_delays': 10.0, 'nb_trajectories': 17.0}
# Loss 114.35131879385787
# loss : 114.35131879385787 traj : 5.478839639195888e+61 LQR : 3.117882940807929 U :111.23343585304994
# Hyperparameters {'dimension': 9.0, 'nb_delays': 18.0, 'nb_trajectories': 31.0}
# Loss 117.65443467797937
# loss : 117.65443467797937 traj : 2.4156842174127768e+61 LQR : 10.56717017074902 U :107.08726450723034
# Hyperparameters {'dimension': 4.0, 'nb_delays': 3.0, 'nb_trajectories': 46.0}
# Loss 196.70575729908262
# loss : 196.70575729908262 traj : 122.67993649127072 LQR : 3.5102083591051576 U :193.19554893997747
# Hyperparameters {'dimension': 7.0, 'nb_delays': 52.0, 'nb_trajectories': 29.0}
# Loss 234.94646331232659
# loss : 234.94646331232659 traj : 1.6412056273230016e+17 LQR : 8.3887090157103 U :226.55775429661628
# Hyperparameters {'dimension': 10.0, 'nb_delays': 4.0, 'nb_trajectories': 25.0}
# Loss 132.00254521619803
# loss : 132.00254521619803 traj : 2.738171938230779e+17 LQR : 2.3933643040168713 U :129.60918091218116
# Hyperparameters {'dimension': 5.0, 'nb_delays': 45.0, 'nb_trajectories': 40.0}
# Loss 233.83457124283677
# loss : 233.83457124283677 traj : 135331954.66856712 LQR : 11.527309307487268 U :222.30726193534952
# Hyperparameters {'dimension': 6.0, 'nb_delays': 7.0, 'nb_trajectories': 56.0}
# Loss 121.25620838941029
# loss : 121.25620838941029 traj : 1267.0916865513923 LQR : 8.293307019987886 U :112.9629013694224
# Hyperparameters {'dimension': 8.0, 'nb_delays': 37.0, 'nb_trajectories': 23.0}
# Loss 170.51868948753668
# loss : 170.51868948753668 traj : 1.0488531787136408e+35 LQR : 16.856660787896637 U :153.66202869964005
# Hyperparameters {'dimension': 9.0, 'nb_delays': 1.0, 'nb_trajectories': 19.0}
# Loss 155.28011550898194
# loss : 155.28011550898194 traj : 657621.3078030313 LQR : 1.1020911379534644 U :154.17802437102847
# Hyperparameters {'dimension': 5.0, 'nb_delays': 9.0, 'nb_trajectories': 27.0}
# Loss 118.84184315636217
# loss : 118.84184315636217 traj : 23153784.219156004 LQR : 5.077816097355548 U :113.76402705900662
# Hyperparameters {'dimension': 7.0, 'nb_delays': 13.0, 'nb_trajectories': 49.0}
# Loss 139.88126747550038
# loss : 139.88126747550038 traj : 1681930.2784635231 LQR : 14.854776628362092 U :125.02649084713829
# Hyperparameters {'dimension': 6.0, 'nb_delays': 5.0, 'nb_trajectories': 33.0}
# Loss 123.92194455450311
# loss : 123.92194455450311 traj : 1.2495655844967133e+19 LQR : 3.25928910826263 U :120.66265544624048
# Hyperparameters {'dimension': 4.0, 'nb_delays': 64.0, 'nb_trajectories': 26.0}
# Loss 236.0766882138337
# loss : 236.0766882138337 traj : 1928.2807017729579 LQR : 4.849551011965773 U :231.22713720186792
# Hyperparameters {'dimension': 10.0, 'nb_delays': 40.0, 'nb_trajectories': 51.0}
# Loss 270.3830964288709
# loss : 270.3830964288709 traj : 3.164180160074578e+25 LQR : 13.092302591079326 U :257.29079383779157
# Hyperparameters {'dimension': 8.0, 'nb_delays': 27.0, 'nb_trajectories': 37.0}
# Loss 165.22579074772213
# loss : 165.22579074772213 traj : 3.789297781144022e+22 LQR : 23.505049636247435 U :141.7207411114747
# Hyperparameters {'dimension': 7.0, 'nb_delays': 31.0, 'nb_trajectories': 30.0}
# Loss 197.94529414404596
# loss : 197.94529414404596 traj : 1.2777431474290021e+25 LQR : 23.04741395916229 U :174.89788018488366
# Hyperparameters {'dimension': 5.0, 'nb_delays': 24.0, 'nb_trajectories': 20.0}
# Loss 140.26007207681334
# loss : 140.26007207681334 traj : 6.640985524812212e+16 LQR : 10.349228008005365 U :129.910844068808
# Hyperparameters {'dimension': 9.0, 'nb_delays': 76.0, 'nb_trajectories': 22.0}
# Loss 256.38972718157993
# loss : 256.38972718157993 traj : 2.1220359076629094e+42 LQR : 24.746846254109773 U :231.64288092747015
# Hyperparameters {'dimension': 14.0, 'nb_delays': 15.0, 'nb_trajectories': 60.0}
# Loss 126.82582868709196
# loss : 126.82582868709196 traj : 4.600523175925703e+46 LQR : 22.25091646493028 U :104.57491222216167
# Hyperparameters {'dimension': 7.0, 'nb_delays': 21.0, 'nb_trajectories': 39.0}
# Loss 168.33269409219545
# loss : 168.33269409219545 traj : 390689328211210.56 LQR : 19.810230783471514 U :148.52246330872393
# Hyperparameters {'dimension': 6.0, 'nb_delays': 2.0, 'nb_trajectories': 35.0}
# Loss 144.4002917382925
# loss : 144.4002917382925 traj : 125.61576520766891 LQR : 1.7006347749577955 U :142.69965696333472
# Hyperparameters {'dimension': 4.0, 'nb_delays': 17.0, 'nb_trajectories': 17.0}
# Loss 124.38951451951944
# loss : 124.38951451951944 traj : 2.6567218134675414e+44 LQR : 4.977742947438841 U :119.4117715720806
# Hyperparameters {'dimension': 8.0, 'nb_delays': 12.0, 'nb_trajectories': 32.0}
# Loss 117.2729555207433
# loss : 117.2729555207433 traj : 6.260512526263215e+77 LQR : 7.525810782118694 U :109.7471447386246
# Hyperparameters {'dimension': 11.0, 'nb_delays': 42.0, 'nb_trajectories': 43.0}
# Loss 255.62726766106476
# loss : 255.62726766106476 traj : 4.261405864742114e+26 LQR : 7.1199768549563585 U :248.50729080610841
# Hyperparameters {'dimension': 5.0, 'nb_delays': 8.0, 'nb_trajectories': 34.0}
# Loss 124.84472660956796
# loss : 124.84472660956796 traj : 51048.71902302447 LQR : 5.824936547647253 U :119.0197900619207
# Hyperparameters {'dimension': 6.0, 'nb_delays': 11.0, 'nb_trajectories': 28.0}
# Loss 117.01077342370591
# loss : 117.01077342370591 traj : 3.609541175327912e+25 LQR : 6.349077903217971 U :110.66169552048794
# Hyperparameters {'dimension': 9.0, 'nb_delays': 19.0, 'nb_trajectories': 47.0}
# Loss 142.99033635231459
# loss : 142.99033635231459 traj : 1915442932612408.5 LQR : 20.864809140704825 U :122.12552721160976
# Hyperparameters {'dimension': 8.0, 'nb_delays': 25.0, 'nb_trajectories': 36.0}
# Loss 132.16343553945083
# loss : 132.16343553945083 traj : 9.442901416623397e+25 LQR : 22.24932711050197 U :109.91410842894885
# Hyperparameters {'dimension': 7.0, 'nb_delays': 36.0, 'nb_trajectories': 21.0}
# Loss 187.91516704739297
# loss : 187.91516704739297 traj : 2.060254297703906e+33 LQR : 18.43989467572807 U :169.47527237166491
# Hyperparameters {'dimension': 4.0, 'nb_delays': 5.0, 'nb_trajectories': 25.0}
# Loss 155.20196414092453
# loss : 155.20196414092453 traj : 124.83639477526168 LQR : 2.208667490555086 U :152.99329665036944
# Hyperparameters {'dimension': 6.0, 'nb_delays': 29.0, 'nb_trajectories': 23.0}
# Loss 141.5268434452187
# loss : 141.5268434452187 traj : 1.0305679495656372e+16 LQR : 15.042527486982111 U :126.48431595823658
# Hyperparameters {'dimension': 12.0, 'nb_delays': 16.0, 'nb_trajectories': 30.0}
# Loss 114.50224932061282
# loss : 114.50224932061282 traj : 1.650682149570566e+34 LQR : 9.477054537250991 U :105.02519478336183
# Hyperparameters {'dimension': 5.0, 'nb_delays': 54.0, 'nb_trajectories': 15.0}
# Loss 189.53332363386696
# loss : 189.53332363386696 traj : 5.8674098788356534e+32 LQR : 16.12186684341516 U :173.4114567904518
# Hyperparameters {'dimension': 8.0, 'nb_delays': 7.0, 'nb_trajectories': 40.0}
# Loss 116.70207464664628
# loss : 116.70207464664628 traj : 2.0961590105237533e+49 LQR : 5.58005490986614 U :111.12201973678015
# Hyperparameters {'dimension': 7.0, 'nb_delays': 14.0, 'nb_trajectories': 38.0}
# Loss 126.8977900677471
# loss : 126.8977900677471 traj : 196121922.29932347 LQR : 11.71870297599009 U :115.17908709175701
# ...
# loss : 118.66238968130244 traj : 1044701641.4041319 LQR : 9.362262401699644 U :109.3001272796028
# Hyperparameters {'dimension': 5.0, 'nb_delays': 5.0, 'nb_trajectories': 22.0}
# Loss 107.14774933685035
# loss : 107.14774933685035 traj : 3.633393366716435e+22 LQR : 1.7589439047131132 U :105.38880543213725
# Hyperparameters {'dimension': 4.0, 'nb_delays': 11.0, 'nb_trajectories': 23.0}
# Loss 136.60247578617918
# loss : 136.60247578617918 traj : 287.35523262588765 LQR : 4.401756334544462 U :132.2007194516347
# Hyperparameters {'dimension': 4.0, 'nb_delays': 6.0, 'nb_trajectories': 18.0}
# Loss 141.1584940707563
# loss : 141.1584940707563 traj : 131.03867138872764 LQR : 1.6561093106031377 U :139.50238476015315
# Hyperparameters {'dimension': 5.0, 'nb_delays': 2.0, 'nb_trajectories': 26.0}
# Loss 105.30861029766596
# loss : 105.30861029766596 traj : 1.2608606262647418e+33 LQR : 0.7847919482765129 U :104.52381834938946
# Hyperparameters {'dimension': 5.0, 'nb_delays': 4.0, 'nb_trajectories': 22.0}
# Loss 112.76156804666212
# loss : 112.76156804666212 traj : 6.316533248234037e+30 LQR : 1.4851983070645005 U :111.27636973959763
# Hyperparameters {'dimension': 4.0, 'nb_delays': 50.0, 'nb_trajectories': 15.0}
# Loss 117.81556461914293
# loss : 117.81556461914293 traj : 414350.6263670678 LQR : 11.908799050402436 U :105.9067655687405
# Hyperparameters {'dimension': 5.0, 'nb_delays': 2.0, 'nb_trajectories': 17.0}
# Loss 176.01363232979014
# loss : 176.01363232979014 traj : 128927.17468205873 LQR : 1.9116407983605228 U :174.10199153142963
# Hyperparameters {'dimension': 4.0, 'nb_delays': 13.0, 'nb_trajectories': 26.0}
# Loss 164.1265155321815
# loss : 164.1265155321815 traj : 4330300393.438017 LQR : 7.168385685226635 U :156.95812984695485
# Hyperparameters {'dimension': 6.0, 'nb_delays': 56.0, 'nb_trajectories': 28.0}
# Loss 294.0260409882702
# loss : 294.0260409882702 traj : 1.3161445553389483e+20 LQR : 20.73967032358395 U :273.2863706646863
# Hyperparameters {'dimension': 5.0, 'nb_delays': 73.0, 'nb_trajectories': 20.0}
# Loss 192.24316327169362
# loss : 192.24316327169362 traj : 17796511038546.547 LQR : 19.07388534115728 U :173.16927793053634
# Hyperparameters {'dimension': 5.0, 'nb_delays': 8.0, 'nb_trajectories': 30.0}
# Loss 120.55018720200424
# loss : 120.55018720200424 traj : 1855067.3093846552 LQR : 5.02355206475295 U :115.52663513725129
# Hyperparameters {'dimension': 4.0, 'nb_delays': 19.0, 'nb_trajectories': 27.0}
# Loss 130.540600795622
# loss : 130.540600795622 traj : 1.4762833520260601e+32 LQR : 9.438428936227872 U :121.10217185939413
# Hyperparameters {'dimension': 6.0, 'nb_delays': 1.0, 'nb_trajectories': 17.0}
# Loss 108.31810899941256
# loss : 108.31810899941256 traj : 4.6709300998974546e+21 LQR : 0.2634169690929225 U :108.05469203031964
# Hyperparameters {'dimension': 6.0, 'nb_delays': 9.0, 'nb_trajectories': 16.0}
# Loss 113.43633757550718
# loss : 113.43633757550718 traj : 2.2565839851510424e+40 LQR : 2.5095456899197344 U :110.92679188558745
# Hyperparameters {'dimension': 5.0, 'nb_delays': 1.0, 'nb_trajectories': 19.0}
# Loss 253.9227249502002
# loss : 253.9227249502002 traj : 543.1658971623979 LQR : 8.52942003808989 U :245.39330491211032
# Hyperparameters {'dimension': 4.0, 'nb_delays': 58.0, 'nb_trajectories': 15.0}
# Loss 126.23681274496897
# loss : 126.23681274496897 traj : 12041.12758445802 LQR : 15.155871134881927 U :111.08094161008705
# Hyperparameters {'dimension': 15.0, 'nb_delays': 81.0, 'nb_trajectories': 17.0}
# Loss 246.12760651075777
# loss : 246.12760651075777 traj : 1.6375051849637834e+56 LQR : 30.464051990898867 U :215.6635545198589
# Hyperparameters {'dimension': 6.0, 'nb_delays': 30.0, 'nb_trajectories': 16.0}
# Loss 154.89966513965183
# loss : 154.89966513965183 traj : 33316615556238.934 LQR : 13.14450180574067 U :141.75516333391116
# Hyperparameters {'dimension': 5.0, 'nb_delays': 3.0, 'nb_trajectories': 22.0}
# Loss 111.15404176802598
# loss : 111.15404176802598 traj : 3.525359148930975e+43 LQR : 1.0832052698397998 U :110.07083649818618
# Hyperparameters {'dimension': 4.0, 'nb_delays': 35.0, 'nb_trajectories': 19.0}
# Loss 119.4430547470793
# loss : 119.4430547470793 traj : 2822053.761314823 LQR : 10.923177111767327 U :108.51987763531197
# Hyperparameters {'dimension': 5.0, 'nb_delays': 15.0, 'nb_trajectories': 18.0}
# Loss 116.4065049385629
# loss : 116.4065049385629 traj : 13666529608768.775 LQR : 5.548775385148556 U :110.85772955341434
# Hyperparameters {'dimension': 6.0, 'nb_delays': 45.0, 'nb_trajectories': 21.0}
# Loss 161.93751151591115
# loss : 161.93751151591115 traj : 3.537060314204552e+35 LQR : 16.84085311348201 U :145.09665840242914
# Hyperparameters {'dimension': 4.0, 'nb_delays': 5.0, 'nb_trajectories': 17.0}
# Loss 137.4620270038203
# loss : 137.4620270038203 traj : 135.28152886274262 LQR : 1.3339763460967455 U :136.12805065772358
# Hyperparameters {'dimension': 6.0, 'nb_delays': 2.0, 'nb_trajectories': 15.0}
# Loss 230.1513662975228
# loss : 230.1513662975228 traj : 210.26581579550907 LQR : 5.549688944646106 U :224.6016773528767
# Hyperparameters {'dimension': 5.0, 'nb_delays': 7.0, 'nb_trajectories': 24.0}
# Loss 111.37503774306526
# loss : 111.37503774306526 traj : 102741.91990786446 LQR : 2.993280644608232 U :108.38175709845703
# Hyperparameters {'dimension': 7.0, 'nb_delays': 11.0, 'nb_trajectories': 20.0}
# Loss 111.47046967089548
# loss : 111.47046967089548 traj : 2.978176466920913e+25 LQR : 4.145854571702962 U :107.32461509919253
# Hyperparameters {'dimension': 4.0, 'nb_delays': 17.0, 'nb_trajectories': 20.0}
# Loss 149.14243364514033
# loss : 149.14243364514033 traj : 2.9861003222359264e+22 LQR : 6.4603925060220035 U :142.68204113911833
# Hyperparameters {'dimension': 7.0, 'nb_delays': 21.0, 'nb_trajectories': 25.0}
# Loss 121.65279717842024
# loss : 121.65279717842024 traj : 1.270986988680877e+32 LQR : 11.033220212436717 U :110.61957696598353
# Hyperparameters {'dimension': 6.0, 'nb_delays': 27.0, 'nb_trajectories': 23.0}
# Loss 133.9523530859955
# loss : 133.9523530859955 traj : 1.5166677314633166e+24 LQR : 14.792532745193398 U :119.1598203408021
# Hyperparameters {'dimension': 5.0, 'nb_delays': 42.0, 'nb_trajectories': 19.0}
# Loss 168.50325763406565
# loss : 168.50325763406565 traj : 2.0695597938160124e+20 LQR : 16.4855794360646 U :152.01767819800105
# Hyperparameters {'dimension': 6.0, 'nb_delays': 23.0, 'nb_trajectories': 16.0}
# Loss 121.32216520893525
# loss : 121.32216520893525 traj : 3.6433221170536314e+95 LQR : 8.113194597162927 U :113.20897061177232
#  40%|██████████████████▍                           | 200/500 [16:26<24:39,  4.93s/trial, best loss: 105.30861029766596]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-309-51c53ec6cf07> in <module>
#      75 trials = Trials()
#      76
# ---> 77 best = fmin(
#      78     fn = hyperparameters_tuning,
#      79     space = space,
#
# ~\anaconda3\lib\site-packages\hyperopt\fmin.py in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     538
#     539     if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 540         return trials.fmin(
#     541             fn,
#     542             space,
#
# ~\anaconda3\lib\site-packages\hyperopt\base.py in fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     669         from .fmin import fmin
#     670
# --> 671         return fmin(
#     672             fn,
#     673             space,
#
# ~\anaconda3\lib\site-packages\hyperopt\fmin.py in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     584
#     585     # next line is where the fmin is actually executed
# --> 586     rval.exhaust()
#     587
#     588     if return_argmin:
#
# ~\anaconda3\lib\site-packages\hyperopt\fmin.py in exhaust(self)
#     362     def exhaust(self):
#     363         n_done = len(self.trials)
# --> 364         self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     365         self.trials.refresh()
#     366         return self
#
# ~\anaconda3\lib\site-packages\hyperopt\fmin.py in run(self, N, block_until_done)
#     298                 else:
#     299                     # -- loop over trials and do the jobs directly
# --> 300                     self.serial_evaluate()
#     301
#     302                 self.trials.refresh()
#
# ~\anaconda3\lib\site-packages\hyperopt\fmin.py in serial_evaluate(self, N)
#     176                 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     177                 try:
# --> 178                     result = self.domain.evaluate(spec, ctrl)
#     179                 except Exception as e:
#     180                     logger.error("job exception: %s" % str(e))
#
# ~\anaconda3\lib\site-packages\hyperopt\base.py in evaluate(self, config, ctrl, attach_attachments)
#     890                 print_node_on_error=self.rec_eval_print_node_on_error,
#     891             )
# --> 892             rval = self.fn(pyll_rval)
#     893
#     894         if isinstance(rval, (float, int, np.number)):
#
# <ipython-input-309-51c53ec6cf07> in hyperparameters_tuning(params)
#      46 #         model.ConstructLQR(x_std=1e6, u_std=2., dt=pend.dt, ref=pend.ref[fold,:])
#      47         model.ConstructLQR(x_std=1e6, u_std=2., dt=pend.dt, ref=pend.ref[fold,:]) # To learn on differences
# ---> 48         model.LQR_simulate(X0=pend.X[fold,:,0])
#      49
#      50 #         # Simulate the closed-loop trajectory for the non-linear dynamics
#
# ~\OneDrive\Documents\Mécanique - EPFL\Master III\Semester project\Software\My code\Subspace-learning-for-robot-application\LQR simulation\Utils\Functions.py in LQR_simulate(self, X0)
#     461 #         Y0[0,:] = np.concatenate((self.Y[:,0],np.ones([1])))
#     462
# --> 463         ys, self.LQR_U = self.LQR.make_rollout(Y0)
#     464
#     465         ys_mean = np.mean(ys, axis=0)
#
# c:\users\cedri\onedrive\documents\mécanique - epfl\master iii\semester project\software\my code\subspace-learning-for-robot-application\pbdlib-python\pbdlib\poglqr.py in make_rollout(self, x0)
#     429             A = self.get_A(i)
#     430
# --> 431             next_us = self.get_command(xs[i], i)
#     432             next_xs = np.einsum('ij,aj->ai', A, xs[i]) + np.einsum('ij,aj->ai', B, next_us)
#     433             xs[i+1] = next_xs
#
# c:\users\cedri\onedrive\documents\mécanique - epfl\master iii\semester project\software\my code\subspace-learning-for-robot-application\pbdlib-python\pbdlib\poglqr.py in get_command(self, xi, i)
#     321             return -self._K[i].dot(xi) + self._Kv[i].dot(self._v[i+1])
#     322         else:
# --> 323             return np.einsum('ij,aj->ai', -self.K[i], xi) + self._Kv[i].dot(self._v[i + 1])
#     324
#     325     def policy(self, xi, t):
#
# KeyboardInterrupt:

# %% [markdown]
# ## Training performance

# %%
tau = 6 # 4 36 50
# Training
train = 2
# model1 = HAVOK(pend.X[train,:,:], pend.U[train,:])
model1 = HAVOK(pend.dX[train,:,:], pend.dU[train,:], type='learnOnDiff')
horizon = 17
model1.HANKEL(horizon, delay_spacing=1)
model1.SVD(tau)
model1.LS(tau,rcond=0)
model1.Simulate(pend.X[train,:,0],U_testing = pend.U[train,:])
model1.TrajError(pend.X[train,:,:])
print('Loss = ',lg.norm(model1.traj_error,2))
# print(model1.Cu)

plt.rcParams['font.size'] = 20
fig, ax = plt.subplots(ncols=2, 
                       constrained_layout = True, figsize=(20,5))
ax[0].plot(pend.T,rad2deg(model1.X_traj[0,:]),label='linear'), ax[1].plot(pend.T,rad2deg(model1.X_traj[1,:]),label='linear')
ax[0].plot(pend.T,rad2deg(pend.X[train,0,:]),label='original',linestyle='dashed'), ax[1].plot(pend.T,rad2deg(pend.X[train,1,:]),label='original',linestyle='dashed')
ax[0].plot(pend.T,rad2deg(np.array(pend.ref[train,:])),linestyle='dotted',label='reference'), ax[0].legend(), ax[1].legend()
ax[0].set_title('Position'), ax[1].set_title('Velocity')
ax[0].set_xlabel('Time [s]'), ax[1].set_xlabel('Time [s]')
ax[0].set_ylabel('Degrees'), ax[1].set_ylabel('Degrees/sec')

# plt.savefig('Images/Midterm/Training.png',dpi=800)
# Out:
# Loss =  1632.6263415897474
# (Text(0, 0.5, 'Degrees'), Text(0, 0.5, 'Degrees/sec'))

# %% [markdown]
# ## Testing performance

# %%
traj = 6
model1.Simulate(pend.X[traj,:,0],U_testing = pend.U[traj,:])
model1.TrajError(pend.X[traj,:,:])
##########################################
plt.rcParams['font.size'] = 20
fig, ax = plt.subplots(ncols=2, 
                       constrained_layout = True, figsize=(20,5))
ax[0].plot(model1.X_traj[0,:],label='linear'), ax[1].plot(model1.X_traj[1,:],label='linear')
ax[0].plot(pend.X[traj,0,:],label='original',linestyle='dashed'), ax[1].plot(pend.X[traj,1,:],label='original',linestyle='dashed')
ax[0].plot(np.array(pend.ref[traj,:]),linestyle='dotted'), ax[0].legend(), ax[1].legend()
# Out:
# ([<matplotlib.lines.Line2D at 0x235565a1c70>],
#  <matplotlib.legend.Legend at 0x235751293d0>,
#  <matplotlib.legend.Legend at 0x235565a1fd0>)

# %% [markdown]
# ## LQR testing

# %%
traj = 4
model1.Simulate(np.array([pend.ref[traj,0],0]), U_testing=pend.U[traj,:])
model1.ConstructLQR(x_std=1e6, u_std=2., dt=pend.dt, ref=pend.ref[traj,:])
model1.LQR_simulate(pend.X[traj,:,0])

# Plot
plt.rcParams['font.size'] = 20
fig,ax = plt.subplots(2, 2, constrained_layout = True, figsize=(18,7))

ax[0,0].plot(pend.T, rad2deg(pend.X[traj,0,:]), label=r'$\theta_{original}$')
ax[0,0].plot(pend.T, rad2deg(model1.LQR_X[:,0]), label=r"$\theta_{LQR} (t)$")
ax[0,0].plot(pend.T, rad2deg(np.array(pend.ref[traj,:])), label="Reference $r_2$")
ax[0,0].set_xlabel('Time [s]'), ax[0,0].set_ylabel('Position [deg]')
ax[0,0].grid()
ax[0,0].legend()

ax[0,1].plot(pend.T, rad2deg(pend.X[traj,1,:]), label=r'$\dot{\theta}_{original}$')
ax[0,1].plot(pend.T, rad2deg(model1.LQR_X[:,1]), label=r"$\dot{\theta}_{LQR} (t)$")
ax[0,1].set_xlabel('Time [s]'), ax[0,1].set_ylabel('Angular speed [deg/s]')
ax[0,1].grid()
ax[0,1].legend()

print(model1.LQR_U[:,:,:].shape)
ax[1,0].plot(pend.T[:model1.N-1], pend.U[traj,:], label='$u_{original}(t)$')
ax[1,0].plot(pend.T[:model1.N-1], (model1.LQR_U[0,:,:].T).T, label='$u_{LQR}(t)$')
ax[1,0].set_xlabel('Time [s]'), ax[1,0].set_ylabel('Torque [Nm]')
ax[1,0].grid()
ax[1,0].legend()

ax[1,1].set_title('$K_{LQR}$')
figA = snb.heatmap(np.array(model1.LQR._K)[:,0,:].T,cmap='Reds')
ax[1,1].set_xlabel('Horizon'), ax[1,1].set_ylabel(r'Subspace coordinate $r$')
# Out:
# (1, 4999, 1)
# (Text(0.5, 32.167000000000016, 'Horizon'),
#  Text(920.4454478425972, 0.5, 'Subspace coordinate $r$'))

# %%
X0 = pend.X[traj,:,0]
Xc, Yc = np.zeros(shape=[model1.nb_S,model1.N]), np.zeros(shape=[model1.tau,model1.N])
Uc = np.empty(shape=[model1.N-1])
Ky = np.array(model1.LQR.K)[:,0,:]
Kx = Ky@pinv(model1.C)
t_interval = pend.dt

# Initial condition
Xc[:,0] = X0
N = np.eye(model1.tau) - pinv(model1.C) @ model1.C
Y0 = pinv(model1.C)@X0
Y0 = Y0 + N@(model1.Y[:,0] - Y0) # Nullspace projection into subspace 
Yc[:,0] = Y0

f = lambda theta, u : pend.dynamics(theta, u)
u_max = [-15,15] # Limiting contol input size

# Simulate the closed-loop trajectory for the non-linear dynamics
for i in range(model1.N-1):
    
#     Uc[i] = (model1.Cu@model1.LQR.get_command(Yc[:,i],i))
    Uc[i] = (model1.LQR.get_command(Yc[:,i],i))[0]
    if Uc[i] >= u_max[1]: Uc[i] = u_max[1]
    if Uc[i] <= u_max[0]: Uc[i] = u_max[0]
    
    Xc[:,i+1]= RK4(f, Xc[:,i], Uc[i], t_interval, type='controller-step-by-step')
    Yc[:,i+1] = pinv(model1.C)@Xc[:,i+1]
    
print('LQR cost : ',model1.LQR_cost(Xc, Uc, pend.ref[traj,:]))
print('LQR cost : ',model1.LQR_cost(pend.X[traj,:,:], pend.U[traj,:], pend.ref[traj,:]))
print('LQR RMSE : ',model1.RMSE(X_pred=Xc[0,:,np.newaxis].T, X_true=pend.ref[traj,:,np.newaxis].T))
print('PID RMSE : ',model1.RMSE(X_pred=pend.X[traj,0,:,np.newaxis].T, X_true=pend.ref[traj,:,np.newaxis].T))
print('U RMSE : ',model.RMSE(X_pred=Uc[:,np.newaxis].T, X_true=pend.U[traj,:,np.newaxis].T))
    
# Plot
plt.rcParams['font.size'] = 15
fig = plt.figure(constrained_layout = True, figsize=(18,9))

gs = fig.add_gridspec(8, 8)

ax00 = fig.add_subplot(gs[0:4,0:4])
ax01 = fig.add_subplot(gs[0:4,4:8])
ax10 = fig.add_subplot(gs[4:8,0:4])
ax11_0 = fig.add_subplot(gs[4:8,4:6])
ax11_1 = fig.add_subplot(gs[4:8,6:8])

ax00.plot(pend.T, rad2deg(pend.X[traj,0,:]), linestyle='dashed', label=r'$\theta_{model-free}$')
ax00.plot(pend.T, rad2deg(model1.LQR_X[:,0]), linestyle=':', label=r'$\theta_{plan}$')
ax00.plot(pend.T, rad2deg(Xc[0,:]), linestyle='dashdot', label=r"$\theta_{LQR}$")
ax00.plot(pend.T, rad2deg(np.array(pend.ref[traj,:])), linestyle='dashed', label='Ref')
ax00.set_xlabel('Time [s]'), ax00.set_ylabel('Position [deg]')
ax00.grid()
ax00.legend(bbox_to_anchor=(1, 1.2),ncol=5)

ax01.plot(pend.T, rad2deg(pend.X[traj,1,:]), linestyle='dotted', label=r'$\dot{\theta}_{model-free}$')
ax01.plot(pend.T, rad2deg(model1.LQR_X[:,1]), linestyle='dashed', label=r"$\dot{\theta}_{plan}$")
ax01.plot(pend.T, rad2deg(Xc[1,:]), linestyle='dashed', label=r"$\dot{\theta}_{LQR}$")
ax01.set_xlabel('Time [s]'), ax01.set_ylabel('Angular speed [deg/s]')
ax01.grid()
ax01.legend(bbox_to_anchor=(.9, 1.22),ncol=4)

ax10.plot(pend.T[:model1.N-1], pend.U[traj,:], linestyle='dashed', label='$u_{model-free}$')
# ax10.plot(pend.T[:model1.N-1], model1.LQR_U[0,:,0], linestyle='dotted', label='$u_{plan}$')
ax10.plot(pend.T[:model1.N-1], Uc, linestyle='dashdot', label='$u_{LQR}$')
ax10.set_xlabel('Time [s]'), ax10.set_ylabel('Torque [Nm]')
ax10.grid()
ax10.legend(bbox_to_anchor=(.9, 1.2),ncol=3)

ax11_0.set_title('$A$')
figA = snb.heatmap(model1.A,cmap='Reds',ax=ax11_0)
ax11_0.set_ylabel('Dimension'), ax11_0.set_xlabel('Dimension')

ax11_1.set_title('$B$')
figA = snb.heatmap(model1.B,cmap='Reds')

# fig.savefig('Images/Pend_HAVOK_trajectories_sine2.svg',format='svg',dpi=800)
# fig.savefig('Images/Midterm/summary.png',dpi=800)
# Out:
# LQR cost :  32316700.168306388
# LQR cost :  50188341.07788874
# LQR RMSE :  15.070327760986785
# PID RMSE :  20.079837795162025
# U RMSE :  15.147316347342755

# %% [markdown]
# ## Pendulum swing up

# %%
freq = .05
dt = 1e-2
period = 1/freq/dt

pend3 = SimplePendulum(mass=1, length=1, time=np.arange(0,10,dt), X0=np.array([deg2rad(120),0]), dt=dt)
pend = pend3

x_std, x_std1, x_std2 = 1e6, 1e4, 1e7
pend.ref = np.zeros([2,pend.N])
# pend.ref[0,:] = sineReference(pend.N, pend.dt, period, 180, -90)
pend.ref[0,:] = deg2rad(90*np.ones(pend.N))
precision1, precision2 = np.zeros(shape=[2,pend.N]), np.zeros(shape=[2,pend.N])
nb = np.int(pend.N/(period/2))

precision1[0,np.int(2*pend.N/4):pend.N] = np.ones(np.int(2*pend.N/4))*x_std
precision2[0,np.int(2*pend.N/4):pend.N] = np.ones(np.int(2*pend.N/4))*x_std
# precision1[0,np.int(3*pend.N/4):pend.N] = np.ones(np.int(pend.N/4))*x_std
# precision2[0,np.int(3*pend.N/4):pend.N] = np.ones(np.int(pend.N/4))*x_std
# precision1[0,np.int(3*pend.N/4)] = x_std2
# precision2[0,np.int(3*pend.N/4)] = x_std2
# precision1[0,pend.N - 100:pend.N] = np.ones(100)*x_std2
# precision2[0,pend.N - 100:pend.N] = np.ones(100)*x_std2
# precision1[0,np.int(pend.N/2)], precision1[0,pend.N-1] = x_std, x_std
# precision2[0,np.int(pend.N/2):pend.N] = np.ones(np.int(pend.N/2))*x_std

# plt.plot(precision1[0,:]/x_std)
# plt.plot(precision2[0,:]/x_std)
# plt.plot(pend.ref[0,:]/deg2rad(90),linestyle='dashed')

u_std = 1.2
model1.ConstructLQR(x_std=x_std, u_std=u_std, dt=pend.dt, ref=pend.ref.T, precision=precision1)
model1.LQR_simulate(np.array([deg2rad(-90),0]))

LQR1_X, LQR1_U, LQR1 = model1.LQR_X, model1.LQR_U, model1.LQR

u_std = 4.
model1.ConstructLQR(x_std=x_std, u_std=u_std, dt=pend.dt, ref=pend.ref.T, precision=precision2)
model1.LQR_simulate(np.array([deg2rad(-90),0]))

LQR2_X, LQR2_U, LQR2 = model1.LQR_X, model1.LQR_U, model1.LQR

X0 = np.array([deg2rad(-90),0])
Xc, Yc = np.zeros(shape=[2,model1.nb_S,pend.N]), np.zeros(shape=[2,model1.tau,pend.N])
Uc = np.empty(shape=[2,pend.N-1])
t_interval = pend.dt

LQR = np.array([LQR1,LQR2])

# Initial condition
Xc[:,:,0] = X0
N = np.eye(model1.tau) - pinv(model1.C) @ model1.C
Y0 = pinv(model1.C)@X0
Y0 = Y0 + N@(model1.Y[:,0] - Y0) # Nullspace projection into subspace 
Yc[:,:,0] = Y0

f = lambda theta, u : pend.dynamics(theta, u)
u_max = [-20,20]

# Simulate the closed-loop trajectory for the non-linear dynamics
for i in range(pend.N-1):
    
    for j in range(2):
        Uc[j,i] = LQR[j].get_command(Yc[j,:,i],i)
        
        if Uc[j,i] >= u_max[1]: Uc[j,i] = u_max[1]
        if Uc[j,i] <= u_max[0]: Uc[j,i] = u_max[0]

        Xc[j,:,i+1]= RK4(f, Xc[j,:,i], Uc[j,i], t_interval, type='controller-step-by-step')
        Yc[j,:,i+1] = pinv(model1.C)@Xc[j,:,i+1]
    
# # Evaluate LQR costs

RMSE_U1 = model1.RMSE(X_pred=Uc[0,:,np.newaxis].T, X_true=np.zeros(shape=[1,pend.N-1]), type='input')
RMSE_U2 = model1.RMSE(X_pred=Uc[1,:,np.newaxis].T, X_true=np.zeros(shape=[1,pend.N-1]), type='input')
print('RMSE U1 : '+str(RMSE_U1))
print('RMSE U2 : '+str(RMSE_U2))
    
# Plot
plt.rcParams['font.size'] = 20
fig,ax = plt.subplots(2, 2, constrained_layout = True, figsize=(18,7))

ax[0,0].plot(pend.T, rad2deg(Xc[0,0,:]), label=r"$\theta_{plan1} (t)$")
ax[0,0].plot(pend.T, rad2deg(Xc[1,0,:]), label=r"$\theta_{plan2} (t)$")
ax[0,0].plot(pend.T, rad2deg(pend.ref[0,:]), label="Reference $r_2$")
ax[0,0].set_xlabel('Time [s]'), ax[0,0].set_ylabel('Position [deg]')
ax[0,0].grid()
ax[0,0].legend()

ax[0,1].plot(pend.T, rad2deg(Xc[0,1,:]), label=r"$\dot{\theta}_{plan1} (t)$")
ax[0,1].plot(pend.T, rad2deg(Xc[1,1,:]), label=r"$\dot{\theta}_{plan2} (t)$")
ax[0,1].set_xlabel('Time [s]'), ax[0,1].set_ylabel('Angular speed [deg/s]')
ax[0,1].grid()
ax[0,1].legend()

ax[1,0].plot(pend.T[:pend.N-1], Uc[0,:], label='$u_{plan1}(t)$')
ax[1,0].plot(pend.T[:pend.N-1], Uc[1,:], label='$u_{plan2}(t)$')
ax[1,0].set_xlabel('Time [s]'), ax[1,0].set_ylabel('Torque [Nm]')
ax[1,0].grid()
ax[1,0].legend()

ax[1,1].set_title('$K_{LQR}$')
figA = snb.heatmap(np.array(model1.LQR._K)[:,0,:].T,cmap='Reds')
ax[1,1].set_xlabel('Horizon'), ax[1,1].set_ylabel(r'Subspace coordinate $r$')
# Out:
# RMSE U1 : 354042.6409473356
# RMSE U2 : 559754.0100776826
# (Text(0.5, 32.167000000000016, 'Horizon'),
#  Text(924.8635207767234, 0.5, 'Subspace coordinate $r$'))
