# %% [markdown]
# # Friction models learning for Panda robot

# %%
import numpy as np
from numpy import random as rnd
from numpy.linalg import pinv
from numpy import linalg as lg
from scipy import linalg as slg
from importlib import reload
import seaborn as snb
import matplotlib.pyplot as plt
import Utils.Functions 
from Utils.Functions import *
import pbdlib as pbd
from scipy.linalg import hankel
import joblib
import pybullet
from pbdlib import LQR
from pbdlib.utils import get_canonical
import pandapybullet as ppb
import torch
import time
import GPy, GPyOpt
# %load_ext autoreload
# %autoreload 2
plt.style.use("default")
plt.rcParams['font.size'] = 13
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams['lines.linewidth'] = 2.5
np.set_printoptions(precision=5, suppress=False)

# %% [markdown]
# ## Gather training data
# ### Define random sine reference
#
# Run a LQR using desired joint position and velocity to retrieve joint acceleration

# %%
N=20000
dt = 1e-3
T = N*dt
n_training = 5
n_testing = 0
n_tot = n_training + n_testing
joint_limits = np.empty([2,2])
joint_limits[0,0], joint_limits[0,1] = -np.pi, np.pi
joint_limits[1,0], joint_limits[1,1] = -np.pi, np.pi

# Trajectories specifications
specs = {'phi': {'low': -np.pi, 'high': np.pi}, 
         'A': {'low': -np.pi, 'high': np.pi},
         'f': {'low': 1/15, 'high': .5},
         'nb_parts': 100, 'margin': .2, 'safety': .9}

pendSim, pendReal = Robot(2, 2, dt, N), Robot(2, 2, dt, N)
pendSim.drawTrajectories(nb_traj=n_tot, q_limits=joint_limits, specs=specs)
pendReal.ref, pendReal.ddq = pendSim.ref, pendSim.desired_ddq
pendReal.nb_traj = pendSim.nb_traj

# %% [markdown]
# ## Gather training data using CTC + PD

# %%
Fv = 1*np.diag([1.,1.])

# %% [markdown]
# ### Simulate using CTC + PD

# %%
N = 20000
log_control = np.zeros(shape=[n_tot,2,N-1])
log_control_model = np.zeros(shape=[n_tot,2,N-1])
log_q = np.zeros(shape=[n_tot,2,N])
log_dq = np.zeros(shape=[n_tot,2,N])
log_ddq = np.zeros(shape=[n_tot,2,N])
param = {'m1': .1, 'm2': .1, 
         'l1': .5, 'l2': .5,
         'time': np.arange(0,N*dt,dt), 'dt': dt
        }
pendulum = DoublePendulum(param)

Kp, Ki, Kd = np.diag([20,20]), np.diag([1,1]), np.diag([1,1])
torque_limit = np.array([100,100])

for n in range(n_tot):
    pendulum.x = np.array([[pendSim.ref[n,0,0],0,0],
                           [pendSim.ref[n,1,0],0,0]]
                         )
    log_error = []
    sum_error = np.zeros(2)
    log_q[n,:,0] = pendulum.x[:,0]
    log_dq[n,:,0] = pendulum.x[:,1]
    log_ddq[n,:,0] = pendulum.x[:,2]
    
    # Initialize matrices
    pendulum.Physics(pendulum.x[:,:2])
    
    for i in range(N-1):
        error_q = pendSim.ref[n,:2,i] - pendulum.x[:,0]
        error_dq = pendSim.ref[n,2:,i] - pendulum.x[:,1]

        # Computed Torque Control for approximate system (doesn't consider friction)
#         control_input = pendulum.CTC(pendSim.desired_ddq[n,:2,i],
#                                      ( Kp @ error_q + Ki @ sum_error + Kd @ error_dq ),
#                                     )
        # Computed Torque Control for approximate system (doesn't consider friction)
        control_input = pendulum.CTC(pendSim.desired_ddq[n,:,i],
                                     ( Kp @ error_q + Ki @ sum_error + Kd @ error_dq ) - Fv@pendulum.x[:,1]
                                    )
        
        for j in range(2):
            if control_input[j] > torque_limit[j]:
                control_input[j] = torque_limit[j]
            elif control_input[j] < -torque_limit[j]:
                control_input[j] = -torque_limit[j]
        
        pendulum.x[:,:2] = RK4(pendulum.Physics,
                               pendulum.x[:,:2], 
                               control_input,
                               pendulum.dt, 
                               type='controller-step-by-step'
                              ) # Simulation with Runge-Kutta 4
        pendulum.Physics(pendulum.x[:,:2],control_input)
        
        log_error.append(np.copy(error_q))
        log_q[n,:,i] = pendulum.x[:,0]
        log_dq[n,:,i] = pendulum.x[:,1]
        log_control[n,:,i] = control_input
#         print(log_control[n,:,:])
#         print(control_input)
        sum_error += error_q*dt
log_q = log_q[:,:,:-1]
log_dq = log_dq[:,:,:-1]

# %% [markdown]
# ## Store data in state-space form

# %% [markdown]
# ### Data for bad model (simulated)

# %%
pendSim.toStateSpace(log_q.copy(), log_dq.copy(), log_control.copy())

# %% [markdown]
# ### Data for true dynamics (observed)

# %%
pendReal.toStateSpace(log_q.copy(), log_dq.copy(), log_control.copy())

# %% [markdown]
# ### Difference dynamics
# Here, the difference between the data simulated with the bad model with the suitable controller and the data gathered using the same controller but on the true system dynamics (which have synthetically been altered) is computed. <br><br>
# $$ \delta X = X_0 - X_{model}$$ <br><br>
# After that, the same algorithm leveraging HAVOK will be employed to retrieve a dynamical expression of the dynamical discrepancy.

# %%
delta_U = pendReal.U - pendSim.U
delta_X = pendReal.X - pendSim.X

# %% [markdown]
# ### Plot for bad model (but rightly calibrated controller)

# %%
traj = 1
model = HAVOK()
RMSE = model.RMSE(X_true=pendReal.X[traj,:,:],
                  X_pred=pendSim.X[traj,:,:])
print(RMSE)
plt.rcParams['font.size'] = 14 
fig, ax = plt.subplots(2, 3, constrained_layout = True, figsize=(15,7))

for i in range(2):

    ax[i,0].plot(pendSim.T[:-1], rad2deg(pendSim.X[traj,i,:]), label=r'$q_{%d}^m$'%(i+1))
    ax[i,0].plot(pendReal.T[:-1], rad2deg(pendReal.X[traj,i,:]), label=r'$q_{%d}^0$'%(i+1), linestyle='dashed')
    ax[i,0].plot(pendSim.T[:], rad2deg(pendSim.ref[traj,i,:]), label=r'$q_{%d}^{ref}$'%(i+1), linestyle='dotted')

    ax[i,1].plot(pendSim.T[:-1], rad2deg(pendSim.X[traj,2+i,:]), label=r'$\dot{q}_{%d}^m$'%(i+1))
    ax[i,1].plot(pendReal.T[:-1], rad2deg(pendReal.X[traj,2+i,:]), label=r'$\dot{q}_{%d}^0$'%(i+1), linestyle='dashed')

    ax[i,2].plot(pendSim.T[:-1], pendSim.U[traj,i,:], label=r'$u_{%d}^m$'%(i+1))
    ax[i,2].plot(pendReal.T[:-1], pendReal.U[traj,i,:], label=r'$u_{%d}^0$'%(i+1), linestyle='dashed')
    ax[i,0].set_ylabel('Position [deg]'), ax[i,1].set_ylabel('Velocity [deg/s]'), ax[i,2].set_ylabel('Torque [Nm]')
    ax[i,0].legend(), ax[i,1].legend(), ax[i,2].legend()
    
ax[1,0].set_xlabel('Time [s]'), ax[1,1].set_xlabel('Time [s]'), ax[1,2].set_xlabel('Time [s]')
# Out:
# tensor(62.0748)
# (Text(0.5, 0, 'Time [s]'), Text(0.5, 0, 'Time [s]'), Text(0.5, 0, 'Time [s]'))

# %% [markdown]
# ### Plot residual dynamics

# %%
traj = 1
plt.rcParams['font.size'] = 14 
fig, ax = plt.subplots(2, 3, constrained_layout = True, figsize=(15,7))

for i in range(2):

    ax[i,0].plot(pendSim.T[:-1], rad2deg(delta_X[traj,i,:]), label=r'$\delta q_{%d}^m$'%(i+1))
    ax[i,1].plot(pendSim.T[:-1], rad2deg(delta_X[traj,2+i,:]), label=r'$\delta \dot{q}_{%d}^m$'%(i+1))

    ax[i,2].plot(pendSim.T[:-1], delta_U[traj,i,:], label=r'$\delta u_{%d}^m$'%(i+1))
    ax[i,0].set_ylabel('Position [deg]'), ax[i,1].set_ylabel('Velocity [deg/s]'), ax[i,2].set_ylabel('Torque [Nm]')
    ax[i,0].legend(), ax[i,1].legend(), ax[i,2].legend()
    
ax[1,0].set_xlabel('Time [s]'), ax[1,1].set_xlabel('Time [s]'), ax[1,2].set_xlabel('Time [s]')
# Out:
# (Text(0.5, 0, 'Time [s]'), Text(0.5, 0, 'Time [s]'), Text(0.5, 0, 'Time [s]'))

# %% [markdown]
# ## Model training

# %%
nb_train, nb_test = 15000, 5000 # train-test ratio of 2

# %% [markdown]
# ### Using *GPyOpt*

# %%
nb_train, nb_test = 15000, 5000 # train-test ratio of 2
traj_ratio = .05
n_low, n_high = 40, 250
d_low, d_high = 1, np.int((1-traj_ratio)/n_high*nb_train)
ref_zeros = np.zeros([2,nb_train-1])

domain = [
    {'name': 'dimension', 'type': 'discrete', 'domain': np.arange(4,15,1)},
    {'name': 'nb_traj', 'type': 'discrete', 'domain': np.arange(n_low,n_high,1)},
    {'name': 'nb_delays', 'type': 'discrete', 'domain': np.arange(d_low,d_high,1)}
]

print('delay max : ',np.int((1-traj_ratio)/n_high*nb_train))
print('points min : ',nb_train- d_high*n_high)

loss_prediction_train = np.empty(shape=[n_training])
loss_prediction_test = np.empty(shape=[n_training])
loss_corr = np.empty(shape=[n_training])
loss_LQR = np.empty(shape=[n_training])

N = pendSim.X.shape[2]

def loss(space):
    # Model parameters
    n_params = space.shape[0] # If train by batch
    s = np.int(space[0,0])
    n = np.int(space[0,1])
    d = np.int(space[0,2])
#     nx = np.int(space[0,0])
#     nu = np.int(space[0,1])
#     d = np.int(space[0,2])
    
    timing = np.empty([2,n_training])
    
    for fold in range(n_training):
        timing[0,fold] = time.time() # HAVOK computation time
        
        # TRAINING #####################################################
        model = HAVOK(delta_X[fold,:,:nb_train], # state-wise difference
                      torch.cat((pendSim.X[fold,:,:nb_train-1], # Exogenous inputs vector
                                 pendSim.U[fold,:,:nb_train-1],
                                 delta_U[fold,:,:nb_train-1]),axis=0),
#                                  delta_U[fold,None,:nb_train-1]),axis=0), 
                      mode='ELQR form',
                      nb_U=8,
                      nb_U_ex=6
                     )
        model.HANKEL(n, d)
        model.SVD(s)
        model.LS(s,rcond=0)
        
        timing[0,fold] = time.time() - timing[0,fold]  
        timing[1,fold] = time.time() # Simulation time computation
        # TESTING ######################################################
        model.Simulate(X0=delta_X[fold,:,0],
                       horizon=nb_train,
                       U=torch.cat((pendSim.X[fold,:,:nb_train],
                                    pendSim.U[fold,:,:nb_train],
#                                     pendReal.U[fold,None,:nb_train]),axis=0).to(torch.float)
                                    delta_U[fold,:,:nb_train]),axis=0).to(torch.float)
                      )
        
        loss_prediction_train[fold] = model.RMSE(X_pred=model.X_prediction,
                                           X_true=delta_X[fold,:,:nb_train])
        model.Simulate(X0=delta_X[fold,:,nb_train],
                       horizon=nb_test,
                       U=torch.cat((pendSim.X[fold,:,nb_train:],
                                    pendSim.U[fold,:,nb_train:],
#                                     pendReal.U[fold,None,nb_train:]),axis=0).to(torch.float)
                                    delta_U[fold,:,nb_train:]),axis=0).to(torch.float)
                      )
        loss_prediction_test[fold] = model.RMSE(X_pred=model.X_prediction[:,:-1],
                                           X_true=delta_X[fold,:,nb_train:])
        
        timing[1,fold] = time.time() - timing[1,fold]  
        
    loss_pred_train_sum = np.mean(loss_prediction_train)
    loss_pred_test_sum = np.mean(loss_prediction_test)
    loss = loss_pred_train_sum + loss_pred_test_sum
    avg_time = [timing[0,:].sum()/n_training,timing[1,:].sum()/n_training]
    
    if np.isnan(loss) or np.isinf(loss):
        loss = 1e10
        
#     print('Total loss : '+str(loss)+' Loss sim. : '+str(loss_traj_sum)+
#           ', s :'+str(s)+', n :'+str(n)+', d : '+str(d))
    print('Total loss : '+str(loss)+' Loss train. : '+str(loss_pred_train_sum)+
          ' Loss test. : '+str(loss_pred_test_sum)+
          ', r :'+str(s)+', n :'+str(n)+', d : '+str(d))
    print('Avg computation time for HAVOK : '+str(avg_time[0])+' [s], for sim. : '+str(avg_time[1])+' [s]')
    
    return loss

max_iter = 1000
batch_size = 6
num_cores = 6

opt = GPyOpt.methods.BayesianOptimization(f = loss,            # function to optimize       
                                          domain = domain,         # box-constraints of the problem
                                          acquisition_type ='LCB',       # LCB acquisition
                                          acquisition_weight = 0.2)     # Exploration exploitation
 

opt.run_optimization(max_iter)
# Out:
# delay max :  57
# points min :  750
# Total loss : 76901.86097106933 Loss train. : 76685.533984375 Loss test. : 216.32698669433594, r :10, n :111, d : 20
# Avg computation time for HAVOK : 0.03230619430541992 [s], for sim. : 0.8940141677856446 [s]
# Total loss : 53128.369623565675 Loss train. : 53006.21796875 Loss test. : 122.15165481567382, r :6, n :77, d : 20
# Avg computation time for HAVOK : 0.020945024490356446 [s], for sim. : 0.8750594615936279 [s]
# Total loss : 827028.7842746736 Loss train. : 826907.7228515625 Loss test. : 121.06142311096191, r :7, n :53, d : 37
# Avg computation time for HAVOK : 0.014149904251098633 [s], for sim. : 0.8543195247650146 [s]
# Total loss : 177.22294998168945 Loss train. : 90.37966842651367 Loss test. : 86.84328155517578, r :4, n :107, d : 49
# Avg computation time for HAVOK : 0.02153639793395996 [s], for sim. : 0.8603095054626465 [s]
# Total loss : 523736157521460.8 Loss train. : 523736157451059.2 Loss test. : 70401.6158203125, r :13, n :91, d : 12
# Avg computation time for HAVOK : 0.03150873184204102 [s], for sim. : 0.8610954761505127 [s]
# Total loss : 177.41181182861328 Loss train. : 90.44633102416992 Loss test. : 86.96548080444336, r :4, n :107, d : 49
# Avg computation time for HAVOK : 0.022320270538330078 [s], for sim. : 0.840770149230957 [s]
# Total loss : 53289.21799621582 Loss train. : 53167.0181640625 Loss test. : 122.19983215332032, r :6, n :77, d : 20
# Avg computation time for HAVOK : 0.020139169692993165 [s], for sim. : 0.8688819408416748 [s]
# Total loss : 174.89717636108398 Loss train. : 88.83055114746094 Loss test. : 86.06662521362304, r :4, n :108, d : 49
# Avg computation time for HAVOK : 0.023131084442138673 [s], for sim. : 0.9053838729858399 [s]
# Total loss : 5859.891954040528 Loss train. : 5762.820556640625 Loss test. : 97.07139739990234, r :4, n :73, d : 23
# Avg computation time for HAVOK : 0.020338964462280274 [s], for sim. : 0.9468727588653565 [s]
# Total loss : 5772.729054260254 Loss train. : 5658.579296875 Loss test. : 114.1497573852539, r :9, n :116, d : 23
# Avg computation time for HAVOK : 0.03371009826660156 [s], for sim. : 0.9231286525726319 [s]
# Total loss : 1374.246141052246 Loss train. : 1300.2044921875 Loss test. : 74.0416488647461, r :5, n :73, d : 18
# Avg computation time for HAVOK : 0.01974015235900879 [s], for sim. : 0.9169529914855957 [s]
# Total loss : 275976.04260253906 Loss train. : 275709.203125 Loss test. : 266.8394775390625, r :10, n :116, d : 18
# Avg computation time for HAVOK : 0.036302614212036136 [s], for sim. : 0.9179435729980469 [s]
# Total loss : 19513.32431411743 Loss train. : 19404.436450195313 Loss test. : 108.88786392211914, r :5, n :113, d : 21
# Avg computation time for HAVOK : 0.029919242858886717 [s], for sim. : 0.9388950347900391 [s]
# Total loss : 455.5614303588867 Loss train. : 370.66432037353513 Loss test. : 84.89710998535156, r :5, n :109, d : 40
# Avg computation time for HAVOK : 0.026919984817504884 [s], for sim. : 0.9454769134521485 [s]
# Total loss : 15346723057.713543 Loss train. : 15346720913.05 Loss test. : 2144.663543701172, r :11, n :48, d : 42
# Avg computation time for HAVOK : 0.01835026741027832 [s], for sim. : 0.9674118995666504 [s]
# Total loss : 5430.768685913086 Loss train. : 5335.93427734375 Loss test. : 94.83440856933593, r :4, n :44, d : 38
# Avg computation time for HAVOK : 0.01236100196838379 [s], for sim. : 0.8982085227966309 [s]
# Total loss : 4548715944001.722 Loss train. : 4548715931326.8 Loss test. : 12674.921606445312, r :12, n :46, d : 33
# Avg computation time for HAVOK : 0.01934843063354492 [s], for sim. : 0.9135547161102295 [s]
# Total loss : 15575155.714001464 Loss train. : 15575030.390856933 Loss test. : 125.32314453125, r :13, n :109, d : 46
# Avg computation time for HAVOK : 0.028921222686767577 [s], for sim. : 0.9366940498352051 [s]
# Total loss : 882890.4989990235 Loss train. : 882616.023046875 Loss test. : 274.4759521484375, r :11, n :112, d : 25
# Avg computation time for HAVOK : 0.03351011276245117 [s], for sim. : 0.9494590759277344 [s]
# Total loss : 312877.5009529114 Loss train. : 312764.615234375 Loss test. : 112.88571853637696, r :7, n :75, d : 23
# Avg computation time for HAVOK : 0.024733257293701173 [s], for sim. : 0.9205372333526611 [s]
# Total loss : 808.2469787597656 Loss train. : 717.6571350097656 Loss test. : 90.58984375, r :4, n :52, d : 48
# Avg computation time for HAVOK : 0.012746334075927734 [s], for sim. : 0.8948317527770996 [s]
# Total loss : 21493912.973781966 Loss train. : 21493363.062722396 Loss test. : 549.9110595703125, r :14, n :107, d : 56
# Avg computation time for HAVOK : 0.024135828018188477 [s], for sim. : 0.8880226135253906 [s]
# Total loss : 20729161.51654167 Loss train. : 20727888.127373885 Loss test. : 1273.3891677856445, r :14, n :119, d : 56
# Avg computation time for HAVOK : 0.025331640243530275 [s], for sim. : 0.8989945411682129 [s]
# Total loss : 2864.9230979919435 Loss train. : 2761.268701171875 Loss test. : 103.65439682006836, r :4, n :40, d : 53
# Avg computation time for HAVOK : 0.010962724685668945 [s], for sim. : 0.8944140434265136 [s]
# Total loss : 6064.057049560547 Loss train. : 5965.66494140625 Loss test. : 98.39210815429688, r :4, n :77, d : 22
# Avg computation time for HAVOK : 0.019140625 [s], for sim. : 0.8672871112823486 [s]
# Total loss : 642374368282922.0 Loss train. : 642374368275098.4 Loss test. : 7823.646447753907, r :14, n :46, d : 56
# Avg computation time for HAVOK : 0.018750429153442383 [s], for sim. : 0.8908153057098389 [s]
# Total loss : 6715.70319595337 Loss train. : 6608.75234375 Loss test. : 106.95085220336914, r :4, n :40, d : 46
# Avg computation time for HAVOK : 0.010551881790161134 [s], for sim. : 0.8800646781921386 [s]
# Total loss : 2985.27459564209 Loss train. : 2881.177197265625 Loss test. : 104.09739837646484, r :4, n :49, d : 43
# Avg computation time for HAVOK : 0.011967849731445313 [s], for sim. : 0.8938148021697998 [s]
# Total loss : 798437249.4651184 Loss train. : 798436102.3 Loss test. : 1147.1651184082032, r :11, n :49, d : 38
# Avg computation time for HAVOK : 0.01834444999694824 [s], for sim. : 0.8814468860626221 [s]
# Total loss : 784.4343475341797 Loss train. : 693.44248046875 Loss test. : 90.99186706542969, r :4, n :60, d : 44
# Avg computation time for HAVOK : 0.014539527893066406 [s], for sim. : 0.8760768413543701 [s]
# Total loss : 1085645266701.7549 Loss train. : 1085645255998.4 Loss test. : 10703.354858398438, r :7, n :40, d : 29
# Avg computation time for HAVOK : 0.012766408920288085 [s], for sim. : 0.8495258808135986 [s]
# Total loss : 11001864171.86377 Loss train. : 11001859699.2 Loss test. : 4472.66376953125, r :10, n :41, d : 36
# Avg computation time for HAVOK : 0.0161562442779541 [s], for sim. : 0.9757894992828369 [s]
# Total loss : 900.2552780151367 Loss train. : 808.2749084472656 Loss test. : 91.9803695678711, r :4, n :55, d : 44
# Avg computation time for HAVOK : 0.014959239959716797 [s], for sim. : 0.9430822372436524 [s]
# Total loss : 294.5434211730957 Loss train. : 159.09114837646484 Loss test. : 135.45227279663087, r :4, n :126, d : 56
# Avg computation time for HAVOK : 0.0237302303314209 [s], for sim. : 0.91077561378479 [s]
# Total loss : 386669.7103603363 Loss train. : 385683.5284374237 Loss test. : 986.1819229125977, r :14, n :135, d : 56
# Avg computation time for HAVOK : 0.02872180938720703 [s], for sim. : 0.922133207321167 [s]
# Total loss : 6503312348688606.0 Loss train. : 6503312348571390.0 Loss test. : 117216.41689071656, r :11, n :128, d : 47
# Avg computation time for HAVOK : 0.03151493072509766 [s], for sim. : 0.9626244068145752 [s]
# Total loss : 21188763257.969948 Loss train. : 21188760876.57003 Loss test. : 2381.3999168395994, r :12, n :101, d : 39
# Avg computation time for HAVOK : 0.02912130355834961 [s], for sim. : 0.9267209529876709 [s]
# Total loss : 10000000000.0 Loss train. : inf Loss test. : 17137656949.166418, r :14, n :146, d : 56
# Avg computation time for HAVOK : 0.028723526000976562 [s], for sim. : 0.9502566814422607 [s]
# Total loss : 494.99256744384763 Loss train. : 328.70211029052734 Loss test. : 166.29045715332032, r :4, n :115, d : 56
# Avg computation time for HAVOK : 0.023330259323120116 [s], for sim. : 0.9524588108062744 [s]
# Total loss : 246.40408020019532 Loss train. : 157.97244873046876 Loss test. : 88.43163146972657, r :4, n :104, d : 37
# Avg computation time for HAVOK : 0.024527502059936524 [s], for sim. : 0.9175510406494141 [s]
# Total loss : 288.55912322998046 Loss train. : 222.30033416748046 Loss test. : 66.2587890625, r :10, n :105, d : 44
# Avg computation time for HAVOK : 0.02632927894592285 [s], for sim. : 0.9534486293792724 [s]
# Total loss : 106.31527061462403 Loss train. : 85.06013336181641 Loss test. : 21.255137252807618, r :4, n :49, d : 12
# Avg computation time for HAVOK : 0.016149330139160156 [s], for sim. : 1.021872615814209 [s]
# Total loss : 10000000000.0 Loss train. : nan Loss test. : 13563366479308.8, r :14, n :40, d : 11
# Avg computation time for HAVOK : 0.02652850151062012 [s], for sim. : 1.075123119354248 [s]
# Total loss : 3.317645486821056e+16 Loss train. : 3.317645486766162e+16 Loss test. : 548938.3984375, r :14, n :55, d : 17
# Avg computation time for HAVOK : 0.026928091049194337 [s], for sim. : 1.0092988014221191 [s]
# Total loss : 20.293503093719483 Loss train. : 10.326334762573243 Loss test. : 9.96716833114624, r :4, n :40, d : 7
# Avg computation time for HAVOK : 0.012160778045654297 [s], for sim. : 0.9129631996154786 [s]
# Total loss : 6137.0046485900875 Loss train. : 6054.1861022949215 Loss test. : 82.81854629516602, r :8, n :79, d : 37
# Avg computation time for HAVOK : 0.019348621368408203 [s], for sim. : 0.8780491352081299 [s]
# Total loss : 112.94723892211914 Loss train. : 90.94724731445312 Loss test. : 21.999991607666015, r :4, n :41, d : 15
# Avg computation time for HAVOK : 0.011144399642944336 [s], for sim. : 0.8613208293914795 [s]
# Total loss : 27.789677238464357 Loss train. : 15.31519775390625 Loss test. : 12.474479484558106, r :4, n :47, d : 7
# Avg computation time for HAVOK : 0.012753963470458984 [s], for sim. : 0.8656950473785401 [s]
# Total loss : 10000000000.0 Loss train. : nan Loss test. : inf, r :13, n :40, d : 6
# Avg computation time for HAVOK : 0.02453460693359375 [s], for sim. : 0.9203367710113526 [s]
# Total loss : 76.33623466491699 Loss train. : 57.59458236694336 Loss test. : 18.741652297973634, r :4, n :45, d : 11
# Avg computation time for HAVOK : 0.012765216827392577 [s], for sim. : 0.9503270149230957 [s]
# Total loss : 238.1917282104492 Loss train. : 150.5276336669922 Loss test. : 87.66409454345703, r :4, n :73, d : 53
# Avg computation time for HAVOK : 0.01695394515991211 [s], for sim. : 0.9481317520141601 [s]
# Total loss : 22192794094.165184 Loss train. : 22192786508.8 Loss test. : 7585.365185546875, r :14, n :43, d : 35
# Avg computation time for HAVOK : 0.020544910430908205 [s], for sim. : 0.9384882926940918 [s]
# Total loss : 153538.82715301515 Loss train. : 153387.23671875 Loss test. : 151.5904342651367, r :7, n :46, d : 34
# Avg computation time for HAVOK : 0.012765645980834961 [s], for sim. : 0.9261215209960938 [s]
# Total loss : 206.53689880371093 Loss train. : 172.6800979614258 Loss test. : 33.85680084228515, r :4, n :77, d : 11
# Avg computation time for HAVOK : 0.02113208770751953 [s], for sim. : 0.8946168899536133 [s]
# Total loss : 3480.4421180725094 Loss train. : 3400.15947265625 Loss test. : 80.28264541625977, r :14, n :68, d : 56
# Avg computation time for HAVOK : 0.021941280364990233 [s], for sim. : 0.9382888793945312 [s]
# Total loss : 677735.2641967774 Loss train. : 677501.0926513672 Loss test. : 234.17154541015626, r :14, n :81, d : 52
# Avg computation time for HAVOK : 0.025728797912597655 [s], for sim. : 0.9452703475952149 [s]
# Total loss : 2241988.6400787355 Loss train. : 2241489.387109375 Loss test. : 499.2529693603516, r :14, n :86, d : 32
# Avg computation time for HAVOK : 0.029918384552001954 [s], for sim. : 0.9572393894195557 [s]
# Total loss : 456.3272766113281 Loss train. : 330.95457916259767 Loss test. : 125.37269744873046, r :4, n :141, d : 56
# Avg computation time for HAVOK : 0.02553086280822754 [s], for sim. : 0.9688078403472901 [s]
# Total loss : 10000000000.0 Loss train. : nan Loss test. : inf, r :14, n :108, d : 1
# Avg computation time for HAVOK : 0.04787192344665527 [s], for sim. : 0.9512537956237793 [s]
# Total loss : 6.75565013885498 Loss train. : 3.0730042934417723 Loss test. : 3.682645845413208, r :4, n :118, d : 1
# Avg computation time for HAVOK : 0.03709220886230469 [s], for sim. : 0.9588425159454346 [s]
# Total loss : 10000000000.0 Loss train. : nan Loss test. : inf, r :14, n :123, d : 1
# Avg computation time for HAVOK : 0.05405550003051758 [s], for sim. : 1.0025171756744384 [s]
# Total loss : 7.621066617965699 Loss train. : 3.4764846324920655 Loss test. : 4.144581985473633, r :4, n :133, d : 1
# Avg computation time for HAVOK : 0.04707279205322266 [s], for sim. : 0.9458697319030762 [s]
# Total loss : 737.8488220214844 Loss train. : 675.0342163085937 Loss test. : 62.814605712890625, r :4, n :126, d : 10
# Avg computation time for HAVOK : 0.03749213218688965 [s], for sim. : 0.9185492515563964 [s]
# Total loss : 10000000000.0 Loss train. : nan Loss test. : inf, r :14, n :141, d : 1
# Avg computation time for HAVOK : 0.06482658386230469 [s], for sim. : 0.9458685398101807 [s]
# Total loss : 8.645114326477051 Loss train. : 3.9685629844665526 Loss test. : 4.676551342010498, r :4, n :150, d : 1
# Avg computation time for HAVOK : 0.050464820861816403 [s], for sim. : 0.973594856262207 [s]
# Total loss : 10000000000.0 Loss train. : nan Loss test. : 9482663302791168.0, r :14, n :158, d : 1
# Avg computation time for HAVOK : 0.07160835266113282 [s], for sim. : 0.958634328842163 [s]
# Total loss : 2470163635471.6616 Loss train. : 2470163625047.4 Loss test. : 10424.261865234375, r :12, n :151, d : 10
# Avg computation time for HAVOK : 0.05345649719238281 [s], for sim. : 0.9715999603271485 [s]
# Total loss : 2218.310729217529 Loss train. : 2140.02919921875 Loss test. : 78.28152999877929, r :4, n :163, d : 9
# Avg computation time for HAVOK : 0.051255416870117185 [s], for sim. : 0.9019933223724366 [s]
# Total loss : 78882016.51779786 Loss train. : 78880989.02421875 Loss test. : 1027.4935791015625, r :14, n :168, d : 13
# Avg computation time for HAVOK : 0.05684847831726074 [s], for sim. : 0.9105628490447998 [s]
# Total loss : 10000000000.0 Loss train. : nan Loss test. : inf, r :10, n :173, d : 1
# Avg computation time for HAVOK : 0.06861658096313476 [s], for sim. : 0.8977970600128173 [s]
# Total loss : 2505.7650833129883 Loss train. : 2403.5065673828126 Loss test. : 102.25851593017578, r :4, n :178, d : 12
# Avg computation time for HAVOK : 0.05244655609130859 [s], for sim. : 0.8812611103057861 [s]
# Total loss : 397470327.49631345 Loss train. : 397467036.2 Loss test. : 3291.2963134765623, r :14, n :184, d : 9
# Avg computation time for HAVOK : 0.06921453475952148 [s], for sim. : 0.8916139125823974 [s]
# Total loss : 1358.4539138793943 Loss train. : 1270.390313720703 Loss test. : 88.0636001586914, r :14, n :181, d : 22
# Avg computation time for HAVOK : 0.05804529190063477 [s], for sim. : 0.8730628967285157 [s]
# Total loss : 602.6219505310058 Loss train. : 525.3813690185547 Loss test. : 77.24058151245117, r :6, n :192, d : 18
# Avg computation time for HAVOK : 0.05824413299560547 [s], for sim. : 0.8969990730285644 [s]
# Total loss : 106.30156631469727 Loss train. : 85.3344482421875 Loss test. : 20.967118072509766, r :4, n :190, d : 3
# Avg computation time for HAVOK : 0.06341753005981446 [s], for sim. : 0.8678900718688964 [s]
# Total loss : 121978625.45838623 Loss train. : 121976394.5 Loss test. : 2230.958386230469, r :13, n :199, d : 9
# Avg computation time for HAVOK : 0.07498507499694824 [s], for sim. : 0.8788548946380615 [s]
# Total loss : 258.71950912475586 Loss train. : 166.75591735839845 Loss test. : 91.96359176635742, r :4, n :171, d : 25
# Avg computation time for HAVOK : 0.043264150619506836 [s], for sim. : 0.8531396865844727 [s]
# Total loss : 199.93257522583008 Loss train. : 105.44309463500977 Loss test. : 94.4894805908203, r :4, n :184, d : 31
# Avg computation time for HAVOK : 0.04527196884155273 [s], for sim. : 0.918953800201416 [s]
# Total loss : 2.3117598743921824e+16 Loss train. : 2.3117598743566996e+16 Loss test. : 354828.6440826416, r :13, n :175, d : 35
# Avg computation time for HAVOK : 0.046474456787109375 [s], for sim. : 0.9444736957550048 [s]
# Total loss : 271.2019889831543 Loss train. : 178.5526336669922 Loss test. : 92.64935531616212, r :4, n :183, d : 23
# Avg computation time for HAVOK : 0.05025825500488281 [s], for sim. : 0.9085819244384765 [s]
# Total loss : 209.87367324829103 Loss train. : 110.76874771118165 Loss test. : 99.10492553710938, r :4, n :192, d : 30
# Avg computation time for HAVOK : 0.04844732284545898 [s], for sim. : 0.9031972408294677 [s]
# Total loss : 1086.083203125 Loss train. : 992.2171447753906 Loss test. : 93.86605834960938, r :4, n :170, d : 19
# Avg computation time for HAVOK : 0.051455020904541016 [s], for sim. : 0.9291274547576904 [s]
# Total loss : 10068.732654571533 Loss train. : 9963.371484375 Loss test. : 105.36117019653321, r :14, n :184, d : 18
# Avg computation time for HAVOK : 0.06242413520812988 [s], for sim. : 0.9492618560791015 [s]
# Total loss : 63524.829000854494 Loss train. : 63258.9921875 Loss test. : 265.83681335449216, r :14, n :177, d : 16
# Avg computation time for HAVOK : 0.06143546104431152 [s], for sim. : 0.9450708866119385 [s]
# Total loss : 178.86179962158204 Loss train. : 91.45944061279297 Loss test. : 87.40235900878906, r :4, n :187, d : 28
# Avg computation time for HAVOK : 0.05204672813415527 [s], for sim. : 0.9373120784759521 [s]
# Total loss : 1097.6015747070312 Loss train. : 1003.7339324951172 Loss test. : 93.86764221191406, r :4, n :202, d : 16
# Avg computation time for HAVOK : 0.062013769149780275 [s], for sim. : 0.9155701160430908 [s]
# Total loss : 947376905741383.6 Loss train. : 947376905663283.2 Loss test. : 78100.3828125, r :14, n :165, d : 7
# Avg computation time for HAVOK : 0.06721353530883789 [s], for sim. : 0.9386946201324463 [s]
# Total loss : 10000000000.0 Loss train. : nan Loss test. : inf, r :12, n :184, d : 1
# Avg computation time for HAVOK : 0.07998528480529785 [s], for sim. : 0.9362951278686523 [s]
# Total loss : 242.33573455810546 Loss train. : 152.3503875732422 Loss test. : 89.98534698486328, r :4, n :176, d : 22
# Avg computation time for HAVOK : 0.05304393768310547 [s], for sim. : 0.9586484909057618 [s]
# Total loss : 35.05694351196289 Loss train. : 21.119732666015626 Loss test. : 13.937210845947266, r :4, n :178, d : 2
# Avg computation time for HAVOK : 0.06260437965393066 [s], for sim. : 0.8950384140014649 [s]
# Total loss : 828.0608764648438 Loss train. : 731.2916931152344 Loss test. : 96.76918334960938, r :4, n :159, d : 18
# Avg computation time for HAVOK : 0.04545292854309082 [s], for sim. : 0.8613272190093995 [s]
# Total loss : 314.31051483154295 Loss train. : 172.86139221191405 Loss test. : 141.4491226196289, r :4, n :204, d : 36
# Avg computation time for HAVOK : 0.04026632308959961 [s], for sim. : 0.8445727348327636 [s]
# Total loss : 2377.0105491638187 Loss train. : 2275.3606689453127 Loss test. : 101.64988021850586, r :4, n :195, d : 11
# Avg computation time for HAVOK : 0.06540584564208984 [s], for sim. : 0.8581289291381836 [s]
# Total loss : 572.5090873718261 Loss train. : 483.9018310546875 Loss test. : 88.60725631713868, r :13, n :211, d : 21
# Avg computation time for HAVOK : 0.06482548713684082 [s], for sim. : 0.8616948127746582 [s]
# Total loss : 10000000000.0 Loss train. : nan Loss test. : inf, r :14, n :151, d : 1
# Avg computation time for HAVOK : 0.06721343994140624 [s], for sim. : 0.8680835723876953 [s]
# Total loss : 296.4132369995117 Loss train. : 152.26346588134766 Loss test. : 144.14977111816407, r :4, n :219, d : 28
# Avg computation time for HAVOK : 0.056628179550170896 [s], for sim. : 0.8623189449310302 [s]
# Total loss : 40734300.41042709 Loss train. : 40733494.51138306 Loss test. : 805.8990440368652, r :7, n :221, d : 13
# Avg computation time for HAVOK : 0.0742006778717041 [s], for sim. : 0.8503252029418945 [s]
# Total loss : 580.2566833496094 Loss train. : 464.49841766357423 Loss test. : 115.75826568603516, r :14, n :228, d : 23
# Avg computation time for HAVOK : 0.06861562728881836 [s], for sim. : 0.8685273647308349 [s]
# Total loss : 241.08207473754885 Loss train. : 147.97601165771485 Loss test. : 93.10606307983399, r :4, n :235, d : 19
# Avg computation time for HAVOK : 0.07079019546508789 [s], for sim. : 0.8711396217346191 [s]
# Total loss : 13166810.363195801 Loss train. : 13165856.815625 Loss test. : 953.5475708007813, r :14, n :234, d : 9
# Avg computation time for HAVOK : 0.09514427185058594 [s], for sim. : 0.9708461284637451 [s]
# Total loss : 728.9816963195801 Loss train. : 615.4552070617676 Loss test. : 113.5264892578125, r :14, n :245, d : 19
# Avg computation time for HAVOK : 0.08316912651062011 [s], for sim. : 0.94587721824646 [s]
# Total loss : 13066.105963134765 Loss train. : 12948.443115234375 Loss test. : 117.66284790039063, r :5, n :246, d : 8
# Avg computation time for HAVOK : 0.09054393768310547 [s], for sim. : 0.9506760597229004 [s]
# Total loss : 15.64478588104248 Loss train. : 7.798392391204834 Loss test. : 7.846393489837647, r :4, n :233, d : 1
# Avg computation time for HAVOK : 0.09293713569641113 [s], for sim. : 0.929526948928833 [s]
# Total loss : 10000000000.0 Loss train. : inf Loss test. : 151849408.26184386, r :9, n :238, d : 34
# Avg computation time for HAVOK : 0.05106263160705567 [s], for sim. : 0.9151514530181885 [s]
# Total loss : 355.1052947998047 Loss train. : 212.55903015136718 Loss test. : 142.5462646484375, r :4, n :249, d : 27
# Avg computation time for HAVOK : 0.06421432495117188 [s], for sim. : 0.9363145351409912 [s]
# Total loss : 10000000000.0 Loss train. : nan Loss test. : inf, r :14, n :216, d : 1
# Avg computation time for HAVOK : 0.10471901893615723 [s], for sim. : 0.9532501220703125 [s]
# Total loss : 27477.88382110596 Loss train. : 26677.671809387208 Loss test. : 800.21201171875, r :13, n :223, d : 38
# Avg computation time for HAVOK : 0.045870304107666016 [s], for sim. : 0.9404833316802979 [s]
# Total loss : 415.139714050293 Loss train. : 246.9300506591797 Loss test. : 168.20966339111328, r :4, n :228, d : 44
# Avg computation time for HAVOK : 0.03608379364013672 [s], for sim. : 0.9590595722198486 [s]
# Total loss : 1668758951506.9128 Loss train. : 1668758887619.4805 Loss test. : 63887.4323425293, r :14, n :141, d : 56
# Avg computation time for HAVOK : 0.029320907592773438 [s], for sim. : 0.9500638484954834 [s]
# Total loss : 10000000000.0 Loss train. : inf Loss test. : 384068071832.3747, r :14, n :236, d : 48
# Avg computation time for HAVOK : 0.03291044235229492 [s], for sim. : 0.9542479038238525 [s]
# Total loss : 551.4973915100097 Loss train. : 239.3899040222168 Loss test. : 312.107487487793, r :4, n :246, d : 45
# Avg computation time for HAVOK : 0.032693910598754886 [s], for sim. : 0.922749662399292 [s]
# Total loss : 29830770.727633666 Loss train. : 29824563.932998657 Loss test. : 6206.794635009765, r :14, n :249, d : 38
# Avg computation time for HAVOK : 0.04548006057739258 [s], for sim. : 0.8513201236724853 [s]
# Total loss : 3811.6393768310545 Loss train. : 3724.922119140625 Loss test. : 86.71725769042969, r :4, n :142, d : 11
# Avg computation time for HAVOK : 0.04366941452026367 [s], for sim. : 0.8529379367828369 [s]
# Total loss : 13.437379074096679 Loss train. : 6.547165203094482 Loss test. : 6.890213871002198, r :4, n :211, d : 1
# Avg computation time for HAVOK : 0.07918148040771485 [s], for sim. : 0.8685099601745605 [s]
# Total loss : 7177.107920074463 Loss train. : 7063.544995117188 Loss test. : 113.56292495727538, r :12, n :181, d : 20
# Avg computation time for HAVOK : 0.05783929824829102 [s], for sim. : 0.8487766742706299 [s]
# Total loss : 10000000000.0 Loss train. : nan Loss test. : 567961878796697.6, r :14, n :245, d : 1
# Avg computation time for HAVOK : 0.11707849502563476 [s], for sim. : 0.8615464687347412 [s]
# Total loss : 10000000000.0 Loss train. : inf Loss test. : 219043531852.1256, r :4, n :237, d : 56
# Avg computation time for HAVOK : 0.018337440490722657 [s], for sim. : 0.8625200271606446 [s]
# Total loss : 10000000000.0 Loss train. : nan Loss test. : nan, r :14, n :249, d : 56
# Avg computation time for HAVOK : 0.02493252754211426 [s], for sim. : 0.8571277141571045 [s]
# Total loss : 10000000000.0 Loss train. : nan Loss test. : 496546645181564.5, r :11, n :223, d : 56
# Avg computation time for HAVOK : 0.02253861427307129 [s], for sim. : 0.863313865661621 [s]
# Total loss : 1335.7388305664062 Loss train. : 1248.541552734375 Loss test. : 87.19727783203125, r :14, n :199, d : 20
# Avg computation time for HAVOK : 0.06342978477478027 [s], for sim. : 0.8872694969177246 [s]
# Total loss : 426.38927993774416 Loss train. : 247.61006851196288 Loss test. : 178.77921142578126, r :4, n :215, d : 47
# Avg computation time for HAVOK : 0.034088420867919925 [s], for sim. : 0.9343326568603516 [s]
# Total loss : 2588018914678710.0 Loss train. : 2588018914603827.0 Loss test. : 74883.0015625, r :14, n :133, d : 9
# Avg computation time for HAVOK : 0.04887204170227051 [s], for sim. : 0.9628206729888916 [s]
# Total loss : 5857.636138153076 Loss train. : 5760.87646484375 Loss test. : 96.75967330932617, r :4, n :151, d : 11
# Avg computation time for HAVOK : 0.04685354232788086 [s], for sim. : 0.8926693439483643 [s]
# Total loss : 13934126.818762207 Loss train. : 13933177.94375 Loss test. : 948.8750122070312, r :14, n :211, d : 10
# Avg computation time for HAVOK : 0.08397455215454101 [s], for sim. : 0.9285158634185791 [s]
# Total loss : 8.15628399848938 Loss train. : 3.731568431854248 Loss test. : 4.424715566635132, r :4, n :142, d : 1
# Avg computation time for HAVOK : 0.05044999122619629 [s], for sim. : 0.9506999492645264 [s]
# Total loss : 10000000000.0 Loss train. : nan Loss test. : inf, r :14, n :116, d : 1
# Avg computation time for HAVOK : 0.062449312210083006 [s], for sim. : 0.9291233062744141 [s]
# Total loss : 14.502742767333984 Loss train. : 7.144668388366699 Loss test. : 7.358074378967285, r :4, n :222, d : 1
# Avg computation time for HAVOK : 0.08654823303222656 [s], for sim. : 0.9231709003448486 [s]
# Total loss : 1251.4355926513672 Loss train. : 1161.7565979003907 Loss test. : 89.67899475097656, r :4, n :61, d : 56
# Avg computation time for HAVOK : 0.015535783767700196 [s], for sim. : 0.9257493495941163 [s]
# Total loss : 10000000000.0 Loss train. : nan Loss test. : 6144346537312406.0, r :4, n :249, d : 56
# Avg computation time for HAVOK : 0.01694149971008301 [s], for sim. : 0.9201523303985596 [s]
# Total loss : 578648.2648216247 Loss train. : 578461.3671508789 Loss test. : 186.8976707458496, r :11, n :72, d : 47
# Avg computation time for HAVOK : 0.02194046974182129 [s], for sim. : 0.9331035614013672 [s]
# Total loss : 848.1740165710448 Loss train. : 782.899853515625 Loss test. : 65.27416305541992, r :4, n :118, d : 11
# Avg computation time for HAVOK : 0.03269252777099609 [s], for sim. : 0.9474905490875244 [s]
# Total loss : 10000000000.0 Loss train. : nan Loss test. : inf, r :14, n :228, d : 1
# Avg computation time for HAVOK : 0.12167444229125976 [s], for sim. : 0.9267202377319336 [s]
# Total loss : 309.79668121337886 Loss train. : 227.4259063720703 Loss test. : 82.37077484130859, r :4, n :168, d : 22
# Avg computation time for HAVOK : 0.04485335350036621 [s], for sim. : 0.8391807079315186 [s]
# Total loss : 760.3592323303222 Loss train. : 696.957373046875 Loss test. : 63.401859283447266, r :4, n :75, d : 17
# Avg computation time for HAVOK : 0.019321393966674805 [s], for sim. : 0.8732966423034668 [s]
# Total loss : 4.680574345588685 Loss train. : 2.124860954284668 Loss test. : 2.555713391304016, r :4, n :80, d : 1
# Avg computation time for HAVOK : 0.021921586990356446 [s], for sim. : 0.8469808101654053 [s]
# Total loss : 177.5525344848633 Loss train. : 91.38918228149414 Loss test. : 86.16335220336914, r :4, n :205, d : 27
# Avg computation time for HAVOK : 0.05123610496520996 [s], for sim. : 0.8539635181427002 [s]
# Total loss : 11061.00998840332 Loss train. : 10697.981867980958 Loss test. : 363.02812042236326, r :4, n :223, d : 56
# Avg computation time for HAVOK : 0.02012624740600586 [s], for sim. : 0.8520102500915527 [s]
# Total loss : 28726.811132812498 Loss train. : 28492.8119140625 Loss test. : 233.99921875, r :14, n :101, d : 29
# Avg computation time for HAVOK : 0.03410787582397461 [s], for sim. : 0.900489616394043 [s]
# Total loss : 9864188610934.29 Loss train. : 9864188599216.0 Loss test. : 11718.289978027344, r :11, n :44, d : 34
# Avg computation time for HAVOK : 0.016945600509643555 [s], for sim. : 0.8557966709136963 [s]
# Total loss : 7.16271800994873 Loss train. : 3.262451696395874 Loss test. : 3.9002663135528564, r :4, n :125, d : 1
# Avg computation time for HAVOK : 0.039898347854614255 [s], for sim. : 0.8771435737609863 [s]
# Total loss : 9.304914617538453 Loss train. : 4.296852016448975 Loss test. : 5.0080626010894775, r :4, n :160, d : 1
# Avg computation time for HAVOK : 0.05583066940307617 [s], for sim. : 0.9237524509429932 [s]
# Total loss : 5.762132263183593 Loss train. : 2.6155553340911863 Loss test. : 3.146576929092407, r :4, n :100, d : 1
# Avg computation time for HAVOK : 0.029095268249511717 [s], for sim. : 0.8956373691558838 [s]
# Total loss : 1689509195793.0615 Loss train. : 1689509192464.118 Loss test. : 3328.9435028076173, r :14, n :249, d : 10
# Avg computation time for HAVOK : 0.10172696113586426 [s], for sim. : 0.9356968402862549 [s]
# Total loss : 27875.24602203369 Loss train. : 27766.751904296874 Loss test. : 108.4941177368164, r :8, n :81, d : 28
# Avg computation time for HAVOK : 0.021341466903686525 [s], for sim. : 0.922532320022583 [s]
# Total loss : 6394.729853820801 Loss train. : 6310.346496582031 Loss test. : 84.38335723876953, r :14, n :87, d : 42
# Avg computation time for HAVOK : 0.027924013137817384 [s], for sim. : 0.9496596336364747 [s]
# Total loss : 10000000000.0 Loss train. : nan Loss test. : inf, r :14, n :97, d : 1
# Avg computation time for HAVOK : 0.04547696113586426 [s], for sim. : 0.9422801017761231 [s]
# Total loss : 1095736.4435287477 Loss train. : 1094828.123765564 Loss test. : 908.3197631835938, r :14, n :113, d : 56
# Avg computation time for HAVOK : 0.027325439453125 [s], for sim. : 0.9462693691253662 [s]
# Total loss : 10000000000.0 Loss train. : nan Loss test. : 4.510787122287299e+16, r :14, n :235, d : 56
# Avg computation time for HAVOK : 0.02154092788696289 [s], for sim. : 0.9368939399719238 [s]
# Total loss : 306.9972915649414 Loss train. : 169.75254669189454 Loss test. : 137.24474487304687, r :4, n :229, d : 31
# Avg computation time for HAVOK : 0.052852201461791995 [s], for sim. : 0.9568455696105957 [s]
# Total loss : 10000000000.0 Loss train. : nan Loss test. : inf, r :14, n :203, d : 1
# Avg computation time for HAVOK : 0.10511765480041504 [s], for sim. : 1.0286485195159911 [s]
# Total loss : 264722759.72870788 Loss train. : 264722360.53882903 Loss test. : 399.1898788452148, r :14, n :92, d : 56
# Avg computation time for HAVOK : 0.0271273136138916 [s], for sim. : 1.011891984939575 [s]
# Total loss : 6291.881373596192 Loss train. : 6183.17861328125 Loss test. : 108.7027603149414, r :4, n :51, d : 37
# Avg computation time for HAVOK : 0.014746952056884765 [s], for sim. : 0.9744121551513671 [s]
# Total loss : 220.62136764526366 Loss train. : 124.05498352050782 Loss test. : 96.56638412475586, r :4, n :86, d : 56
# Avg computation time for HAVOK : 0.018524646759033203 [s], for sim. : 0.8693056583404541 [s]
# Total loss : 1604290.8112823486 Loss train. : 1603946.4130859375 Loss test. : 344.3981964111328, r :11, n :58, d : 48
# Avg computation time for HAVOK : 0.01914811134338379 [s], for sim. : 0.8658835887908936 [s]
# Total loss : 233.05293960571288 Loss train. : 136.54785537719727 Loss test. : 96.50508422851563, r :4, n :217, d : 38
# Avg computation time for HAVOK : 0.04128952026367187 [s], for sim. : 0.8938146591186523 [s]
# Total loss : 285.02500381469724 Loss train. : 202.44024658203125 Loss test. : 82.58475723266602, r :4, n :81, d : 46
# Avg computation time for HAVOK : 0.01893582344055176 [s], for sim. : 0.8653041362762451 [s]
# Total loss : 17.35160427093506 Loss train. : 8.748461246490479 Loss test. : 8.60314302444458, r :4, n :249, d : 1
# Avg computation time for HAVOK : 0.10269851684570312 [s], for sim. : 0.8587287425994873 [s]
# Total loss : 10000000000.0 Loss train. : nan Loss test. : inf, r :14, n :249, d : 47
# Avg computation time for HAVOK : 0.03031768798828125 [s], for sim. : 0.8738625526428223 [s]
# Total loss : 10000000000.0 Loss train. : nan Loss test. : 3.8209021384648755e+17, r :14, n :225, d : 48
# Avg computation time for HAVOK : 0.03409528732299805 [s], for sim. : 0.8631523132324219 [s]
# Total loss : 1759731.561805725 Loss train. : 1758850.5204727172 Loss test. : 881.0413330078125, r :14, n :218, d : 29
# Avg computation time for HAVOK : 0.05884184837341309 [s], for sim. : 0.8511230945587158 [s]
# Total loss : 649.1097663879394 Loss train. : 588.9771240234375 Loss test. : 60.132642364501955, r :4, n :174, d : 7
# Avg computation time for HAVOK : 0.06221990585327149 [s], for sim. : 0.9704376220703125 [s]
# Total loss : 103669346.52189864 Loss train. : 103667844.15123062 Loss test. : 1502.370668029785, r :14, n :249, d : 27
# Avg computation time for HAVOK : 0.06960577964782715 [s], for sim. : 0.9059834003448486 [s]
# Total loss : 212.98465805053712 Loss train. : 116.91659851074219 Loss test. : 96.06805953979492, r :4, n :182, d : 27
# Avg computation time for HAVOK : 0.04705867767333984 [s], for sim. : 0.9213558673858643 [s]
# Total loss : 492.11094665527344 Loss train. : 329.8668975830078 Loss test. : 162.24404907226562, r :4, n :192, d : 34
# Avg computation time for HAVOK : 0.04684805870056152 [s], for sim. : 0.9259555339813232 [s]
# Total loss : 4.418261712870468e+16 Loss train. : 4.4182617128081816e+16 Loss test. : 622860.7, r :14, n :179, d : 5
# Avg computation time for HAVOK : 0.07300457954406739 [s], for sim. : 0.9428768157958984 [s]
# Total loss : 3174682529.0601807 Loss train. : 3174679973.5375 Loss test. : 2555.5226806640626, r :14, n :186, d : 10
# Avg computation time for HAVOK : 0.07240548133850097 [s], for sim. : 0.9207365036010742 [s]
# Total loss : 10000000000.0 Loss train. : nan Loss test. : inf, r :11, n :186, d : 1
# Avg computation time for HAVOK : 0.08138141632080079 [s], for sim. : 0.9704041957855225 [s]
# Total loss : 10000000000.0 Loss train. : inf Loss test. : 11873702145.43125, r :8, n :171, d : 1
# Avg computation time for HAVOK : 0.06462635993957519 [s], for sim. : 0.9253246784210205 [s]
# Total loss : 2020315.9839538573 Loss train. : 2020195.1412109374 Loss test. : 120.84274291992188, r :7, n :48, d : 39
# Avg computation time for HAVOK : 0.013762140274047851 [s], for sim. : 0.922731876373291 [s]
# Total loss : 37604008.991485596 Loss train. : 37602749.3875 Loss test. : 1259.603985595703, r :14, n :184, d : 11
# Avg computation time for HAVOK : 0.06821632385253906 [s], for sim. : 0.954047441482544 [s]
# Total loss : 268.84211883544924 Loss train. : 197.92855529785157 Loss test. : 70.91356353759765, r :7, n :105, d : 40
# Avg computation time for HAVOK : 0.026129865646362306 [s], for sim. : 0.9342999935150147 [s]
# Total loss : 16088.17597541809 Loss train. : 16001.264111328124 Loss test. : 86.91186408996582, r :7, n :52, d : 42
# Avg computation time for HAVOK : 0.015956687927246093 [s], for sim. : 0.9113614559173584 [s]
# Total loss : 8812.117248535156 Loss train. : 8717.015509033203 Loss test. : 95.10173950195312, r :14, n :178, d : 19
# Avg computation time for HAVOK : 0.05904178619384766 [s], for sim. : 0.8602981090545654 [s]
# Total loss : 674798.7563106538 Loss train. : 674681.8190063477 Loss test. : 116.93730430603027, r :7, n :57, d : 47
# Avg computation time for HAVOK : 0.014959049224853516 [s], for sim. : 0.8628918647766113 [s]
# Total loss : 10000000000.0 Loss train. : nan Loss test. : inf, r :10, n :171, d : 1
# Avg computation time for HAVOK : 0.0670201301574707 [s], for sim. : 0.8666811466217041 [s]
# Total loss : 10000000000.0 Loss train. : inf Loss test. : 62956588416.0, r :9, n :40, d : 9
# Avg computation time for HAVOK : 0.015158843994140626 [s], for sim. : 0.8628915309906006 [s]
# Total loss : 1706.6176979064942 Loss train. : 1625.6619338989258 Loss test. : 80.95576400756836, r :7, n :108, d : 45
# Avg computation time for HAVOK : 0.024732685089111327 [s], for sim. : 0.8529185295104981 [s]
# Total loss : 117.28784828186035 Loss train. : 95.18474655151367 Loss test. : 22.10310173034668, r :4, n :122, d : 5
# Avg computation time for HAVOK : 0.03489232063293457 [s], for sim. : 0.8670937061309815 [s]
# Total loss : 10000000000.0 Loss train. : inf Loss test. : 362210531384.575, r :8, n :121, d : 2
# Avg computation time for HAVOK : 0.03789224624633789 [s], for sim. : 0.8622987747192383 [s]
# Total loss : 5944432358440.643 Loss train. : 5944432327065.6 Loss test. : 31375.0427734375, r :8, n :150, d : 7
# Avg computation time for HAVOK : 0.055450725555419925 [s], for sim. : 0.9212548732757568 [s]
# Total loss : 10.285477018356323 Loss train. : 4.804306316375732 Loss test. : 5.481170701980591, r :4, n :174, d : 1
# Avg computation time for HAVOK : 0.06262578964233398 [s], for sim. : 0.9298121929168701 [s]
# Total loss : 10000000000.0 Loss train. : nan Loss test. : inf, r :13, n :185, d : 1
# Avg computation time for HAVOK : 0.08336992263793945 [s], for sim. : 0.9404923439025878 [s]
# Total loss : 10000000000.0 Loss train. : inf Loss test. : 5375976376.5, r :11, n :154, d : 3
# Avg computation time for HAVOK : 0.060837411880493165 [s], for sim. : 0.9353408813476562 [s]
# Total loss : 254846424.6940918 Loss train. : 254842785.6 Loss test. : 3639.094091796875, r :13, n :185, d : 9
# Avg computation time for HAVOK : 0.07200570106506347 [s], for sim. : 0.9767876625061035 [s]
# Total loss : 2300.878388214111 Loss train. : 2235.888323974609 Loss test. : 64.99006423950195, r :6, n :197, d : 15
# Avg computation time for HAVOK : 0.06880154609680175 [s], for sim. : 1.0031367301940919 [s]
# Total loss : 828.0635696411133 Loss train. : 732.2017761230469 Loss test. : 95.8617935180664, r :4, n :176, d : 16
# Avg computation time for HAVOK : 0.05963320732116699 [s], for sim. : 1.0035282135009767 [s]
# Total loss : 163804727890273.97 Loss train. : 163804727867801.6 Loss test. : 22472.366564941407, r :5, n :146, d : 5
# Avg computation time for HAVOK : 0.04904789924621582 [s], for sim. : 0.9522719383239746 [s]
# Total loss : 9.237686238594674e+16 Loss train. : 9.237686238587126e+16 Loss test. : 75466.046875, r :9, n :247, d : 4
# Avg computation time for HAVOK : 0.10910053253173828 [s], for sim. : 0.9121728897094726 [s]
# Total loss : 1746.209342956543 Loss train. : 1647.4739013671874 Loss test. : 98.73544158935547, r :4, n :246, d : 9
# Avg computation time for HAVOK : 0.09253082275390626 [s], for sim. : 0.9321273803710938 [s]
# Total loss : 44649026.511772916 Loss train. : 44648857.84846191 Loss test. : 168.66331100463867, r :9, n :114, d : 21
# Avg computation time for HAVOK : 0.036294746398925784 [s], for sim. : 1.0547643661499024 [s]
# Total loss : 34400379.594903566 Loss train. : 34399448.975 Loss test. : 930.6199035644531, r :9, n :46, d : 37
# Avg computation time for HAVOK : 0.022134160995483397 [s], for sim. : 0.9356049060821533 [s]
# Total loss : 1269220.2786880494 Loss train. : 1269110.41796875 Loss test. : 109.8607192993164, r :7, n :50, d : 36
# Avg computation time for HAVOK : 0.014560317993164063 [s], for sim. : 0.8828383922576905 [s]
# Total loss : 24328.73477935791 Loss train. : 24218.427514648436 Loss test. : 110.30726470947266, r :5, n :52, d : 45
# Avg computation time for HAVOK : 0.014147663116455078 [s], for sim. : 0.8836492538452149 [s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-210-98448bb4e4ac> in <module>
#     102
#     103
# --> 104 opt.run_optimization(max_iter)
#
# ~\anaconda3\lib\site-packages\GPyOpt\core\bo.py in run_optimization(self, max_iter, max_time, eps, context, verbosity, save_models_parameters, report_file, evaluations_file, models_file)
#     149
#     150             # --- Evaluate *f* in X, augment Y and update cost function (if needed)
# --> 151             self.evaluate_objective()
#     152
#     153             # --- Update current evaluation time and function evaluations
#
# ~\anaconda3\lib\site-packages\GPyOpt\core\bo.py in evaluate_objective(self)
#     195         Evaluates the objective
#     196         """
# --> 197         self.Y_new, cost_new = self.objective.evaluate(self.suggested_sample)
#     198         self.cost.update_cost_model(self.suggested_sample, cost_new)
#     199         self.Y = np.vstack((self.Y,self.Y_new))
#
# ~\anaconda3\lib\site-packages\GPyOpt\core\task\objective.py in evaluate(self, x)
#      48
#      49         if self.n_procs == 1:
# ---> 50             f_evals, cost_evals = self._eval_func(x)
#      51         else:
#      52             try:
#
# ~\anaconda3\lib\site-packages\GPyOpt\core\task\objective.py in _eval_func(self, x)
#      72         for i in range(x.shape[0]):
#      73             st_time    = time.time()
# ---> 74             rlt = self.func(np.atleast_2d(x[i]))
#      75             f_evals     = np.vstack([f_evals,rlt])
#      76             cost_evals += [time.time()-st_time]
#
# <ipython-input-210-98448bb4e4ac> in loss(space)
#      53         timing[1,fold] = time.time() # Simulation time computation
#      54         # TESTING ######################################################
# ---> 55         model.Simulate(X0=delta_X[fold,:,0],
#      56                        horizon=nb_train,
#      57                        U=torch.cat((pendSim.X[fold,:,:nb_train],
#
# ~\OneDrive\Documents\Mécanique - EPFL\Master III\Semester project\Software\My code\Subspace-learning-for-robot-application\LQR simulation\Utils\Functions.py in Simulate(self, X0, horizon, **kwargs)
#     494                         self.Y_prediction[:,i+1] = self.A @ self.Y_prediction[:,i] + self.B @ U[:,i]
#     495                 elif self.kwargs['mode'] == 'ELQR form': # Includes exogenous input Ud
# --> 496                     self.Y_prediction[:,i+1] = self.A @ self.Y_prediction[:,i] + torch.cat((self.Bd[:],
#     497                                                                                             self.B),axis=1) @ U[:,i]
#     498                 elif self.kwargs['mode'] == 'step-wise': # only predicts one step forward, hence should perform better
#
# KeyboardInterrupt:

# %% [markdown]
# ## LQR control of the Panda robot
# ### Model prediction capabilities in training

# %%
# Train linear model
traj = 0

n = 80
r = 4
d = 1

model = HAVOK(delta_X[traj,:,:nb_train], # state-wise difference
              torch.cat((pendSim.X[traj,:,:nb_train-1],
                         pendSim.U[traj,:,:nb_train-1],
                         delta_U[traj,:,:nb_train-1]),axis=0), # model predicted states
              mode='ELQR form',
              nb_U=8,
              nb_U_ex=6
             )
# model = HAVOK(pandaRobot.X[traj,:,:nb_train], # state-wise difference
#               pandaRobot.U[traj,:,nb_train-1], # model predicted states
#               mode='prediction'
#              )
model.HANKEL(n, d)
model.SVD(r)
model.LS(r,rcond=0)

# model.Simulate(delta_X[traj,:,0],
#                horizon=nb_train,
#                U=torch.cat((pendSim.X[traj,:,:nb_train-1],
#                           pendSim.U[traj,None,:nb_train-1],
#                           delta_U[traj,None,:nb_train-1]),axis=0),
#                )
traj=1
model.Simulate(delta_X[traj,:,0],
               horizon=nb_test + nb_train-1,
               U=torch.cat((pendSim.X[traj,:,:],
                            pendSim.U[traj,:,:],
                            delta_U[traj,:,:]),axis=0),
               )
loss_traj = model.RMSE(X_true=delta_X[traj],
                       X_pred=model.X_prediction 
                      )
model.toNumpy()
print(loss_traj)
# print(loss_model)

# plt.rcParams['font.size'] = 20
# fig, ax = plt.subplots(1, 2, constrained_layout = True, figsize=(18,8))

# figA = snb.heatmap(model.A,cmap='Reds',ax=ax[0])
# figB = snb.heatmap(model.B,cmap='Reds',ax=ax[1])

plt.rcParams['font.size'] = 14 
fig, ax = plt.subplots(2, 3, constrained_layout = True, figsize=(15,7))

for i in range(2):

    ax[i,0].plot(pendSim.T[:-1], rad2deg(delta_X[traj,i,:]), label=r'$\delta q_{%d}$'%(i+1))
    ax[i,0].plot(pendSim.T[:-1], rad2deg(model.X_prediction[i,:]), label=r'$\delta \hat{q}_{%d}$'%(i+1),linestyle='dashed')
    ax[i,1].plot(pendSim.T[:-1], rad2deg(delta_X[traj,2+i,:]), label=r'$\delta \dot{q}_{%d}^m$'%(i+1))
    ax[i,1].plot(pendSim.T[:-1], rad2deg(model.X_prediction[2+i,:]), label=r'$\delta \dot{\hat{q}}_{%d}^m$'%(i+1),linestyle='dashed')

    ax[i,2].plot(pendSim.T[:-1], delta_U[traj,i,:], label=r'$\delta u_{%d}^m$'%(i+1))
    ax[i,0].set_ylabel('Position [deg]'), ax[i,1].set_ylabel('Velocity [deg/s]'), ax[i,2].set_ylabel('Torque [Nm]')
    ax[i,0].legend(), ax[i,1].legend(), ax[i,2].legend()
    
ax[1,0].set_xlabel('Time [s]'), ax[1,1].set_xlabel('Time [s]'), ax[1,2].set_xlabel('Time [s]')
# Out:
# tensor(3.4183)
# (Text(0.5, 0, 'Time [s]'), Text(0.5, 0, 'Time [s]'), Text(0.5, 0, 'Time [s]'))

# %%
model.A
# Out:
# array([[ 0.99629,  0.00824],
#        [-0.00258,  0.99985]], dtype=float32)

# %% [markdown]
# ### Use Extended LQR to correct trajectory

# %%
# Train linear model #######################################
traj = 2
# Correct trajectories with ELQR ############################
u_d = torch.cat((pendSim.X[traj,:,:],
                 pendSim.U[traj,:,:]),axis=0)
model.ConstructLQR(x_std=1e6*np.array([1,1,0,0]),
                   u_std=0.,
                   dt=pendSim.dt,
                   horizon=pendReal.N,
                   mode='ELQR',
                   u_d=u_d,
                   Bd=model.Bd
                  )
model.LQR_simulate(delta_X[traj,:,0].numpy(),
                   mode='ELQR', 
                   u_d=u_d,
                   Bd=model.Bd
                  )

plt.rcParams['font.size'] = 14 
fig, ax = plt.subplots(2, 3, constrained_layout = True, figsize=(15,7))

for i in range(2):

    ax[i,0].plot(pendSim.T[:-1], rad2deg(delta_X[traj,i,:]), label=r'$\delta q_{%d}$'%(i+1))
    ax[i,0].plot(pendSim.T[:-1], rad2deg(model.LQR_X[i,:]), label=r'$\delta \hat{q}_{%d}$'%(i+1),linestyle='dashed')
    ax[i,1].plot(pendSim.T[:-1], rad2deg(delta_X[traj,2+i,:]), label=r'$\delta \dot{q}_{%d}^m$'%(i+1))
    ax[i,1].plot(pendSim.T[:-1], rad2deg(model.LQR_X[2+i,:]), label=r'$\delta \dot{\hat{q}}_{%d}^m$'%(i+1),linestyle='dashed')

    ax[i,2].plot(pendSim.T[:-1], delta_U[traj,i,:], label=r'$\delta u_{%d}^m$'%(i+1))
    ax[i,2].plot(pendSim.T[:-2], model.LQR_U[0,:,i], label=r'$\delta u_{%d}^m$'%(i+1))
    ax[i,0].set_ylabel('Position [deg]'), ax[i,1].set_ylabel('Velocity [deg/s]'), ax[i,2].set_ylabel('Torque [Nm]')
    ax[i,0].legend(), ax[i,1].legend(), ax[i,2].legend()
    
ax[1,0].set_xlabel('Time [s]'), ax[1,1].set_xlabel('Time [s]'), ax[1,2].set_xlabel('Time [s]')
# Out:
# (Text(0.5, 0, 'Time [s]'), Text(0.5, 0, 'Time [s]'), Text(0.5, 0, 'Time [s]'))

# %%
a = np.array([[1,2],[3,4]])
print(a)
print(a.T.reshape(4,1))
# Out:
# [[1 2]
#  [3 4]]
# [[1]
#  [3]
#  [2]
#  [4]]

# %%
pendSim.X.shape
# Out:
# torch.Size([5, 4, 19999])

# %% [markdown]
# ### Corrected trajectories

# %%
log_control = np.empty(shape=[2,N-1])
log_control_model = np.empty(shape=[2,N-1])
log_q = np.empty(shape=[2,N])
log_dq = np.empty(shape=[2,N])
log_ddq = np.empty(shape=[2,N])
param = {'m1': .1, 'm2': .1, 
         'l1': .5, 'l2': .5,
         'time': np.arange(0,N*dt,dt), 'dt': dt
        }
pendulum = DoublePendulum(param)

Kp, Ki, Kd = np.diag([20,20]), np.diag([1,1]), np.diag([1,1])
torque_limit = np.array([100,100])
K = (np.array(model.LQR.K)[:,:,:] @ model.pinvC)
torque_limit = np.array([100,100])

pendulum.x = np.array([[pendSim.ref[traj,0,0],0,0],
                       [pendSim.ref[traj,1,0],0,0]])
log_error = []
sum_error = np.zeros(2)
log_q[:,0] = pendulum.x[:,0]
log_dq[:,0] = pendulum.x[:,1]
log_ddq[:,0] = pendulum.x[:,2]

# Initialize matrices
pendulum.Physics(pendulum.x[:,:2])

for i in range(0, N-2):
    error_q = pendSim.ref[traj,:2,i] - pendulum.x[:,0]
    error_dq = pendSim.ref[traj,2:,i] - pendulum.x[:,1]

    # Computed Torque Control
    control_input = pendulum.CTC(pendSim.desired_ddq[traj,:,i],
                                 ( Kp @ error_q + Ki @ sum_error + Kd @ error_dq ) - Fv@pendulum.x[:,1]
                                ) - K[i,:,:] @ (pendulum.x[:,:2].T.reshape(4) - pendSim.X[traj,:,i].numpy())
    
    for j in range(2):
        if control_input[j] > torque_limit[j]:
            control_input[j] = torque_limit[j]
        elif control_input[j] < -torque_limit[j]:
            control_input[j] = -torque_limit[j]

    pendulum.x[:,:2] = RK4(pendulum.Physics,
                           pendulum.x[:,:2], 
                           control_input,
                           pendulum.dt, 
                           type='controller-step-by-step'
                          ) # Simulation with Runge-Kutta 4
    pendulum.Physics(pendulum.x[:,:2],control_input)

    log_error.append(np.copy(error_q))
    log_q[:,i] = pendulum.x[:,0]
    log_dq[:,i] = pendulum.x[:,1]
    log_control[:,i] = control_input

    sum_error += error_q*dt
log_q = log_q[:,:-1]
log_dq = log_dq[:,:-1]

print(model.RMSE(X_true=pendSim.X[traj,]))

plt.rcParams['font.size'] = 14 
fig, ax = plt.subplots(2, 3, constrained_layout = True, figsize=(15,7))

for i in range(2):

    ax[i,0].plot(pendSim.T[:-1], rad2deg(pendSim.X[traj,i,:]), label=r'$q_{%d}^m$'%(i+1))
    ax[i,0].plot(pendReal.T[:-1], rad2deg(pendReal.X[traj,i,:]), label=r'$q_{%d}^0$'%(i+1), linestyle='dashed')
    ax[i,0].plot(pendSim.T[:-2], rad2deg(log_q[i,:]), label=r'$q_{%d}^{corr}$'%(i+1), linestyle='dotted')

    ax[i,1].plot(pendSim.T[:-1], rad2deg(pendSim.X[traj,2+i,:]), label=r'$\dot{q}_{%d}^m$'%(i+1))
    ax[i,1].plot(pendReal.T[:-1], rad2deg(pendReal.X[traj,2+i,:]), label=r'$\dot{q}_{%d}^0$'%(i+1), linestyle='dashed')
    ax[i,1].plot(pendReal.T[:-2], rad2deg(log_dq[i,:]), label=r'$\dot{q}_{%d}^{corr}$'%(i+1), linestyle='dotted')

    ax[i,2].plot(pendSim.T[:-1], pendSim.U[traj,i,:], label=r'$u_{%d}^m$'%(i+1))
    ax[i,2].plot(pendReal.T[:-1], pendReal.U[traj,i,:], label=r'$u_{%d}^0$'%(i+1), linestyle='dashed')
    ax[i,2].plot(pendReal.T[:-2], log_control[i,:], label=r'$u_{%d}^{corr}$'%(i+1), linestyle='dashed')
    ax[i,0].set_ylabel('Position [deg]'), ax[i,1].set_ylabel('Velocity [deg/s]'), ax[i,2].set_ylabel('Torque [Nm]')
    ax[i,0].legend(), ax[i,1].legend(), ax[i,2].legend()
    
ax[1,0].set_xlabel('Time [s]'), ax[1,1].set_xlabel('Time [s]'), ax[1,2].set_xlabel('Time [s]')
# Out:
# (Text(0.5, 0, 'Time [s]'), Text(0.5, 0, 'Time [s]'), Text(0.5, 0, 'Time [s]'))
