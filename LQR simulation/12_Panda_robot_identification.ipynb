# %% [markdown]
# # Panda robot identification and LQR control

# %%
import numpy as np
from numpy import random as rnd
from numpy.linalg import pinv
from numpy import linalg as lg
from scipy import linalg as slg
from importlib import reload
import seaborn as snb
import matplotlib.pyplot as plt
import Utils.Functions 
from Utils.Functions import *
import pbdlib as pbd
from scipy.linalg import hankel
import joblib
import pybullet
from pbdlib import LQR
from pbdlib.utils import get_canonical
import pandapybullet as ppb
import torch
import time
import GPy, GPyOpt
# %load_ext autoreload
# %autoreload 2
plt.style.use("default")
plt.rcParams['font.size'] = 13
plt.rcParams['axes.linewidth'] = 1.5
plt.rcParams['lines.linewidth'] = 2.5
np.set_printoptions(precision=5, suppress=False)

# %% [markdown]
# ## Gather training data
# ### Define random sine reference
#
# Run a LQR using desired joint position and velocity to retrieve jooitn acceleration

# %%
dt = 1e-3
world_sim = ppb.WorldSim()
world_sim.setup_scene()
world_sim.load_table()
robot = world_sim.load_panda()

# %%
N=15000
T = N*dt
n_training = 5
n_testing = 1
n_tot = n_training + n_testing
joint_limits = robot.joint_limits.copy()
joint_limits[1,:] = [-deg2rad(35),deg2rad(35)]
# joint_limits[3,0] = -deg2rad(60)

# Trajectories specifications
specs = {'phi': {'low': -np.pi, 'high': np.pi}, 
         'A': {'low': -np.pi, 'high': np.pi},
         'f': {'low': 1/20, 'high': .3},
         'nb_parts': 100, 'margin': .2, 'safety': .8}

pandaRobot = Robot(7, 7, dt, N, robot)
pandaRobot.drawTrajectories(nb_traj=n_tot, q_limits=joint_limits, specs=specs)

# %% [markdown]
# ## Gather training data using CTC + PD
#
# ### Tune PD controller

# %%
Kp = np.diag([200]*7)
Ki = np.eye(7)*5.
Kd = np.eye(7)*5.

robot.reset_q(max_iter=100)
robot.joints_free=True
# Out:
# joints are free now

# %% [markdown]
# ### Simulate using CTC + PD

# %%
log_control = np.empty(shape=[n_tot,7,N-1])
log_q = np.empty(shape=[n_tot,7,N])
log_dq = np.empty(shape=[n_tot,7,N])
log_ddq = np.empty(shape=[n_tot,7,N])

for n in range(n_tot):
    log_error = []
    sum_error = np.zeros(7)
    log_q[n,:,0] = robot.q
    log_dq[n,:,0] = robot.dq
    log_ddq[n,:,0] = robot.ddq
    
    robot.default_q = pandaRobot.ref[n,:7,0]
    robot.reset_q(max_iter=100)
    robot.joints_free=True
    for i in range(0, N-1):
        error_q = pandaRobot.ref[n,:7,i] - robot.q
        error_dq = pandaRobot.ref[n,7:,i] - robot.dq

    #   Computed Torque Control
        control_input = robot.configuration_ctc(Kp @ error_q + Ki @ sum_error + Kd @ error_dq + pandaRobot.desired_ddq[n,:,i])
        
        for j in range(7):
            if control_input[j] < robot.joint_torque_limits[j,0]:
                control_input[j] = robot.joint_torque_limits[j,0].copy()
            if control_input[j] > robot.joint_torque_limits[j,1]:
                control_input[j] = robot.joint_torque_limits[j,1].copy()

        robot.set_torque(control_input[:7])

        log_error.append(np.copy(error_q))
        log_q[n,:,i] = robot.q.copy()
        log_dq[n,:,i] = robot.dq.copy()
        log_ddq[n,:,i] = robot.ddq.copy()
        log_control[n,:,i] = np.copy(control_input)
    #     time.sleep(dt)
        sum_error += error_q*dt
# Out:
# joints are free now
# joints are free now
# joints are free now
# joints are free now
# joints are free now
# joints are free now
# joints are free now

# %% [markdown]
# ### Store data in state-space form

# %%
pandaRobot.toStateSpace(log_q, log_dq, log_control)

# %% [markdown]
# ## Model training

# %% [markdown]
# ### Using *GPyOpt*

# %%
traj_ratio = .02
n_low, n_high = 15, 120
d_low, d_high = 1, np.int((1-traj_ratio)/n_high*pandaRobot.N)

domain = [
    {'name': 'input_cost', 'type': 'continuous', 'domain': (0.,3.)},
    {'name': 'dimension', 'type': 'discrete', 'domain': np.arange(5,100,1)},
    {'name': 'nb_traj', 'type': 'discrete', 'domain': np.arange(n_low,n_high,1)},
    {'name': 'nb_delays', 'type': 'discrete', 'domain': np.arange(d_low,d_high,1)}
]

print('delay max : ',np.int((1-traj_ratio)/n_high*pandaRobot.N))
print('points min : ',pandaRobot.N- d_high*n_high)

# n_training = 5 # Number of trainings per epoch
loss_traj = np.empty(shape=[n_training])
loss_U = np.empty(shape=[n_training])
loss_LQR = np.empty(shape=[n_training])

# @use_named_args(SPACE)
def loss(space):
    # Model parameters
    n_params = space.shape[0] # If train by batch
    u_std = space[0,0]
    s = np.int(space[0,1])
    n = np.int(space[0,2])
    d = np.int(space[0,3])
    
    timing = np.empty([2,n_training])
    
    for fold in range(n_training):
        timing[0,fold] = time.time() # HAVOK computation time
        
        model = HAVOK(pandaRobot.dX[fold,:,:], pandaRobot.dU[fold,:,:], learnOnDiff=True)
#         model = HAVOK(pandaRobot.X[fold,:,:], pandaRobot.U[fold,:,:])
        model.HANKEL(n, d)
        model.SVD(s)
        model.LS(s,rcond=0)
#         model.Simulate(pandaRobot.ref[fold,:,0],U_testing = pandaRobot.U[fold,:]) # Learn on differences

        timing[0,fold] = time.time() - timing[0,fold]  
        timing[1,fold] = time.time() # LQR computation time
        
        # LQR loss ##############################
        model.ConstructLQR(x_std=np.concatenate((1e6*np.ones([7]),np.zeros([7]))), u_std=u_std, dt=dt, ref=pandaRobot.ref[fold,:,:]) # To learn on differences
        model.LQR_simulate(X0=pandaRobot.ref[fold,:,0])
        
#         loss_traj[fold] = model.RMSE(X_pred=model.X_traj, X_true=pandaRobot.X[fold,:,:]) 
        loss_LQR[fold] = model.RMSE(X_pred=torch.tensor(model.LQR_X[:7,:],dtype=torch.float), 
                                    X_true=torch.tensor(pandaRobot.ref[fold,:7,:],dtype=torch.float))
        loss_U[fold] = model.RMSE(X_pred=model.LQR_U[0,:,:].T, 
                                  X_true=pandaRobot.U[fold,:,:])
        
        timing[1,fold] = time.time() - timing[1,fold]  
        
    loss_LQR_sum = loss_LQR.sum()/n_training
    loss_U_sum = loss_U.sum()/n_training
    loss = loss_LQR_sum + loss_U_sum
    avg_time = [timing[0,:].sum()/n_training,timing[1,:].sum()/n_training]
    
    if np.isnan(loss) or np.isinf(loss):
        loss = 1e10
        
    print('Total loss : '+str(loss)+'Loss LQR : '+str(loss_LQR_sum)+'Loss U : '+str(loss_U_sum)+
          ', u_std : '+str(u_std)+', s :'+str(s)+', n :'+str(n)+', d : '+str(d))
    print('Avg computation time for HAVOK : '+str(avg_time[0])+' [s], for LQR : '+str(avg_time[1])+' [s]')
    
    return loss

max_iter = 1000
batch_size = 6
num_cores = 6

opt = GPyOpt.methods.BayesianOptimization(f = loss,            # function to optimize       
                                          domain = domain,         # box-constraints of the problem
                                          acquisition_type ='LCB',       # LCB acquisition
                                          acquisition_weight = 0.5)     # Exploration exploitation
 

opt.run_optimization(max_iter)
# Out:
# delay max :  122
# points min :  360
# Total loss : 1686.733226899336Loss LQR : 48.96777992248535Loss U : 1637.7654469768506, u_std : 0.7131495641360898, s :23, n :93, d : 43
# Avg computation time for HAVOK : 12.307263326644897 [s], for LQR : 4.995491218566895 [s]
# Total loss : 432.4197799180178Loss LQR : 54.497859191894534Loss U : 377.9219207261233, u_std : 2.121529108115136, s :49, n :31, d : 16
# Avg computation time for HAVOK : 3.211124038696289 [s], for LQR : 7.5896553039550785 [s]
# Total loss : 446.05397769150255Loss LQR : 55.374369049072264Loss U : 390.6796086424303, u_std : 2.1060669325099095, s :50, n :16, d : 5
# Avg computation time for HAVOK : 2.203894567489624 [s], for LQR : 8.011662769317628 [s]
# Total loss : 1302.7464451267947Loss LQR : 63.33039093017578Loss U : 1239.416054196619, u_std : 0.6356706135243727, s :10, n :88, d : 118
# Avg computation time for HAVOK : 3.0880942821502684 [s], for LQR : 4.872353219985962 [s]
# Total loss : 2492.778728909426Loss LQR : 62.84781188964844Loss U : 2429.9309170197776, u_std : 0.01660388497461418, s :11, n :80, d : 13
# Avg computation time for HAVOK : 14.133033657073975 [s], for LQR : 4.86197190284729 [s]
# Total loss : 504.8468462801778Loss LQR : 53.71226959228515Loss U : 451.1345766878926, u_std : 1.9811515877954415, s :50, n :16, d : 5
# Avg computation time for HAVOK : 2.0649405002593992 [s], for LQR : 8.416836881637574 [s]
# Total loss : 228.53684403346256Loss LQR : 58.96286849975586Loss U : 169.5739755337067, u_std : 3.0, s :59, n :22, d : 20
# Avg computation time for HAVOK : 2.55745644569397 [s], for LQR : 9.884281539916993 [s]
# Total loss : 218.68966743459904Loss LQR : 57.785848999023436Loss U : 160.9038184355756, u_std : 3.0, s :76, n :25, d : 30
# Avg computation time for HAVOK : 3.113987112045288 [s], for LQR : 13.917974519729615 [s]
# Total loss : 214.8083831317794Loss LQR : 61.54716796875Loss U : 153.26121516302942, u_std : 3.0, s :59, n :15, d : 44
# Avg computation time for HAVOK : 1.9606491565704345 [s], for LQR : 10.275583267211914 [s]
# Total loss : 2751.6118987963455Loss LQR : 25.110669898986817Loss U : 2726.5012288973585, u_std : 0.0, s :66, n :15, d : 31
# Avg computation time for HAVOK : 2.089398956298828 [s], for LQR : 11.370130729675292 [s]
# Total loss : 236.6532968106711Loss LQR : 64.30808868408204Loss U : 172.34520812658906, u_std : 3.0, s :50, n :17, d : 5
# Avg computation time for HAVOK : 2.4807355880737303 [s], for LQR : 8.710967445373536 [s]
# Total loss : 223.6873015641399Loss LQR : 56.72020263671875Loss U : 166.96709892742112, u_std : 3.0, s :57, n :23, d : 19
# Avg computation time for HAVOK : 2.6016310691833495 [s], for LQR : 8.812657880783082 [s]
# Total loss : 213.09439059734578Loss LQR : 59.57844543457031Loss U : 153.51594516277547, u_std : 3.0, s :51, n :21, d : 8
# Avg computation time for HAVOK : 2.727478504180908 [s], for LQR : 9.436613512039184 [s]
# Total loss : 218.2292074597654Loss LQR : 58.951378631591794Loss U : 159.2778288281736, u_std : 3.0, s :57, n :15, d : 48
# Avg computation time for HAVOK : 1.8776129245758058 [s], for LQR : 9.633253145217896 [s]
# Total loss : 246.48483721116978Loss LQR : 58.524583435058595Loss U : 187.9602537761112, u_std : 3.0, s :79, n :29, d : 29
# Avg computation time for HAVOK : 6.746393537521362 [s], for LQR : 15.355691719055176 [s]
# Total loss : 251.4456125092377Loss LQR : 67.60010299682617Loss U : 183.84550951241152, u_std : 3.0, s :49, n :22, d : 2
# Avg computation time for HAVOK : 2.578553342819214 [s], for LQR : 9.188118267059327 [s]
# Total loss : 226.3047075539407Loss LQR : 56.60075378417969Loss U : 169.703953769761, u_std : 3.0, s :62, n :25, d : 16
# Avg computation time for HAVOK : 2.983378219604492 [s], for LQR : 11.820877933502198 [s]
# Total loss : 273.16537323441935Loss LQR : 65.57615356445312Loss U : 207.5892196699662, u_std : 3.0, s :73, n :30, d : 25
# Avg computation time for HAVOK : 3.2744328498840334 [s], for LQR : 13.370255851745606 [s]
# Total loss : 237.02442496593108Loss LQR : 63.26487350463867Loss U : 173.7595514612924, u_std : 3.0, s :57, n :20, d : 46
# Avg computation time for HAVOK : 6.039215564727783 [s], for LQR : 9.577031803131103 [s]
# Total loss : 275.98416824826234Loss LQR : 71.6683135986328Loss U : 204.3158546496295, u_std : 3.0, s :75, n :30, d : 34
# Avg computation time for HAVOK : 3.2513893604278565 [s], for LQR : 14.21009087562561 [s]
# Total loss : 251.0896092434313Loss LQR : 65.21023101806641Loss U : 185.87937822536492, u_std : 3.0, s :61, n :30, d : 21
# Avg computation time for HAVOK : 5.51818470954895 [s], for LQR : 10.020529747009277 [s]
# Total loss : 243.05270965499952Loss LQR : 61.09259948730469Loss U : 181.96011016769484, u_std : 3.0, s :63, n :17, d : 49
# Avg computation time for HAVOK : 2.7117069721221925 [s], for LQR : 12.541805648803711 [s]
# Total loss : 247.2368413969146Loss LQR : 58.70207977294922Loss U : 188.53476162396538, u_std : 3.0, s :82, n :25, d : 34
# Avg computation time for HAVOK : 4.212778759002686 [s], for LQR : 12.966561365127564 [s]
# Total loss : 245.0620233495194Loss LQR : 64.40539932250977Loss U : 180.65662402700963, u_std : 3.0, s :82, n :24, d : 25
# Avg computation time for HAVOK : 4.329080486297608 [s], for LQR : 15.223420906066895 [s]
# Total loss : 255.17457013230086Loss LQR : 75.20675659179688Loss U : 179.96781354050398, u_std : 3.0, s :71, n :30, d : 51
# Avg computation time for HAVOK : 4.784474849700928 [s], for LQR : 10.658127403259277 [s]
# Total loss : 270.3586182612004Loss LQR : 68.88061447143555Loss U : 201.47800378976484, u_std : 3.0, s :81, n :28, d : 51
# Avg computation time for HAVOK : 5.784210062026977 [s], for LQR : 13.675493812561035 [s]
# Total loss : 256.1888474545507Loss LQR : 61.82073745727539Loss U : 194.3681099972753, u_std : 3.0, s :74, n :23, d : 59
# Avg computation time for HAVOK : 4.245904064178466 [s], for LQR : 14.473749828338622 [s]
# Total loss : 262.67351480854643Loss LQR : 76.7522087097168Loss U : 185.9213060988296, u_std : 3.0, s :77, n :34, d : 61
# Avg computation time for HAVOK : 5.23084716796875 [s], for LQR : 15.235422706604004 [s]
# Total loss : 258.3674991603112Loss LQR : 67.70813446044922Loss U : 190.65936469986198, u_std : 3.0, s :86, n :26, d : 64
# Avg computation time for HAVOK : 4.727560234069824 [s], for LQR : 17.00436315536499 [s]
# Total loss : 3547.256578995967Loss LQR : 39.9606764793396Loss U : 3507.2959025166274, u_std : 0.0, s :77, n :27, d : 72
# Avg computation time for HAVOK : 3.9194126605987547 [s], for LQR : 14.957926034927368 [s]
# Total loss : 233.8356463557957Loss LQR : 67.61086883544922Loss U : 166.22477752034646, u_std : 3.0, s :91, n :27, d : 59
# Avg computation time for HAVOK : 3.2643822193145753 [s], for LQR : 19.721420001983642 [s]
# Total loss : 276.598994056337Loss LQR : 78.9484848022461Loss U : 197.65050925409093, u_std : 3.0, s :81, n :37, d : 56
# Avg computation time for HAVOK : 3.8489262104034423 [s], for LQR : 16.965872287750244 [s]
# Total loss : 265.8945458480001Loss LQR : 65.73536224365235Loss U : 200.1591836043478, u_std : 3.0, s :83, n :21, d : 57
# Avg computation time for HAVOK : 2.808918857574463 [s], for LQR : 18.151837635040284 [s]
# Total loss : 236.99147208741846Loss LQR : 60.34249420166016Loss U : 176.64897788575828, u_std : 3.0, s :47, n :15, d : 42
# Avg computation time for HAVOK : 1.7874231338500977 [s], for LQR : 7.023680591583252 [s]
# Total loss : 212.00887771001365Loss LQR : 58.4903205871582Loss U : 153.51855712285544, u_std : 3.0, s :43, n :27, d : 37
# Avg computation time for HAVOK : 3.38116660118103 [s], for LQR : 6.6917845726013185 [s]
# Total loss : 260.5757304977791Loss LQR : 75.88997879028321Loss U : 184.68575170749585, u_std : 3.0, s :80, n :29, d : 57
# Avg computation time for HAVOK : 5.868064308166504 [s], for LQR : 20.476923656463622 [s]
# Total loss : 241.94593024872387Loss LQR : 63.48681564331055Loss U : 178.45911460541333, u_std : 3.0, s :73, n :21, d : 53
# Avg computation time for HAVOK : 2.6061832904815674 [s], for LQR : 271.1339149951935 [s]
# Total loss : 222.55778804225537Loss LQR : 63.81327667236328Loss U : 158.74451136989208, u_std : 3.0, s :33, n :20, d : 36
# Avg computation time for HAVOK : 5.234917402267456 [s], for LQR : 2.393195295333862 [s]
# Total loss : 261.3946947011933Loss LQR : 77.0564567565918Loss U : 184.3382379446015, u_std : 3.0, s :71, n :40, d : 57
# Avg computation time for HAVOK : 2.6308947563171388 [s], for LQR : 8.316534423828125 [s]
# Total loss : 241.10825812239645Loss LQR : 62.43732833862305Loss U : 178.6709297837734, u_std : 3.0, s :35, n :26, d : 46
# Avg computation time for HAVOK : 1.9861028671264649 [s], for LQR : 2.2938958168029786 [s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-77a1e182946c> in <module>
#      78
#      79
# ---> 80 opt.run_optimization(max_iter)
#
# ~\anaconda3\lib\site-packages\GPyOpt\core\bo.py in run_optimization(self, max_iter, max_time, eps, context, verbosity, save_models_parameters, report_file, evaluations_file, models_file)
#     149
#     150             # --- Evaluate *f* in X, augment Y and update cost function (if needed)
# --> 151             self.evaluate_objective()
#     152
#     153             # --- Update current evaluation time and function evaluations
#
# ~\anaconda3\lib\site-packages\GPyOpt\core\bo.py in evaluate_objective(self)
#     195         Evaluates the objective
#     196         """
# --> 197         self.Y_new, cost_new = self.objective.evaluate(self.suggested_sample)
#     198         self.cost.update_cost_model(self.suggested_sample, cost_new)
#     199         self.Y = np.vstack((self.Y,self.Y_new))
#
# ~\anaconda3\lib\site-packages\GPyOpt\core\task\objective.py in evaluate(self, x)
#      48
#      49         if self.n_procs == 1:
# ---> 50             f_evals, cost_evals = self._eval_func(x)
#      51         else:
#      52             try:
#
# ~\anaconda3\lib\site-packages\GPyOpt\core\task\objective.py in _eval_func(self, x)
#      72         for i in range(x.shape[0]):
#      73             st_time    = time.time()
# ---> 74             rlt = self.func(np.atleast_2d(x[i]))
#      75             f_evals     = np.vstack([f_evals,rlt])
#      76             cost_evals += [time.time()-st_time]
#
# <ipython-input-7-77a1e182946c> in loss(space)
#      43
#      44         # LQR loss ##############################
# ---> 45         model.ConstructLQR(x_std=np.concatenate((1e6*np.ones([7]),np.zeros([7]))), u_std=u_std, dt=dt, ref=pandaRobot.ref[fold,:,:]) # To learn on differences
#      46         model.LQR_simulate(X0=pandaRobot.ref[fold,:,0])
#      47
#
# ~\OneDrive\Documents\Mécanique - EPFL\Master III\Semester project\Software\My code\Subspace-learning-for-robot-application\LQR simulation\Utils\Functions.py in ConstructLQR(self, x_std, u_std, dt, ref, **kwargs)
#     465             else:
#     466                 cost = x_std
# --> 467             Q_tracking[i,:,:] = self.C.T@np.diag(cost)@self.C # Put zero velocity precision
#     468 #             current_ref = reference[i,:,np.newaxis]
#     469 #             ref_ref_T = current_ref@current_ref.T
#
# KeyboardInterrupt:

# %% [markdown]
# ## LQR control of the Panda robot
# ### Construct LQR planner

# %%
# Train linear model
traj = 0

n = 27
r = 43
d = 37
u_std = 3.0

model = HAVOK(pandaRobot.dX[traj,:,:], pandaRobot.dU[traj,:,:], learnOnDiff=True)
model.HANKEL(n, d)
model.SVD(r)
model.LS(r,rcond=0)
model.Simulate(pandaRobot.X[traj,:,0], U_testing = pandaRobot.U[traj,:])

loss_traj_train = model.RMSE(X_pred=model.X_traj, X_true=pandaRobot.X[traj,:,:])
print('Forward prediction RMSE : '+str(loss_traj_train))

# Train LQR controller
model.ConstructLQR(x_std=np.concatenate((1e6*np.ones([7]),np.zeros([7]))), u_std=u_std, dt=dt, ref=pandaRobot.ref[traj,:,:]) # To learn on differences
model.LQR_simulate(X0=pandaRobot.ref[traj,:,0])

loss_LQR_subspace = model.RMSE(X_pred=torch.tensor(model.LQR_X[:7,:]), 
                                    X_true=torch.tensor(pandaRobot.ref[traj,:7,:]))
print('LQR RMSE : '+str(loss_LQR_subspace))

# plt.rcParams['font.size'] = 20
# fig, ax = plt.subplots(1, 2, constrained_layout = True, figsize=(18,8))

# figA = snb.heatmap(model.A,cmap='Reds',ax=ax[0])
# figB = snb.heatmap(model.B,cmap='Reds',ax=ax[1])

plt.rcParams['font.size'] = 20
fig, ax = plt.subplots(7, 3, constrained_layout = True, figsize=(18,13))

for i in range(7):
    
    ax[i,0].plot(pandaRobot.T, rad2deg(model.LQR_X[i,:]), label='Joint '+str(i+1)+' pos.')
    ax[i,0].plot(pandaRobot.T, rad2deg(pandaRobot.ref[traj,i,:]), label='Pos. ref.')
    ax[i,1].plot(pandaRobot.T, rad2deg(model.LQR_X[7+i,:]), label='Joint '+str(i+1)+' vel.')
    ax[i,1].plot(pandaRobot.T, rad2deg(pandaRobot.X[traj,7+i,:]), label='Vel. CTC.')
    ax[i,2].plot(pandaRobot.T[:len(pandaRobot.T)-1], model.LQR_U[0,:,i], label='Joint '+str(i+1)+' torque LQR')
    ax[i,2].plot(pandaRobot.T[:len(pandaRobot.T)-1], pandaRobot.U[traj,i,:], label='Joint '+str(i+1)+' torque CTC')
    ax[i,0].set_ylabel('Pos. [deg]'), ax[i,1].set_ylabel('Vel. [deg/s]'), ax[i,2].set_ylabel('Torque [Nm]')
    ax[i,0].legend(), ax[i,1].legend(), ax[i,2].legend()
    
ax[6,0].set_xlabel('Time [s]'), ax[6,1].set_xlabel('Time [s]')
# Out:
# Forward prediction RMSE : tensor(107.3797)
# LQR RMSE : tensor(83.2077, dtype=torch.float64)
# (Text(0.5, 0, 'Time [s]'), Text(0.5, 0, 'Time [s]'))

# %% [markdown]
# ### Plot CTC trajectory

# %%
traj = 4
plt.rcParams['font.size'] = 20
fig, ax = plt.subplots(7, 3, constrained_layout = True, figsize=(18,11))

for i in range(7):
    
    ax[i,0].plot(pandaRobot.T, rad2deg(pandaRobot.X[traj,i,:]), label='Joint '+str(i+1)+' pos.')
    ax[i,0].plot(pandaRobot.T, rad2deg(pandaRobot.ref[traj,i,:]), label='Pos. ref.')
    ax[i,1].plot(pandaRobot.T, rad2deg(pandaRobot.X[traj,i+7,:]), label='Joint '+str(i+1)+' vel.')
    ax[i,1].plot(pandaRobot.T, rad2deg(pandaRobot.ref[traj,i+7,:]), label='Vel. ref.')
    ax[i,2].plot(pandaRobot.T[:len(pandaRobot.T)-1], pandaRobot.U[traj,i,:], label='Joint '+str(i+1)+' torque')
    ax[i,0].set_ylabel('Position [deg]'), ax[i,1].set_ylabel('Velocity [deg/s]'), ax[i,2].set_ylabel('Torque [Nm]')
    ax[i,0].legend(), ax[i,1].legend(), ax[i,2].legend()
    
ax[6,0].set_xlabel('Time [s]'), ax[6,1].set_xlabel('Time [s]')
# Out:
# (Text(0.5, 0, 'Time [s]'), Text(0.5, 0, 'Time [s]'))

# %% [markdown]
# ### Apply LQR planner onto real robot dynamics

# %%
X0 = pandaRobot.ref[traj,:,0]
Xc, Yc = np.zeros(shape=[model.nb_S,model.N]), np.zeros(shape=[model.tau,model.N])
Uc = np.empty(shape=[model.nb_U,model.N-1])

# Initial condition
Xc[:,0] = X0
# N = np.eye(model.tau) - pinv(model.C) @ model.C
Y0 = pinv(model.C)@X0
# Y0 = Y0 + N@(model.Y[:,0] - Y0) # Nullspace projection into subspace 
Yc[:,0] = Y0

robot.default_q = Xc[:7,0]
robot.reset_q(max_iter=100)
robot.joints_free=True

sum_error = np.zeros(7)

# Simulate the closed-loop trajectory for the non-linear dynamics
for i in range(model.N-1):

#   LQR planner control input
    control_input = model.LQR.get_command(Yc[:,i],i)

    robot.set_torque(control_input[:7])

    log_error.append(np.copy(error_q))
    Xc[0:7,i] = robot.q
    Xc[7:,i] = robot.dq
#     log_ddq[n,:,i] = robot.ddq
    Uc[:,i] = np.copy(control_input)
#     time.sleep(dt) # Real-time rendering
    sum_error += error_q*dt
    
    Yc[:,i+1] = pinv(model.C)@Xc[:,i+1]
    
loss_LQR_true = model.RMSE(X_pred=Xc[, 
                                    X_true=pandaRobot.ref[traj,:,:])
print('LQR RMSE : '+str(loss_LQR_true))
    
plt.rcParams['font.size'] = 20
fig,ax = plt.subplots(7, 3, constrained_layout = True, figsize=(18,13))

for i in range(7):
    
    ax[i,0].plot(pandaRobot.T, rad2deg(Xc[i,:]), label='Joint '+str(i+1)+' pos.')
    ax[i,0].plot(pandaRobot.T, rad2deg(pandaRobot.ref[traj,i,:]), label='Pos. ref.')
    ax[i,1].plot(pandaRobot.T, rad2deg(Xc[i+7,:]), label='Joint '+str(i+1)+' vel.')
    ax[i,1].plot(pandaRobot.T, rad2deg(pandaRobot.ref[traj,i+7,:]), label='Vel. ref.')
    ax[i,2].plot(pandaRobot.T[:len(pandaRobot.T)-1], Uc[i,:], label='Joint '+str(i+1)+' control')
    
    ax[i,0].set_ylabel('Position [deg]'), ax[i,1].set_ylabel('Velocity [deg/s]')
    ax[i,2].set_ylabel('Torque [Nm]')
    ax[i,0].legend(), ax[i,1].legend(), ax[i,2].legend()
    
ax[6,0].set_xlabel('Time [s]'), ax[6,1].set_xlabel('Time [s]')
# Out:
# C:\Users\cedri\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# joints are free now
# LQR RMSE : 497.4645270185171
# (Text(0.5, 0, 'Time [s]'), Text(0.5, 0, 'Time [s]'))

# %%
print(Xc[:,0],pandaRobot.ref[traj,:,0])
# Out:
# [ 1.92311 -0.84735  1.12334 -1.5787   1.15286 -0.00617 -1.87547  0.32676
#  -0.18946 -0.40925 -0.64609  0.71115 -0.24451 -1.27567] [-1.00575 -0.67185  1.75852 -0.44156 -1.78396  1.44367  0.94552  0.
#   0.       0.       0.       0.       0.       0.     ]
